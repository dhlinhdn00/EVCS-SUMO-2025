# %% [markdown]
# # **SETUP**

# %%
import sys
from pathlib import Path
sys.path.append('/home/hoai-linh.dao/Works/EVCS/CEREMA-Mini/src') 
from config import *

# Fixed PATHs
# NET_XML = Path("/home/hoai-linh.dao/Works/EVCS/CEREMA-Mini/data/newtest-osm.net.xml")
NET_XML = "/home/hoai-linh.dao/Works/EVCS/CEREMA-Mini/result/net-repairment/cleaned_p2_2_newtest-osm.net.xml"
VTYPES_DIST_XML = "/home/hoai-linh.dao/Works/EVCS/CEREMA-Mini/data/additional-files/vtypes-dist.add.xml"
MAIN_FLOW_CSV = "/home/hoai-linh.dao/Works/EVCS/CEREMA-Mini/data/processed-data/main-flow.csv"
TAZ_XML = "/home/hoai-linh.dao/Works/EVCS/CEREMA-Mini/data/additional-files/taz/taz-spatial-no-border-ratio.xml"

# Dynamic DIRs
SIMULATION_DIR = Path("/home/hoai-linh.dao/Works/EVCS/CEREMA-Mini/result/experiments/20-05-25-old-taz-ignore-errors") # MOST IMPORTANT

ODS_DIR = SIMULATION_DIR / "ods"
TRIPS_DIR = SIMULATION_DIR / "trips"
OUTPUTS_DIR = SIMULATION_DIR / "outputs"
LOGS_DIR = SIMULATION_DIR / "logs"
VISUALIZATIONS_DIR = SIMULATION_DIR / "visualizations"

SIMULATION_DIR.mkdir(parents=True, exist_ok=True)
for path in [ODS_DIR, TRIPS_DIR, OUTPUTS_DIR, LOGS_DIR, VISUALIZATIONS_DIR]:
    path.mkdir(parents=True, exist_ok=True)

# Dynamic PATHs
ALL_TRIPS_XML = SIMULATION_DIR / "trips.xml"
ROUTE_XML = SIMULATION_DIR / "route.xml"
ROUTE_ALT_XML = SIMULATION_DIR / "route.alt.xml"
SUMOCFG_XML = SIMULATION_DIR / "run.sumocfg"

DUAROUTER_LOG = LOGS_DIR / "duarouter.log"
SIMULATION_LOG = LOGS_DIR / "sumo_run.log"

# Outputs Paths
COLLISIONS_XML = OUTPUTS_DIR / "collisions.xml"
BATTERY_XML = OUTPUTS_DIR / "battery.xml"
LANECHANGES_XML = OUTPUTS_DIR / "laneChanges.xml"
STATISTICS_XML = OUTPUTS_DIR / "statistics.xml"
TRACE_XML = OUTPUTS_DIR / "sumoTrace.xml"
SUMMARY_XML = OUTPUTS_DIR / "summary.xml"
TRIPINFO_XML = OUTPUTS_DIR / "tripinfo.xml"
VEHROUTES_XML = OUTPUTS_DIR / "vehRoutes.xml"
NETSTATE_XML = OUTPUTS_DIR / "netstate.xml"
LOG_TXT = OUTPUTS_DIR / "log.txt"
EDGEDATA_XML = OUTPUTS_DIR / "edgeData-60s.xml"
LANEDATA_XML = OUTPUTS_DIR / "laneData-60s.xml"
QUEUE_XML = OUTPUTS_DIR / "queue.xml"
EMISSION_XML = OUTPUTS_DIR / "emission.xml"
SMS_XML = OUTPUTS_DIR / "sms.xml"

# Visualization Paths
PLOT_1_PNG = VISUALIZATIONS_DIR / "plot_1.png"
PLOT_2_PNG = VISUALIZATIONS_DIR / "plot_2.png"
PLOT_3_PNG = VISUALIZATIONS_DIR / "plot_3.png"
PLOT_4_PNG = VISUALIZATIONS_DIR / "plot_4.png"
PLOT_5_PNG = VISUALIZATIONS_DIR / "plot_5.png"
PLOT_6_PNG = VISUALIZATIONS_DIR / "plot_6.png"
PLOT_7_PNG = VISUALIZATIONS_DIR / "plot_7.png"
PLOT_8_PNG = VISUALIZATIONS_DIR / "plot_8.png"

PATH_REPLACEMENTS = {
    'net-file': NET_XML,
    'route-files': ROUTE_XML,
    'summary-output': SUMMARY_XML,
    'tripinfo-output': TRIPINFO_XML,
    'fcd-output': TRACE_XML,
    'lanechange-output': LANECHANGES_XML,
    'battery-output': BATTERY_XML,
    'vehroute-output': VEHROUTES_XML,
    'collision-output': COLLISIONS_XML,
    'netstate-dump': NETSTATE_XML,
    'statistic-output': STATISTICS_XML,
    'log': LOG_TXT,
    'lanedata-output': LANEDATA_XML,
    'edgedata-output': EDGEDATA_XML,
    'device.ssm.file': SMS_XML,
    'emission-output': EMISSION_XML,
    'queue-output': QUEUE_XML
}

# %% [markdown]
# # **MAIN**

# %% [markdown]
# ## Creating Ods

# %%
matrix_files = generateOds(
    MAIN_FLOW_CSV,
    ODS_DIR,
    TAZ_IDS,
    real_origin="marseille",
    exclude_cols={"total","intra"},
    trips_ratio=TRIPS_RATIO_0,
    scale_in=INCOMING_RATIO,
    scale_out=OUTGOING_RATIO
)


for hour, path in matrix_files:
    size = os.path.getsize(path)
    print(f"[DONE] OD matrix hour {hour}: {path} ({size} bytes)")
# Out:
# [DONE] OD matrix hour 4: /home/hoai-linh.dao/Works/EVCS/CEREMA-Mini/result/experiments/20-05-25-old-taz-ignore-errors/ods/od_matrix_04.txt (1688 bytes)
# [DONE] OD matrix hour 5: /home/hoai-linh.dao/Works/EVCS/CEREMA-Mini/result/experiments/20-05-25-old-taz-ignore-errors/ods/od_matrix_05.txt (1688 bytes)
# [DONE] OD matrix hour 6: /home/hoai-linh.dao/Works/EVCS/CEREMA-Mini/result/experiments/20-05-25-old-taz-ignore-errors/ods/od_matrix_06.txt (1688 bytes)
# [DONE] OD matrix hour 7: /home/hoai-linh.dao/Works/EVCS/CEREMA-Mini/result/experiments/20-05-25-old-taz-ignore-errors/ods/od_matrix_07.txt (1688 bytes)
# [DONE] OD matrix hour 8: /home/hoai-linh.dao/Works/EVCS/CEREMA-Mini/result/experiments/20-05-25-old-taz-ignore-errors/ods/od_matrix_08.txt (1688 bytes)
# [DONE] OD matrix hour 9: /home/hoai-linh.dao/Works/EVCS/CEREMA-Mini/result/experiments/20-05-25-old-taz-ignore-errors/ods/od_matrix_09.txt (1689 bytes)
# [DONE] OD matrix hour 10: /home/hoai-linh.dao/Works/EVCS/CEREMA-Mini/result/experiments/20-05-25-old-taz-ignore-errors/ods/od_matrix_10.txt (1690 bytes)
# [DONE] OD matrix hour 11: /home/hoai-linh.dao/Works/EVCS/CEREMA-Mini/result/experiments/20-05-25-old-taz-ignore-errors/ods/od_matrix_11.txt (1690 bytes)
# [DONE] OD matrix hour 12: /home/hoai-linh.dao/Works/EVCS/CEREMA-Mini/result/experiments/20-05-25-old-taz-ignore-errors/ods/od_matrix_12.txt (1690 bytes)
# [DONE] OD matrix hour 13: /home/hoai-linh.dao/Works/EVCS/CEREMA-Mini/result/experiments/20-05-25-old-taz-ignore-errors/ods/od_matrix_13.txt (1690 bytes)
# [DONE] OD matrix hour 14: /home/hoai-linh.dao/Works/EVCS/CEREMA-Mini/result/experiments/20-05-25-old-taz-ignore-errors/ods/od_matrix_14.txt (1690 bytes)
# [DONE] OD matrix hour 15: /home/hoai-linh.dao/Works/EVCS/CEREMA-Mini/result/experiments/20-05-25-old-taz-ignore-errors/ods/od_matrix_15.txt (1690 bytes)
# [DONE] OD matrix hour 16: /home/hoai-linh.dao/Works/EVCS/CEREMA-Mini/result/experiments/20-05-25-old-taz-ignore-errors/ods/od_matrix_16.txt (1690 bytes)
# [DONE] OD matrix hour 17: /home/hoai-linh.dao/Works/EVCS/CEREMA-Mini/result/experiments/20-05-25-old-taz-ignore-errors/ods/od_matrix_17.txt (1690 bytes)
# [DONE] OD matrix hour 18: /home/hoai-linh.dao/Works/EVCS/CEREMA-Mini/result/experiments/20-05-25-old-taz-ignore-errors/ods/od_matrix_18.txt (1690 bytes)
# [DONE] OD matrix hour 19: /home/hoai-linh.dao/Works/EVCS/CEREMA-Mini/result/experiments/20-05-25-old-taz-ignore-errors/ods/od_matrix_19.txt (1690 bytes)
# [DONE] OD matrix hour 20: /home/hoai-linh.dao/Works/EVCS/CEREMA-Mini/result/experiments/20-05-25-old-taz-ignore-errors/ods/od_matrix_20.txt (1690 bytes)
# [DONE] OD matrix hour 21: /home/hoai-linh.dao/Works/EVCS/CEREMA-Mini/result/experiments/20-05-25-old-taz-ignore-errors/ods/od_matrix_21.txt (1690 bytes)
# [DONE] OD matrix hour 22: /home/hoai-linh.dao/Works/EVCS/CEREMA-Mini/result/experiments/20-05-25-old-taz-ignore-errors/ods/od_matrix_22.txt (1690 bytes)
# [DONE] OD matrix hour 23: /home/hoai-linh.dao/Works/EVCS/CEREMA-Mini/result/experiments/20-05-25-old-taz-ignore-errors/ods/od_matrix_23.txt (1690 bytes)
# [DONE] OD matrix hour 0: /home/hoai-linh.dao/Works/EVCS/CEREMA-Mini/result/experiments/20-05-25-old-taz-ignore-errors/ods/od_matrix_00.txt (1688 bytes)
# [DONE] OD matrix hour 1: /home/hoai-linh.dao/Works/EVCS/CEREMA-Mini/result/experiments/20-05-25-old-taz-ignore-errors/ods/od_matrix_01.txt (1688 bytes)
# [DONE] OD matrix hour 2: /home/hoai-linh.dao/Works/EVCS/CEREMA-Mini/result/experiments/20-05-25-old-taz-ignore-errors/ods/od_matrix_02.txt (1688 bytes)
# [DONE] OD matrix hour 3: /home/hoai-linh.dao/Works/EVCS/CEREMA-Mini/result/experiments/20-05-25-old-taz-ignore-errors/ods/od_matrix_03.txt (1688 bytes)

# %% [markdown]
# ## Creating Trips from Ods

# %%
print("Call od2trips for all ...")
trips_files = od2tripsForAll(TAZ_XML, TRIPS_DIR, ODS_DIR)
print()
print("[DONE] Finished 24 Trips based on hours.")

mergeTrips(TRIPS_DIR, ALL_TRIPS_XML)
# Out:
# Call od2trips for all ...
# Success.time 3598.96
# Generated /home/hoai-linh.dao/Works/EVCS/CEREMA-Mini/result/experiments/20-05-25-old-taz-ignore-errors/trips/trips_00.xml
# Success.time 7199.76
# Generated /home/hoai-linh.dao/Works/EVCS/CEREMA-Mini/result/experiments/20-05-25-old-taz-ignore-errors/trips/trips_01.xml
# Success.time 10799.40
# Generated /home/hoai-linh.dao/Works/EVCS/CEREMA-Mini/result/experiments/20-05-25-old-taz-ignore-errors/trips/trips_02.xml
# Success.time 14395.97
# Generated /home/hoai-linh.dao/Works/EVCS/CEREMA-Mini/result/experiments/20-05-25-old-taz-ignore-errors/trips/trips_03.xml
# Success.time 17997.98
# Generated /home/hoai-linh.dao/Works/EVCS/CEREMA-Mini/result/experiments/20-05-25-old-taz-ignore-errors/trips/trips_04.xml
# Success.time 21598.85
# Generated /home/hoai-linh.dao/Works/EVCS/CEREMA-Mini/result/experiments/20-05-25-old-taz-ignore-errors/trips/trips_05.xml
# Success.time 25199.32
# Generated /home/hoai-linh.dao/Works/EVCS/CEREMA-Mini/result/experiments/20-05-25-old-taz-ignore-errors/trips/trips_06.xml
# Success.time 28799.4161.68
# Generated /home/hoai-linh.dao/Works/EVCS/CEREMA-Mini/result/experiments/20-05-25-old-taz-ignore-errors/trips/trips_07.xml
# Success.time 32399.48rsing time 29923.39ing time 31046.80g time 32170.17
# Generated /home/hoai-linh.dao/Works/EVCS/CEREMA-Mini/result/experiments/20-05-25-old-taz-ignore-errors/trips/trips_08.xml
# Success.time 35999.74me 33890.147
# Generated /home/hoai-linh.dao/Works/EVCS/CEREMA-Mini/result/experiments/20-05-25-old-taz-ignore-errors/trips/trips_09.xml
# Success.time 39599.84.99me 39595.76
# Generated /home/hoai-linh.dao/Works/EVCS/CEREMA-Mini/result/experiments/20-05-25-old-taz-ignore-errors/trips/trips_10.xml
# Success.time 43199.17.17me 43198.16
# Generated /home/hoai-linh.dao/Works/EVCS/CEREMA-Mini/result/experiments/20-05-25-old-taz-ignore-errors/trips/trips_11.xml
# Success.time 46799.764905.37rsing time 46422.07
# Generated /home/hoai-linh.dao/Works/EVCS/CEREMA-Mini/result/experiments/20-05-25-old-taz-ignore-errors/trips/trips_12.xml
# Success.time 50399.978480.12g time 50161.24
# Generated /home/hoai-linh.dao/Works/EVCS/CEREMA-Mini/result/experiments/20-05-25-old-taz-ignore-errors/trips/trips_13.xml
# Success.time 53999.20.22me 53943.10
# Generated /home/hoai-linh.dao/Works/EVCS/CEREMA-Mini/result/experiments/20-05-25-old-taz-ignore-errors/trips/trips_14.xml
# Success.time 57599.39
# Generated /home/hoai-linh.dao/Works/EVCS/CEREMA-Mini/result/experiments/20-05-25-old-taz-ignore-errors/trips/trips_15.xml
# Success.time 61199.079284.87g time 60970.74
# Generated /home/hoai-linh.dao/Works/EVCS/CEREMA-Mini/result/experiments/20-05-25-old-taz-ignore-errors/trips/trips_16.xml
# Success.time 64799.46rsing time 62320.57time 63627.73me 64748.30
# Generated /home/hoai-linh.dao/Works/EVCS/CEREMA-Mini/result/experiments/20-05-25-old-taz-ignore-errors/trips/trips_17.xml
# Success.time 68399.36rsing time 65924.29ing time 67048.58g time 68172.88
# Generated /home/hoai-linh.dao/Works/EVCS/CEREMA-Mini/result/experiments/20-05-25-old-taz-ignore-errors/trips/trips_18.xml
# Success.time 71999.95me 69911.225
# Generated /home/hoai-linh.dao/Works/EVCS/CEREMA-Mini/result/experiments/20-05-25-old-taz-ignore-errors/trips/trips_19.xml
# Success.time 75599.74ing time 74278.86
# Generated /home/hoai-linh.dao/Works/EVCS/CEREMA-Mini/result/experiments/20-05-25-old-taz-ignore-errors/trips/trips_20.xml
# Success.time 79199.20g time 79059.81
# Generated /home/hoai-linh.dao/Works/EVCS/CEREMA-Mini/result/experiments/20-05-25-old-taz-ignore-errors/trips/trips_21.xml
# Success.time 82799.76
# Generated /home/hoai-linh.dao/Works/EVCS/CEREMA-Mini/result/experiments/20-05-25-old-taz-ignore-errors/trips/trips_22.xml
# Success.time 86399.62
# Generated /home/hoai-linh.dao/Works/EVCS/CEREMA-Mini/result/experiments/20-05-25-old-taz-ignore-errors/trips/trips_23.xml
#
# [DONE] Finished 24 Trips based on hours.
# [DONE] Merged 24 trip files to /home/hoai-linh.dao/Works/EVCS/CEREMA-Mini/result/experiments/20-05-25-old-taz-ignore-errors/trips.xml

# %% [markdown]
# ## Creating Route

# %%
DUAROUTER_CMD = [
    "duarouter",
    "-n", NET_XML,            
    "-r", ALL_TRIPS_XML,            
    "-a", VTYPES_DIST_XML,
    "--randomize-flows",         
    "-o", ROUTE_XML,    
    "--log", DUAROUTER_LOG,
    "--exit-times",
    "--named-routes",
    "--route-length",
    "--write-costs",
    "--ignore-errors",
    "--seed", "2005"
]

print("Running DUAROUTER Step ...")
subprocess.run(DUAROUTER_CMD, check=True)
print(f"[DONE] Routes written in {ROUTE_XML}\n[LOG] Output logged in {DUAROUTER_LOG}")
# Out:
# Running DUAROUTER Step ...
# Reading up to time step: 200.12
# Warning: No connection between edge '47000202#2' and edge '367820007' found.
# Warning: Mandatory edge '367820007' not reachable by vehicle 'h00_476'.
# Warning: The vehicle 'h00_476' has no valid route.
# Warning: No connection between edge '71572284#0' and edge '383076320' found.
# Warning: Mandatory edge '383076320' not reachable by vehicle 'h00_486'.
# Warning: The vehicle 'h00_486' has no valid route.
# Warning: No connection between edge '159460077#0' and edge '112885002#1' found.
# Warning: Mandatory edge '112885002#1' not reachable by vehicle 'h00_739'.
# Warning: The vehicle 'h00_739' has no valid route.
# Reading up to time step: 400.12
# Warning: No connection between edge '121131441#1' and edge '386307421#1' found.
# Warning: Mandatory edge '386307421#1' not reachable by vehicle 'h00_1006'.
# Warning: The vehicle 'h00_1006' has no valid route.
# Warning: No connection between edge '176500112#3' and edge '161432888' found.
# Warning: Mandatory edge '161432888' not reachable by vehicle 'h00_1123'.
# Warning: The vehicle 'h00_1123' has no valid route.
# Warning: No connection between edge '196878695#1' and edge '143962123#0' found.
# Warning: Mandatory edge '143962123#0' not reachable by vehicle 'h00_1286'.
# Warning: The vehicle 'h00_1286' has no valid route.
# Reading up to time step: 600.12
# Warning: No connection between edge '150283169' and edge '62023740' found.
# Warning: Mandatory edge '62023740' not reachable by vehicle 'h00_1800'.
# Warning: The vehicle 'h00_1800' has no valid route.
# Warning: No connection between edge '425062602' and edge '510193680' found.
# Warning: Mandatory edge '510193680' not reachable by vehicle 'h00_2028'.
# Warning: The vehicle 'h00_2028' has no valid route.
# Warning: No connection between edge '103268024' and edge '388890720#7' found.
# Warning: Mandatory edge '388890720#7' not reachable by vehicle 'h00_16758'.
# Warning: The vehicle 'h00_16758' has no valid route.
# Warning: No connection between edge '793930821' and edge '41965503#1' found.
# Warning: Mandatory edge '41965503#1' not reachable by vehicle 'h00_2578'.
# Warning: The vehicle 'h00_2578' has no valid route.
# Reading up to time step: 1200.12
# Warning: No connection between edge '688357782#0' and edge '53189086#2' found.
# Warning: Mandatory edge '53189086#2' not reachable by vehicle 'h00_4869'.
# Warning: The vehicle 'h00_4869' has no valid route.
# Warning: No connection between edge '82113753#1' and edge '144160557#0' found.
# Warning: Mandatory edge '144160557#0' not reachable by vehicle 'h00_5020'.
# Warning: The vehicle 'h00_5020' has no valid route.
# Reading up to time step: 1400.12
# Warning: No connection between edge '23411141#7' and edge '383076320' found.
# Warning: Mandatory edge '383076320' not reachable by vehicle 'h00_5301'.
# Warning: The vehicle 'h00_5301' has no valid route.
# Warning: No connection between edge '71572268' and edge '767313243' found.
# Warning: Mandatory edge '767313243' not reachable by vehicle 'h00_5700'.
# Warning: The vehicle 'h00_5700' has no valid route.
# Warning: No connection between edge '27769535#1' and edge '188649571' found.
# Warning: Mandatory edge '188649571' not reachable by vehicle 'h00_5988'.
# Warning: The vehicle 'h00_5988' has no valid route.
# Warning: No connection between edge '142239317#3' and edge '378355994#0' found.
# Warning: Mandatory edge '378355994#0' not reachable by vehicle 'h00_6050'.
# Warning: The vehicle 'h00_6050' has no valid route.
# Warning: No connection between edge '39386402#5' and edge '143962123#0' found.
# Warning: Mandatory edge '143962123#0' not reachable by vehicle 'h00_7047'.
# Warning: The vehicle 'h00_7047' has no valid route.
# Reading up to time step: 2200.12
# Warning: No connection between edge '99205761#6' and edge '378355994#0' found.
# Warning: Mandatory edge '378355994#0' not reachable by vehicle 'h00_9221'.
# Warning: The vehicle 'h00_9221' has no valid route.
# Warning: No connection between edge '646975806' and edge '143962123#2' found.
# Warning: Mandatory edge '143962123#2' not reachable by vehicle 'h00_9313'.
# Warning: The vehicle 'h00_9313' has no valid route.
# Warning: No connection between edge '1109637680' and edge '144160557#2' found.
# Warning: Mandatory edge '144160557#2' not reachable by vehicle 'h00_9415'.
# Warning: The vehicle 'h00_9415' has no valid route.
# Reading up to time step: 2400.12
# Warning: No connection between edge '614946280#7' and edge '188649571' found.
# Warning: Mandatory edge '188649571' not reachable by vehicle 'h00_9757'.
# Warning: The vehicle 'h00_9757' has no valid route.
# Warning: No connection between edge '44583876#1' and edge '767313244' found.
# Warning: Mandatory edge '767313244' not reachable by vehicle 'h00_17206'.
# Warning: The vehicle 'h00_17206' has no valid route.
# Reading up to time step: 2600.12
# Warning: No connection between edge '6313524#10' and edge '1060073977' found.
# Warning: Mandatory edge '1060073977' not reachable by vehicle 'h00_10643'.
# Warning: The vehicle 'h00_10643' has no valid route.
# Reading up to time step: 2800.12
# Warning: No connection between edge '235503763#1' and edge '62023741' found.
# Warning: Mandatory edge '62023741' not reachable by vehicle 'h00_11338'.
# Warning: The vehicle 'h00_11338' has no valid route.
# Reading up to time step: 3000.12
# Warning: No connection between edge '130707775#1' and edge '161432888' found.
# Warning: Mandatory edge '161432888' not reachable by vehicle 'h00_12554'.
# Warning: The vehicle 'h00_12554' has no valid route.
# Warning: No connection between edge '113578837#1' and edge '62023730' found.
# Warning: Mandatory edge '62023730' not reachable by vehicle 'h00_12765'.
# Warning: The vehicle 'h00_12765' has no valid route.
# Warning: No connection between edge '201101700#1' and edge '143962123#0' found.
# Warning: Mandatory edge '143962123#0' not reachable by vehicle 'h00_12984'.
# Warning: The vehicle 'h00_12984' has no valid route.
# Warning: No connection between edge '226764826#1' and edge '62023730' found.
# Warning: Mandatory edge '62023730' not reachable by vehicle 'h00_13099'.
# Warning: The vehicle 'h00_13099' has no valid route.
# Reading up to time step: 3200.12
# Warning: No connection between edge '251782958' and edge '510193683' found.
# Warning: Mandatory edge '510193683' not reachable by vehicle 'h00_17264'.
# Warning: The vehicle 'h00_17264' has no valid route.
# Reading up to time step: 3400.12
# Warning: No connection between edge '49326518#1' and edge '1060073977' found.
# Warning: Mandatory edge '1060073977' not reachable by vehicle 'h00_14072'.
# Warning: The vehicle 'h00_14072' has no valid route.
# Warning: No connection between edge '675594354' and edge '62023740' found.
# Warning: Mandatory edge '62023740' not reachable by vehicle 'h00_14161'.
# Warning: The vehicle 'h00_14161' has no valid route.
# Warning: No connection between edge '150925676' and edge '39386402#1' found.
# Warning: Mandatory edge '39386402#1' not reachable by vehicle 'h00_14567'.
# Warning: The vehicle 'h00_14567' has no valid route.
# Warning: No connection between edge '424108223' and edge '112885002#0' found.
# Warning: Mandatory edge '112885002#0' not reachable by vehicle 'h00_14645'.
# Warning: The vehicle 'h00_14645' has no valid route.
# Warning: No connection between edge '144168988#2' and edge '144160557#1' found.
# Warning: Mandatory edge '144160557#1' not reachable by vehicle 'h00_14750'.
# Warning: The vehicle 'h00_14750' has no valid route.
# Reading up to time step: 3600.12
# Warning: No connection between edge '385535528' and edge '383076320' found.
# Warning: Mandatory edge '383076320' not reachable by vehicle 'h00_14765'.
# Warning: The vehicle 'h00_14765' has no valid route.
# Warning: No connection between edge '157678657' and edge '144160557#0' found.
# Warning: Mandatory edge '144160557#0' not reachable by vehicle 'h00_15150'.
# Warning: The vehicle 'h00_15150' has no valid route.
# Warning: No connection between edge '103267981#0' and edge '132342733#0' found.
# Warning: Mandatory edge '132342733#0' not reachable by vehicle 'h00_17038'.
# Warning: The vehicle 'h00_17038' has no valid route.
# Reading up to time step: 4200.12
# Warning: No connection between edge '236977891#0' and edge '1097309369' found.
# Warning: Mandatory edge '1097309369' not reachable by vehicle 'h01_7684'.
# Warning: The vehicle 'h01_7684' has no valid route.
# Reading up to time step: 4400.12
# Warning: No connection between edge '53331493#3' and edge '161432888' found.
# Warning: Mandatory edge '161432888' not reachable by vehicle 'h01_1396'.
# Warning: The vehicle 'h01_1396' has no valid route.
# Reading up to time step: 4600.12
# Warning: No connection between edge '561020798#2' and edge '143962123#0' found.
# Warning: Mandatory edge '143962123#0' not reachable by vehicle 'h01_1739'.
# Warning: The vehicle 'h01_1739' has no valid route.
# Reading up to time step: 4800.12
# Warning: No connection between edge '620942875#2' and edge '144160557#1' found.
# Warning: Mandatory edge '144160557#1' not reachable by vehicle 'h01_2269'.
# Warning: The vehicle 'h01_2269' has no valid route.
# Warning: No connection between edge '793930821' and edge '66833284#4' found.
# Warning: Mandatory edge '66833284#4' not reachable by vehicle 'h01_2324'.
# Warning: The vehicle 'h01_2324' has no valid route.
# Reading up to time step: 5000.12
# Warning: No connection between edge '46999933#7' and edge '62023728#1' found.
# Warning: Mandatory edge '62023728#1' not reachable by vehicle 'h01_2785'.
# Warning: The vehicle 'h01_2785' has no valid route.
# Reading up to time step: 5200.12
# Warning: No connection between edge '124060635' and edge '67209276#1' found.
# Warning: Mandatory edge '67209276#1' not reachable by vehicle 'h01_3199'.
# Warning: The vehicle 'h01_3199' has no valid route.
# Reading up to time step: 5400.12
# Warning: No connection between edge '53188868#0' and edge '62023741' found.
# Warning: Mandatory edge '62023741' not reachable by vehicle 'h01_3440'.
# Warning: The vehicle 'h01_3440' has no valid route.
# Warning: No connection between edge '966771866#1' and edge '367820007' found.
# Warning: Mandatory edge '367820007' not reachable by vehicle 'h01_3629'.
# Warning: The vehicle 'h01_3629' has no valid route.
# Reading up to time step: 5600.12
# Warning: No connection between edge '165280726#5' and edge '62023740' found.
# Warning: Mandatory edge '62023740' not reachable by vehicle 'h01_3831'.
# Warning: The vehicle 'h01_3831' has no valid route.
# Reading up to time step: 5800.12
# Warning: No connection between edge '508177178' and edge '378355994#2' found.
# Warning: Mandatory edge '378355994#2' not reachable by vehicle 'h01_4179'.
# Warning: The vehicle 'h01_4179' has no valid route.
# Warning: No connection between edge '71896855' and edge '143962123#2' found.
# Warning: Mandatory edge '143962123#2' not reachable by vehicle 'h01_4270'.
# Warning: The vehicle 'h01_4270' has no valid route.
# Reading up to time step: 6000.12
# Warning: No connection between edge '793930821' and edge '187069050#8' found.
# Warning: Mandatory edge '187069050#8' not reachable by vehicle 'h01_4900'.
# Warning: The vehicle 'h01_4900' has no valid route.
# Warning: No connection between edge '142418779' and edge '144160557#1' found.
# Warning: Mandatory edge '144160557#1' not reachable by vehicle 'h01_4924'.
# Warning: The vehicle 'h01_4924' has no valid route.
# Reading up to time step: 6200.12
# Warning: No connection between edge '881884802#1' and edge '144160557#0' found.
# Warning: Mandatory edge '144160557#0' not reachable by vehicle 'h01_5233'.
# Warning: The vehicle 'h01_5233' has no valid route.
# Reading up to time step: 6400.12
# Warning: No connection between edge '70186692#2' and edge '143962123#2' found.
# Warning: Mandatory edge '143962123#2' not reachable by vehicle 'h01_5441'.
# Warning: The vehicle 'h01_5441' has no valid route.
# Reading up to time step: 6600.12
# Warning: No connection between edge '429244751#1' and edge '510193683' found.
# Warning: Mandatory edge '510193683' not reachable by vehicle 'h01_5992'.
# Warning: The vehicle 'h01_5992' has no valid route.
# Reading up to time step: 6800.12
# Warning: No connection between edge '620942875#2' and edge '1060073977' found.
# Warning: Mandatory edge '1060073977' not reachable by vehicle 'h01_6409'.
# Warning: The vehicle 'h01_6409' has no valid route.
# Reading up to time step: 7000.12
# Warning: No connection between edge '197535615#0' and edge '281308645' found.
# Warning: Mandatory edge '281308645' not reachable by vehicle 'h01_6849'.
# Warning: The vehicle 'h01_6849' has no valid route.
# Reading up to time step: 7200.12
# Warning: No connection between edge '463657004#1' and edge '367820007' found.
# Warning: Mandatory edge '367820007' not reachable by vehicle 'h01_7179'.
# Warning: The vehicle 'h01_7179' has no valid route.
# Reading up to time step: 7400.12
# Warning: No connection between edge '71896672#1' and edge '378355994#0' found.
# Warning: Mandatory edge '378355994#0' not reachable by vehicle 'h02_108'.
# Warning: The vehicle 'h02_108' has no valid route.
# Reading up to time step: 7600.12
# Warning: No connection between edge '35032294' and edge '510193680' found.
# Warning: Mandatory edge '510193680' not reachable by vehicle 'h02_301'.
# Warning: The vehicle 'h02_301' has no valid route.
# Reading up to time step: 8000.12
# Warning: No connection between edge '508513586' and edge '510193683' found.
# Warning: Mandatory edge '510193683' not reachable by vehicle 'h02_611'.
# Warning: The vehicle 'h02_611' has no valid route.
# Reading up to time step: 8400.12
# Warning: No connection between edge '688357782#1' and edge '112732694' found.
# Warning: Mandatory edge '112732694' not reachable by vehicle 'h02_873'.
# Warning: The vehicle 'h02_873' has no valid route.
# Reading up to time step: 9400.12
# Warning: No connection between edge '528739668' and edge '510193683' found.
# Warning: Mandatory edge '510193683' not reachable by vehicle 'h02_1766'.
# Warning: The vehicle 'h02_1766' has no valid route.
# Reading up to time step: 9600.12
# Warning: No connection between edge '82287657#0' and edge '62023740' found.
# Warning: Mandatory edge '62023740' not reachable by vehicle 'h02_1865'.
# Warning: The vehicle 'h02_1865' has no valid route.
# Reading up to time step: 10600.12
# Warning: No connection between edge '688357782#0' and edge '426446342#3' found.
# Warning: Mandatory edge '426446342#3' not reachable by vehicle 'h02_2696'.
# Warning: The vehicle 'h02_2696' has no valid route.
# Reading up to time step: 10800.12
# Warning: No connection between edge '793930821' and edge '53839242#1' found.
# Warning: Mandatory edge '53839242#1' not reachable by vehicle 'h02_2922'.
# Warning: The vehicle 'h02_2922' has no valid route.
# Warning: No connection between edge '160967885' and edge '62023728#1' found.
# Warning: Mandatory edge '62023728#1' not reachable by vehicle 'h03_51'.
# Warning: The vehicle 'h03_51' has no valid route.
# Reading up to time step: 13000.12
# Warning: No connection between edge '120057512' and edge '367820007' found.
# Warning: Mandatory edge '367820007' not reachable by vehicle 'h03_264'.
# Warning: The vehicle 'h03_264' has no valid route.
# Warning: No connection between edge '160967885' and edge '62023728#1' found.
# Warning: Mandatory edge '62023728#1' not reachable by vehicle 'h04_51'.
# Warning: The vehicle 'h04_51' has no valid route.
# Reading up to time step: 14800.12
# Warning: No connection between edge '120057512' and edge '367820007' found.
# Warning: Mandatory edge '367820007' not reachable by vehicle 'h04_264'.
# Warning: The vehicle 'h04_264' has no valid route.
# Reading up to time step: 18400.12
# Warning: No connection between edge '53210120#0' and edge '383076320' found.
# Warning: Mandatory edge '383076320' not reachable by vehicle 'h05_656'.
# Warning: The vehicle 'h05_656' has no valid route.
# Warning: No connection between edge '124060635' and edge '141678548' found.
# Warning: Mandatory edge '141678548' not reachable by vehicle 'h05_694'.
# Warning: The vehicle 'h05_694' has no valid route.
# Reading up to time step: 18600.12
# Warning: No connection between edge '181988681#0' and edge '378355994#0' found.
# Warning: Mandatory edge '378355994#0' not reachable by vehicle 'h05_1211'.
# Warning: The vehicle 'h05_1211' has no valid route.
# Reading up to time step: 19200.12
# Warning: No connection between edge '428543000' and edge '62023728#1' found.
# Warning: Mandatory edge '62023728#1' not reachable by vehicle 'h05_2479'.
# Warning: The vehicle 'h05_2479' has no valid route.
# Reading up to time step: 19600.12
# Warning: No connection between edge '520816676' and edge '188649571' found.
# Warning: Mandatory edge '188649571' not reachable by vehicle 'h05_3144'.
# Warning: The vehicle 'h05_3144' has no valid route.
# Warning: No connection between edge '694436947' and edge '367820007' found.
# Warning: Mandatory edge '367820007' not reachable by vehicle 'h05_3167'.
# Warning: The vehicle 'h05_3167' has no valid route.
# Warning: No connection between edge '688357782#1' and edge '561020798#2' found.
# Warning: Mandatory edge '561020798#2' not reachable by vehicle 'h05_3200'.
# Warning: The vehicle 'h05_3200' has no valid route.
# Warning: No connection between edge '1031460026' and edge '367820007' found.
# Warning: Mandatory edge '367820007' not reachable by vehicle 'h05_3247'.
# Warning: The vehicle 'h05_3247' has no valid route.
# Reading up to time step: 19800.12
# Warning: No connection between edge '425702645#1' and edge '767313244' found.
# Warning: Mandatory edge '767313244' not reachable by vehicle 'h05_3750'.
# Warning: The vehicle 'h05_3750' has no valid route.
# Warning: No connection between edge '793930821' and edge '144632800' found.
# Warning: Mandatory edge '144632800' not reachable by vehicle 'h05_3775'.
# Warning: The vehicle 'h05_3775' has no valid route.
# Warning: No connection between edge '120673709#1' and edge '161432888' found.
# Warning: Mandatory edge '161432888' not reachable by vehicle 'h05_4455'.
# Warning: The vehicle 'h05_4455' has no valid route.
# Reading up to time step: 20200.12
# Warning: No connection between edge '178296586#0' and edge '143962123#2' found.
# Warning: Mandatory edge '143962123#2' not reachable by vehicle 'h05_4471'.
# Warning: The vehicle 'h05_4471' has no valid route.
# Warning: No connection between edge '40932555#1' and edge '367820007' found.
# Warning: Mandatory edge '367820007' not reachable by vehicle 'h05_4747'.
# Warning: The vehicle 'h05_4747' has no valid route.
# Reading up to time step: 20800.12
# Warning: No connection between edge '194679027#1' and edge '188649571' found.
# Warning: Mandatory edge '188649571' not reachable by vehicle 'h05_5805'.
# Warning: The vehicle 'h05_5805' has no valid route.
# Warning: No connection between edge '54965913' and edge '62023740' found.
# Warning: Mandatory edge '62023740' not reachable by vehicle 'h05_5888'.
# Warning: The vehicle 'h05_5888' has no valid route.
# Reading up to time step: 21200.12
# Warning: No connection between edge '71587999' and edge '378355994#0' found.
# Warning: Mandatory edge '378355994#0' not reachable by vehicle 'h05_6644'.
# Warning: The vehicle 'h05_6644' has no valid route.
# Reading up to time step: 21400.12
# Warning: No connection between edge '47001231#2' and edge '510193683' found.
# Warning: Mandatory edge '510193683' not reachable by vehicle 'h05_6975'.
# Warning: The vehicle 'h05_6975' has no valid route.
# Reading up to time step: 21600.12
# Warning: No connection between edge '853758817' and edge '144160557#2' found.
# Warning: Mandatory edge '144160557#2' not reachable by vehicle 'h05_7399'.
# Warning: The vehicle 'h05_7399' has no valid route.
# Warning: No connection between edge '53253218#0' and edge '161432888' found.
# Warning: Mandatory edge '161432888' not reachable by vehicle 'h05_7481'.
# Warning: The vehicle 'h05_7481' has no valid route.
# Warning: No connection between edge '291200406#0' and edge '767313244' found.
# Warning: Mandatory edge '767313244' not reachable by vehicle 'h05_8843'.
# Warning: The vehicle 'h05_8843' has no valid route.
# Warning: No connection between edge '377991076#14' and edge '378355994#1' found.
# Warning: Mandatory edge '378355994#1' not reachable by vehicle 'h05_7546'.
# Warning: The vehicle 'h05_7546' has no valid route.
# Reading up to time step: 21800.12
# Warning: No connection between edge '688357782#1' and edge '323979328' found.
# Warning: Mandatory edge '323979328' not reachable by vehicle 'h06_1287'.
# Warning: The vehicle 'h06_1287' has no valid route.
# Warning: No connection between edge '796526003#1' and edge '143962123#2' found.
# Warning: Mandatory edge '143962123#2' not reachable by vehicle 'h06_26637'.
# Warning: The vehicle 'h06_26637' has no valid route.
# Reading up to time step: 22000.12
# Warning: No connection between edge '24930703#0' and edge '367820004' found.
# Warning: Mandatory edge '367820004' not reachable by vehicle 'h06_2272'.
# Warning: The vehicle 'h06_2272' has no valid route.
# Warning: No connection between edge '34934785#2' and edge '383076320' found.
# Warning: Mandatory edge '383076320' not reachable by vehicle 'h06_2415'.
# Warning: The vehicle 'h06_2415' has no valid route.
# Warning: No connection between edge '793930821' and edge '36918729' found.
# Warning: Mandatory edge '36918729' not reachable by vehicle 'h06_2639'.
# Warning: The vehicle 'h06_2639' has no valid route.
# Reading up to time step: 22200.12
# Warning: No connection between edge '185992843' and edge '767313244' found.
# Warning: Mandatory edge '767313244' not reachable by vehicle 'h06_3081'.
# Warning: The vehicle 'h06_3081' has no valid route.
# Warning: No connection between edge '6314124' and edge '386307421#0' found.
# Warning: Mandatory edge '386307421#0' not reachable by vehicle 'h06_3544'.
# Warning: The vehicle 'h06_3544' has no valid route.
# Warning: No connection between edge '436967671' and edge '143962123#2' found.
# Warning: Mandatory edge '143962123#2' not reachable by vehicle 'h06_3773'.
# Warning: The vehicle 'h06_3773' has no valid route.
# Reading up to time step: 22400.12
# Warning: No connection between edge '253388242' and edge '767313244' found.
# Warning: Mandatory edge '767313244' not reachable by vehicle 'h06_4068'.
# Warning: The vehicle 'h06_4068' has no valid route.
# Warning: No connection between edge '150925676' and edge '71440136#0' found.
# Warning: Mandatory edge '71440136#0' not reachable by vehicle 'h06_4195'.
# Warning: The vehicle 'h06_4195' has no valid route.
# Warning: No connection between edge '345730923' and edge '161432888' found.
# Warning: Mandatory edge '161432888' not reachable by vehicle 'h06_4706'.
# Warning: The vehicle 'h06_4706' has no valid route.
# Reading up to time step: 22600.12
# Warning: No connection between edge '81059139' and edge '188649571' found.
# Warning: Mandatory edge '188649571' not reachable by vehicle 'h06_5909'.
# Warning: The vehicle 'h06_5909' has no valid route.
# Warning: No connection between edge '124060635' and edge '161572538' found.
# Warning: Mandatory edge '161572538' not reachable by vehicle 'h06_6427'.
# Warning: The vehicle 'h06_6427' has no valid route.
# Warning: No connection between edge '53189149#0' and edge '386307421#0' found.
# Warning: Mandatory edge '386307421#0' not reachable by vehicle 'h06_6778'.
# Warning: The vehicle 'h06_6778' has no valid route.
# Reading up to time step: 22800.12
# Warning: No connection between edge '1032383516' and edge '144160557#1' found.
# Warning: Mandatory edge '144160557#1' not reachable by vehicle 'h06_6860'.
# Warning: The vehicle 'h06_6860' has no valid route.
# Warning: No connection between edge '28071825' and edge '386307421#1' found.
# Warning: Mandatory edge '386307421#1' not reachable by vehicle 'h06_7699'.
# Warning: The vehicle 'h06_7699' has no valid route.
# Reading up to time step: 23200.12
# Warning: No connection between edge '675769858' and edge '143962123#2' found.
# Warning: Mandatory edge '143962123#2' not reachable by vehicle 'h06_9675'.
# Warning: The vehicle 'h06_9675' has no valid route.
# Warning: No connection between edge '112732676#0' and edge '378355994#0' found.
# Warning: Mandatory edge '378355994#0' not reachable by vehicle 'h06_9818'.
# Warning: The vehicle 'h06_9818' has no valid route.
# Warning: No connection between edge '560365540#1' and edge '143962123#1' found.
# Warning: Mandatory edge '143962123#1' not reachable by vehicle 'h06_10009'.
# Warning: The vehicle 'h06_10009' has no valid route.
# Warning: No connection between edge '112732680#3' and edge '767313243' found.
# Warning: Mandatory edge '767313243' not reachable by vehicle 'h06_10307'.
# Warning: The vehicle 'h06_10307' has no valid route.
# Reading up to time step: 23400.12
# Warning: No connection between edge '43795813#0' and edge '144160557#1' found.
# Warning: Mandatory edge '144160557#1' not reachable by vehicle 'h06_26226'.
# Warning: The vehicle 'h06_26226' has no valid route.
# Warning: No connection between edge '71572300#3' and edge '510193680' found.
# Warning: Mandatory edge '510193680' not reachable by vehicle 'h06_11741'.
# Warning: The vehicle 'h06_11741' has no valid route.
# Warning: No connection between edge '425064096' and edge '378355994#2' found.
# Warning: Mandatory edge '378355994#2' not reachable by vehicle 'h06_11926'.
# Warning: The vehicle 'h06_11926' has no valid route.
# Warning: No connection between edge '386784038' and edge '378355994#1' found.
# Warning: Mandatory edge '378355994#1' not reachable by vehicle 'h06_11990'.
# Warning: The vehicle 'h06_11990' has no valid route.
# Reading up to time step: 23600.12
# Warning: No connection between edge '925261618' and edge '689189972' found.
# Warning: Mandatory edge '689189972' not reachable by vehicle 'h06_13008'.
# Warning: The vehicle 'h06_13008' has no valid route.
# Reading up to time step: 23800.12
# Warning: No connection between edge '624358274' and edge '386307421#1' found.
# Warning: Mandatory edge '386307421#1' not reachable by vehicle 'h06_13737'.
# Warning: The vehicle 'h06_13737' has no valid route.
# Warning: No connection between edge '96719561#1' and edge '367820007' found.
# Warning: Mandatory edge '367820007' not reachable by vehicle 'h06_13828'.
# Warning: The vehicle 'h06_13828' has no valid route.
# Warning: No connection between edge '764046730#0' and edge '144160557#1' found.
# Warning: Mandatory edge '144160557#1' not reachable by vehicle 'h06_14251'.
# Warning: The vehicle 'h06_14251' has no valid route.
# Warning: No connection between edge '521547945#4' and edge '62023730' found.
# Warning: Mandatory edge '62023730' not reachable by vehicle 'h06_14400'.
# Warning: The vehicle 'h06_14400' has no valid route.
# Warning: No connection between edge '115668973' and edge '378355994#0' found.
# Warning: Mandatory edge '378355994#0' not reachable by vehicle 'h06_14499'.
# Warning: The vehicle 'h06_14499' has no valid route.
# Warning: No connection between edge '191736660#1' and edge '62023728#1' found.
# Warning: Mandatory edge '62023728#1' not reachable by vehicle 'h06_14562'.
# Warning: The vehicle 'h06_14562' has no valid route.
# Warning: No connection between edge '401956792' and edge '383076320' found.
# Warning: Mandatory edge '383076320' not reachable by vehicle 'h06_14590'.
# Warning: The vehicle 'h06_14590' has no valid route.
# Reading up to time step: 24000.12
# Warning: No connection between edge '156862603#8' and edge '143962123#2' found.
# Warning: Mandatory edge '143962123#2' not reachable by vehicle 'h06_14863'.
# Warning: The vehicle 'h06_14863' has no valid route.
# Warning: No connection between edge '200439548#2' and edge '281308645' found.
# Warning: Mandatory edge '281308645' not reachable by vehicle 'h06_26574'.
# Warning: The vehicle 'h06_26574' has no valid route.
# Reading up to time step: 24200.12
# Warning: No connection between edge '524960203#1' and edge '144160557#2' found.
# Warning: Mandatory edge '144160557#2' not reachable by vehicle 'h06_16805'.
# Warning: The vehicle 'h06_16805' has no valid route.
# Warning: No connection between edge '565542700' and edge '62023740' found.
# Warning: Mandatory edge '62023740' not reachable by vehicle 'h06_16942'.
# Warning: The vehicle 'h06_16942' has no valid route.
# Warning: No connection between edge '925261618' and edge '684350388' found.
# Warning: Mandatory edge '684350388' not reachable by vehicle 'h06_17169'.
# Warning: The vehicle 'h06_17169' has no valid route.
# Warning: No connection between edge '48500941' and edge '161432888' found.
# Warning: Mandatory edge '161432888' not reachable by vehicle 'h06_27194'.
# Warning: The vehicle 'h06_27194' has no valid route.
# Reading up to time step: 24400.12
# Warning: No connection between edge '24374348#0' and edge '510193683' found.
# Warning: Mandatory edge '510193683' not reachable by vehicle 'h06_17507'.
# Warning: The vehicle 'h06_17507' has no valid route.
# Warning: No connection between edge '150925676' and edge '157046112#2' found.
# Warning: Mandatory edge '157046112#2' not reachable by vehicle 'h06_17523'.
# Warning: The vehicle 'h06_17523' has no valid route.
# Warning: No connection between edge '124060635' and edge '375231327' found.
# Warning: Mandatory edge '375231327' not reachable by vehicle 'h06_18015'.
# Warning: The vehicle 'h06_18015' has no valid route.
# Warning: No connection between edge '68303299' and edge '378355994#1' found.
# Warning: Mandatory edge '378355994#1' not reachable by vehicle 'h06_25933'.
# Warning: The vehicle 'h06_25933' has no valid route.
# Reading up to time step: 24600.12
# Warning: No connection between edge '81825423' and edge '62023730' found.
# Warning: Mandatory edge '62023730' not reachable by vehicle 'h06_19570'.
# Warning: The vehicle 'h06_19570' has no valid route.
# Reading up to time step: 24800.12
# Warning: No connection between edge '142420387#0' and edge '112885002#1' found.
# Warning: Mandatory edge '112885002#1' not reachable by vehicle 'h06_20595'.
# Warning: The vehicle 'h06_20595' has no valid route.
# Warning: No connection between edge '120053749#2' and edge '143962123#2' found.
# Warning: Mandatory edge '143962123#2' not reachable by vehicle 'h06_21016'.
# Warning: The vehicle 'h06_21016' has no valid route.
# Reading up to time step: 25000.12
# Warning: No connection between edge '330775260#0' and edge '1060073977' found.
# Warning: Mandatory edge '1060073977' not reachable by vehicle 'h06_21241'.
# Warning: The vehicle 'h06_21241' has no valid route.
# Warning: No connection between edge '688357782#1' and edge '169984982#2' found.
# Warning: Mandatory edge '169984982#2' not reachable by vehicle 'h06_21252'.
# Warning: The vehicle 'h06_21252' has no valid route.
# Warning: No connection between edge '753629980' and edge '144160557#0' found.
# Warning: Mandatory edge '144160557#0' not reachable by vehicle 'h06_27224'.
# Warning: The vehicle 'h06_27224' has no valid route.
# Warning: No connection between edge '1082045572#1' and edge '143962120' found.
# Warning: Mandatory edge '143962120' not reachable by vehicle 'h06_27038'.
# Warning: The vehicle 'h06_27038' has no valid route.
# Warning: No connection between edge '40943833' and edge '144160557#1' found.
# Warning: Mandatory edge '144160557#1' not reachable by vehicle 'h06_22532'.
# Warning: The vehicle 'h06_22532' has no valid route.
# Warning: No connection between edge '97294546#0' and edge '767313243' found.
# Warning: Mandatory edge '767313243' not reachable by vehicle 'h06_22781'.
# Warning: The vehicle 'h06_22781' has no valid route.
# Reading up to time step: 25200.12
# Warning: No connection between edge '723767662#1' and edge '143962123#0' found.
# Warning: Mandatory edge '143962123#0' not reachable by vehicle 'h06_22863'.
# Warning: The vehicle 'h06_22863' has no valid route.
# Warning: No connection between edge '330773989' and edge '378355994#0' found.
# Warning: Mandatory edge '378355994#0' not reachable by vehicle 'h06_23434'.
# Warning: The vehicle 'h06_23434' has no valid route.
# Warning: No connection between edge '889237648#1' and edge '367820007' found.
# Warning: Mandatory edge '367820007' not reachable by vehicle 'h06_23510'.
# Warning: The vehicle 'h06_23510' has no valid route.
# Warning: No connection between edge '303225593#0' and edge '53791743#0' found.
# Warning: Mandatory edge '53791743#0' not reachable by vehicle 'h06_26036'.
# Warning: The vehicle 'h06_26036' has no valid route.
# Reading up to time step: 25400.12
# Warning: No connection between edge '366469489#6' and edge '510193680' found.
# Warning: Mandatory edge '510193680' not reachable by vehicle 'h07_821'.
# Warning: The vehicle 'h07_821' has no valid route.
# Warning: No connection between edge '34245082#1' and edge '62023728#0' found.
# Warning: Mandatory edge '62023728#0' not reachable by vehicle 'h07_923'.
# Warning: The vehicle 'h07_923' has no valid route.
# Warning: No connection between edge '399059309#1' and edge '144160557#1' found.
# Warning: Mandatory edge '144160557#1' not reachable by vehicle 'h07_1051'.
# Warning: The vehicle 'h07_1051' has no valid route.
# Warning: No connection between edge '534277849' and edge '62023741' found.
# Warning: Mandatory edge '62023741' not reachable by vehicle 'h07_1484'.
# Warning: The vehicle 'h07_1484' has no valid route.
# Warning: No connection between edge '71572288' and edge '367820004' found.
# Warning: Mandatory edge '367820004' not reachable by vehicle 'h07_1498'.
# Warning: The vehicle 'h07_1498' has no valid route.
# Warning: No connection between edge '71572303#3' and edge '383076320' found.
# Warning: Mandatory edge '383076320' not reachable by vehicle 'h07_1895'.
# Warning: The vehicle 'h07_1895' has no valid route.
# Warning: No connection between edge '388890728#2' and edge '378355994#1' found.
# Warning: Mandatory edge '378355994#1' not reachable by vehicle 'h07_2768'.
# Warning: The vehicle 'h07_2768' has no valid route.
# Warning: No connection between edge '1116553451#4' and edge '386307421#0' found.
# Warning: Mandatory edge '386307421#0' not reachable by vehicle 'h07_3004'.
# Warning: The vehicle 'h07_3004' has no valid route.
# Warning: No connection between edge '456191616#1' and edge '144160557#1' found.
# Warning: Mandatory edge '144160557#1' not reachable by vehicle 'h07_3109'.
# Warning: The vehicle 'h07_3109' has no valid route.
# Warning: No connection between edge '925261618' and edge '323991799' found.
# Warning: Mandatory edge '323991799' not reachable by vehicle 'h07_3544'.
# Warning: The vehicle 'h07_3544' has no valid route.
# Warning: No connection between edge '37794973#5' and edge '112885002#0' found.
# Warning: Mandatory edge '112885002#0' not reachable by vehicle 'h07_3923'.
# Warning: The vehicle 'h07_3923' has no valid route.
# Warning: No connection between edge '693196076#0' and edge '378355994#0' found.
# Warning: Mandatory edge '378355994#0' not reachable by vehicle 'h07_4886'.
# Warning: The vehicle 'h07_4886' has no valid route.
# Warning: No connection between edge '200682986' and edge '144160557#0' found.
# Warning: Mandatory edge '144160557#0' not reachable by vehicle 'h07_107338'.
# Warning: The vehicle 'h07_107338' has no valid route.
# Reading up to time step: 25600.12
# Warning: No connection between edge '210412779' and edge '236123650#1' found.
# Warning: Mandatory edge '236123650#1' not reachable by vehicle 'h07_105039'.
# Warning: The vehicle 'h07_105039' has no valid route.
# Warning: No connection between edge '688357782#0' and edge '1175823314' found.
# Warning: Mandatory edge '1175823314' not reachable by vehicle 'h07_5915'.
# Warning: The vehicle 'h07_5915' has no valid route.
# Warning: No connection between edge '6310515#1' and edge '161432888' found.
# Warning: Mandatory edge '161432888' not reachable by vehicle 'h07_5936'.
# Warning: The vehicle 'h07_5936' has no valid route.
# Warning: No connection between edge '675322050' and edge '378355994#0' found.
# Warning: Mandatory edge '378355994#0' not reachable by vehicle 'h07_6045'.
# Warning: The vehicle 'h07_6045' has no valid route.
# Warning: No connection between edge '303225593#0' and edge '926826893' found.
# Warning: Mandatory edge '926826893' not reachable by vehicle 'h07_101367'.
# Warning: The vehicle 'h07_101367' has no valid route.
# Warning: No connection between edge '141815671#2' and edge '144160557#1' found.
# Warning: Mandatory edge '144160557#1' not reachable by vehicle 'h07_7770'.
# Warning: The vehicle 'h07_7770' has no valid route.
# Warning: No connection between edge '150925676' and edge '143299683#0' found.
# Warning: Mandatory edge '143299683#0' not reachable by vehicle 'h07_7781'.
# Warning: The vehicle 'h07_7781' has no valid route.
# Warning: No connection between edge '105258166' and edge '969310182' found.
# Warning: Mandatory edge '969310182' not reachable by vehicle 'h07_105049'.
# Warning: The vehicle 'h07_105049' has no valid route.
# Warning: No connection between edge '125483124#1' and edge '510193683' found.
# Warning: Mandatory edge '510193683' not reachable by vehicle 'h07_7928'.
# Warning: The vehicle 'h07_7928' has no valid route.
# Warning: No connection between edge '954004232#0' and edge '767313244' found.
# Warning: Mandatory edge '767313244' not reachable by vehicle 'h07_8363'.
# Warning: The vehicle 'h07_8363' has no valid route.
# Warning: No connection between edge '675851215' and edge '1097309372' found.
# Warning: Mandatory edge '1097309372' not reachable by vehicle 'h07_96712'.
# Warning: The vehicle 'h07_96712' has no valid route.
# Warning: No connection between edge '141678548' and edge '143962123#1' found.
# Warning: Mandatory edge '143962123#1' not reachable by vehicle 'h07_8928'.
# Warning: The vehicle 'h07_8928' has no valid route.
# Warning: No connection between edge '170168295' and edge '112885002#1' found.
# Warning: Mandatory edge '112885002#1' not reachable by vehicle 'h07_9627'.
# Warning: The vehicle 'h07_9627' has no valid route.
# Warning: No connection between edge '109153257' and edge '367820007' found.
# Warning: Mandatory edge '367820007' not reachable by vehicle 'h07_9636'.
# Warning: The vehicle 'h07_9636' has no valid route.
# Warning: No connection between edge '688357782#1' and edge '6314181' found.
# Warning: Mandatory edge '6314181' not reachable by vehicle 'h07_10470'.
# Warning: The vehicle 'h07_10470' has no valid route.
# Reading up to time step: 25800.12
# Warning: No connection between edge '64738689' and edge '62023730' found.
# Warning: Mandatory edge '62023730' not reachable by vehicle 'h07_11311'.
# Warning: The vehicle 'h07_11311' has no valid route.
# Warning: No connection between edge '40941613' and edge '367820007' found.
# Warning: Mandatory edge '367820007' not reachable by vehicle 'h07_11372'.
# Warning: The vehicle 'h07_11372' has no valid route.
# Warning: No connection between edge '121131434#0' and edge '62023740' found.
# Warning: Mandatory edge '62023740' not reachable by vehicle 'h07_11393'.
# Warning: The vehicle 'h07_11393' has no valid route.
# Warning: No connection between edge '64502817#1' and edge '281308645' found.
# Warning: Mandatory edge '281308645' not reachable by vehicle 'h07_11507'.
# Warning: The vehicle 'h07_11507' has no valid route.
# Warning: No connection between edge '793930821' and edge '383076314#0' found.
# Warning: Mandatory edge '383076314#0' not reachable by vehicle 'h07_11898'.
# Warning: The vehicle 'h07_11898' has no valid route.
# Warning: No connection between edge '171948947#0' and edge '767313243' found.
# Warning: Mandatory edge '767313243' not reachable by vehicle 'h07_12253'.
# Warning: The vehicle 'h07_12253' has no valid route.
# Warning: No connection between edge '173216620' and edge '112885002#1' found.
# Warning: Mandatory edge '112885002#1' not reachable by vehicle 'h07_101496'.
# Warning: The vehicle 'h07_101496' has no valid route.
# Warning: No connection between edge '330637562' and edge '144160557#1' found.
# Warning: Mandatory edge '144160557#1' not reachable by vehicle 'h07_14097'.
# Warning: The vehicle 'h07_14097' has no valid route.
# Warning: No connection between edge '59826889#0' and edge '510193683' found.
# Warning: Mandatory edge '510193683' not reachable by vehicle 'h07_14982'.
# Warning: The vehicle 'h07_14982' has no valid route.
# Reading up to time step: 26000.12
# Warning: No connection between edge '428493586#0' and edge '143962120' found.
# Warning: Mandatory edge '143962120' not reachable by vehicle 'h07_15913'.
# Warning: The vehicle 'h07_15913' has no valid route.
# Warning: No connection between edge '568743825' and edge '34245082#2' found.
# Warning: Mandatory edge '34245082#2' not reachable by vehicle 'h07_101563'.
# Warning: The vehicle 'h07_101563' has no valid route.
# Warning: No connection between edge '41455207#0' and edge '510193680' found.
# Warning: Mandatory edge '510193680' not reachable by vehicle 'h07_17472'.
# Warning: The vehicle 'h07_17472' has no valid route.
# Warning: No connection between edge '40932269' and edge '510193680' found.
# Warning: Mandatory edge '510193680' not reachable by vehicle 'h07_19215'.
# Warning: The vehicle 'h07_19215' has no valid route.
# Warning: No connection between edge '161386578#1' and edge '143962123#2' found.
# Warning: Mandatory edge '143962123#2' not reachable by vehicle 'h07_19698'.
# Warning: The vehicle 'h07_19698' has no valid route.
# Warning: No connection between edge '146785368' and edge '62023728#1' found.
# Warning: Mandatory edge '62023728#1' not reachable by vehicle 'h07_105841'.
# Warning: The vehicle 'h07_105841' has no valid route.
# Warning: No connection between edge '890168663' and edge '62023741' found.
# Warning: Mandatory edge '62023741' not reachable by vehicle 'h07_20317'.
# Warning: The vehicle 'h07_20317' has no valid route.
# Warning: No connection between edge '400363759' and edge '210551368' found.
# Warning: Mandatory edge '210551368' not reachable by vehicle 'h07_100734'.
# Warning: The vehicle 'h07_100734' has no valid route.
# Warning: No connection between edge '377991076#5' and edge '281308645' found.
# Warning: Mandatory edge '281308645' not reachable by vehicle 'h07_20930'.
# Warning: The vehicle 'h07_20930' has no valid route.
# Reading up to time step: 26200.12
# Warning: No connection between edge '925261618' and edge '53788973#2' found.
# Warning: Mandatory edge '53788973#2' not reachable by vehicle 'h07_21060'.
# Warning: The vehicle 'h07_21060' has no valid route.
# Warning: No connection between edge '427102503#2' and edge '367820007' found.
# Warning: Mandatory edge '367820007' not reachable by vehicle 'h07_21066'.
# Warning: The vehicle 'h07_21066' has no valid route.
# Warning: No connection between edge '561004584' and edge '378355994#0' found.
# Warning: Mandatory edge '378355994#0' not reachable by vehicle 'h07_21658'.
# Warning: The vehicle 'h07_21658' has no valid route.
# Warning: No connection between edge '206743295#1' and edge '55262562' found.
# Warning: Mandatory edge '55262562' not reachable by vehicle 'h07_98461'.
# Warning: The vehicle 'h07_98461' has no valid route.
# Warning: No connection between edge '925261618' and edge '158529806#2' found.
# Warning: Mandatory edge '158529806#2' not reachable by vehicle 'h07_22158'.
# Warning: The vehicle 'h07_22158' has no valid route.
# Warning: No connection between edge '430026087#2' and edge '1155222630' found.
# Warning: Mandatory edge '1155222630' not reachable by vehicle 'h07_96941'.
# Warning: The vehicle 'h07_96941' has no valid route.
# Warning: No connection between edge '53188864#3' and edge '143962123#0' found.
# Warning: Mandatory edge '143962123#0' not reachable by vehicle 'h07_22768'.
# Warning: The vehicle 'h07_22768' has no valid route.
# Warning: No connection between edge '131904969#1' and edge '143962123#2' found.
# Warning: Mandatory edge '143962123#2' not reachable by vehicle 'h07_22774'.
# Warning: The vehicle 'h07_22774' has no valid route.
# Warning: No connection between edge '356962708#1' and edge '62023741' found.
# Warning: Mandatory edge '62023741' not reachable by vehicle 'h07_23061'.
# Warning: The vehicle 'h07_23061' has no valid route.
# Warning: No connection between edge '925261618' and edge '141815670#0' found.
# Warning: Mandatory edge '141815670#0' not reachable by vehicle 'h07_23152'.
# Warning: The vehicle 'h07_23152' has no valid route.
# Warning: No connection between edge '167692609' and edge '143962120' found.
# Warning: Mandatory edge '143962120' not reachable by vehicle 'h07_23478'.
# Warning: The vehicle 'h07_23478' has no valid route.
# Warning: No connection between edge '137342753' and edge '238088161' found.
# Warning: Mandatory edge '238088161' not reachable by vehicle 'h07_105121'.
# Warning: The vehicle 'h07_105121' has no valid route.
# Warning: No connection between edge '166652902#0' and edge '143962123#0' found.
# Warning: Mandatory edge '143962123#0' not reachable by vehicle 'h07_23627'.
# Warning: The vehicle 'h07_23627' has no valid route.
# Warning: No connection between edge '713872941#0' and edge '143962120' found.
# Warning: Mandatory edge '143962120' not reachable by vehicle 'h07_24219'.
# Warning: The vehicle 'h07_24219' has no valid route.
# Warning: No connection between edge '40931837' and edge '767313243' found.
# Warning: Mandatory edge '767313243' not reachable by vehicle 'h07_24641'.
# Warning: The vehicle 'h07_24641' has no valid route.
# Warning: No connection between edge '793930821' and edge '144852144' found.
# Warning: Mandatory edge '144852144' not reachable by vehicle 'h07_24797'.
# Warning: The vehicle 'h07_24797' has no valid route.
# Warning: No connection between edge '27773471#1' and edge '144160557#1' found.
# Warning: Mandatory edge '144160557#1' not reachable by vehicle 'h07_25871'.
# Warning: The vehicle 'h07_25871' has no valid route.
# Warning: No connection between edge '126796450#1' and edge '378355994#2' found.
# Warning: Mandatory edge '378355994#2' not reachable by vehicle 'h07_26682'.
# Warning: The vehicle 'h07_26682' has no valid route.
# Reading up to time step: 26400.12
# Warning: No connection between edge '51762086#1' and edge '143962123#0' found.
# Warning: Mandatory edge '143962123#0' not reachable by vehicle 'h07_26891'.
# Warning: The vehicle 'h07_26891' has no valid route.
# Warning: No connection between edge '24829292#3' and edge '144160557#0' found.
# Warning: Mandatory edge '144160557#0' not reachable by vehicle 'h07_27272'.
# Warning: The vehicle 'h07_27272' has no valid route.
# Warning: No connection between edge '561004521#2' and edge '62023728#1' found.
# Warning: Mandatory edge '62023728#1' not reachable by vehicle 'h07_27315'.
# Warning: The vehicle 'h07_27315' has no valid route.
# Warning: No connection between edge '53144421#0' and edge '62023728#1' found.
# Warning: Mandatory edge '62023728#1' not reachable by vehicle 'h07_27332'.
# Warning: The vehicle 'h07_27332' has no valid route.
# Warning: No connection between edge '377396791#2' and edge '161432888' found.
# Warning: Mandatory edge '161432888' not reachable by vehicle 'h07_27746'.
# Warning: The vehicle 'h07_27746' has no valid route.
# Warning: No connection between edge '395353702' and edge '144160557#2' found.
# Warning: Mandatory edge '144160557#2' not reachable by vehicle 'h07_27964'.
# Warning: The vehicle 'h07_27964' has no valid route.
# Warning: No connection between edge '24967552' and edge '144160557#1' found.
# Warning: Mandatory edge '144160557#1' not reachable by vehicle 'h07_27969'.
# Warning: The vehicle 'h07_27969' has no valid route.
# Warning: No connection between edge '67209282#3' and edge '367820004' found.
# Warning: Mandatory edge '367820004' not reachable by vehicle 'h07_27976'.
# Warning: The vehicle 'h07_27976' has no valid route.
# Warning: No connection between edge '688357782#0' and edge '388202560#0' found.
# Warning: Mandatory edge '388202560#0' not reachable by vehicle 'h07_28000'.
# Warning: The vehicle 'h07_28000' has no valid route.
# Warning: No connection between edge '171514121#0' and edge '112885002#1' found.
# Warning: Mandatory edge '112885002#1' not reachable by vehicle 'h07_28232'.
# Warning: The vehicle 'h07_28232' has no valid route.
# Warning: No connection between edge '925261618' and edge '142366416#0' found.
# Warning: Mandatory edge '142366416#0' not reachable by vehicle 'h07_28236'.
# Warning: The vehicle 'h07_28236' has no valid route.
# Warning: No connection between edge '157010360#0' and edge '383076320' found.
# Warning: Mandatory edge '383076320' not reachable by vehicle 'h07_28650'.
# Warning: The vehicle 'h07_28650' has no valid route.
# Warning: No connection between edge '688357782#0' and edge '6309968' found.
# Warning: Mandatory edge '6309968' not reachable by vehicle 'h07_28754'.
# Warning: The vehicle 'h07_28754' has no valid route.
# Warning: No connection between edge '51202319#3' and edge '188649571' found.
# Warning: Mandatory edge '188649571' not reachable by vehicle 'h07_29408'.
# ...
# Warning: Mandatory edge '112885002#0' not reachable by vehicle 'h22_29674'.
# Warning: The vehicle 'h22_29674' has no valid route.
# Warning: No connection between edge '131821101#2' and edge '62023740' found.
# Warning: Mandatory edge '62023740' not reachable by vehicle 'h22_29755'.
# Warning: The vehicle 'h22_29755' has no valid route.
# Warning: No connection between edge '150925676' and edge '52513138' found.
# Warning: Mandatory edge '52513138' not reachable by vehicle 'h22_29811'.
# Warning: The vehicle 'h22_29811' has no valid route.
# Warning: No connection between edge '120753216#1' and edge '378355994#0' found.
# Warning: Mandatory edge '378355994#0' not reachable by vehicle 'h22_30742'.
# Warning: The vehicle 'h22_30742' has no valid route.
# Reading up to time step: 82400.12
# Warning: No connection between edge '291943440' and edge '378355994#2' found.
# Warning: Mandatory edge '378355994#2' not reachable by vehicle 'h22_31484'.
# Warning: The vehicle 'h22_31484' has no valid route.
# Warning: No connection between edge '793930821' and edge '788574996' found.
# Warning: Mandatory edge '788574996' not reachable by vehicle 'h22_32266'.
# Warning: The vehicle 'h22_32266' has no valid route.
# Warning: No connection between edge '688357782#0' and edge '342760948#7' found.
# Warning: Mandatory edge '342760948#7' not reachable by vehicle 'h22_32880'.
# Warning: The vehicle 'h22_32880' has no valid route.
# Reading up to time step: 82600.12
# Warning: No connection between edge '925261618' and edge '34961220#5' found.
# Warning: Mandatory edge '34961220#5' not reachable by vehicle 'h22_33256'.
# Warning: The vehicle 'h22_33256' has no valid route.
# Warning: No connection between edge '830663988#0' and edge '386307421#0' found.
# Warning: Mandatory edge '386307421#0' not reachable by vehicle 'h22_33763'.
# Warning: The vehicle 'h22_33763' has no valid route.
# Warning: No connection between edge '688357782#0' and edge '53770339' found.
# Warning: Mandatory edge '53770339' not reachable by vehicle 'h22_34183'.
# Warning: The vehicle 'h22_34183' has no valid route.
# Warning: No connection between edge '124060635' and edge '48395126#1' found.
# Warning: Mandatory edge '48395126#1' not reachable by vehicle 'h22_34293'.
# Warning: The vehicle 'h22_34293' has no valid route.
# Warning: No connection between edge '96719516' and edge '143962123#2' found.
# Warning: Mandatory edge '143962123#2' not reachable by vehicle 'h22_34976'.
# Warning: The vehicle 'h22_34976' has no valid route.
# Warning: No connection between edge '688357782#0' and edge '53334003' found.
# Warning: Mandatory edge '53334003' not reachable by vehicle 'h22_34999'.
# Warning: The vehicle 'h22_34999' has no valid route.
# Reading up to time step: 82800.12
# Warning: No connection between edge '401956785#1' and edge '367820004' found.
# Warning: Mandatory edge '367820004' not reachable by vehicle 'h22_35507'.
# Warning: The vehicle 'h22_35507' has no valid route.
# Warning: No connection between edge '962905283#0' and edge '62023728#0' found.
# Warning: Mandatory edge '62023728#0' not reachable by vehicle 'h22_35846'.
# Warning: The vehicle 'h22_35846' has no valid route.
# Warning: No connection between edge '51202923' and edge '767313244' found.
# Warning: Mandatory edge '767313244' not reachable by vehicle 'h22_36652'.
# Warning: The vehicle 'h22_36652' has no valid route.
# Warning: No connection between edge '24255393#0' and edge '510193680' found.
# Warning: Mandatory edge '510193680' not reachable by vehicle 'h22_36921'.
# Warning: The vehicle 'h22_36921' has no valid route.
# Reading up to time step: 83000.12
# Warning: No connection between edge '836796624#0' and edge '767313243' found.
# Warning: Mandatory edge '767313243' not reachable by vehicle 'h23_868'.
# Warning: The vehicle 'h23_868' has no valid route.
# Warning: No connection between edge '71440136#4' and edge '143962123#1' found.
# Warning: Mandatory edge '143962123#1' not reachable by vehicle 'h23_1136'.
# Warning: The vehicle 'h23_1136' has no valid route.
# Reading up to time step: 83200.12
# Warning: No connection between edge '925261618' and edge '112781625' found.
# Warning: Mandatory edge '112781625' not reachable by vehicle 'h23_1663'.
# Warning: The vehicle 'h23_1663' has no valid route.
# Warning: No connection between edge '139762735' and edge '144160557#0' found.
# Warning: Mandatory edge '144160557#0' not reachable by vehicle 'h23_1885'.
# Warning: The vehicle 'h23_1885' has no valid route.
# Warning: No connection between edge '676368257' and edge '510193683' found.
# Warning: Mandatory edge '510193683' not reachable by vehicle 'h23_1896'.
# Warning: The vehicle 'h23_1896' has no valid route.
# Warning: No connection between edge '167788907#1' and edge '383076320' found.
# Warning: Mandatory edge '383076320' not reachable by vehicle 'h23_2070'.
# Warning: The vehicle 'h23_2070' has no valid route.
# Warning: No connection between edge '429244521#0' and edge '767313244' found.
# Warning: Mandatory edge '767313244' not reachable by vehicle 'h23_2248'.
# Warning: The vehicle 'h23_2248' has no valid route.
# Warning: No connection between edge '293815501' and edge '62023740' found.
# Warning: Mandatory edge '62023740' not reachable by vehicle 'h23_2456'.
# Warning: The vehicle 'h23_2456' has no valid route.
# Warning: No connection between edge '331884235' and edge '510193683' found.
# Warning: Mandatory edge '510193683' not reachable by vehicle 'h23_2501'.
# Warning: The vehicle 'h23_2501' has no valid route.
# Warning: No connection between edge '30779081' and edge '112885002#0' found.
# Warning: Mandatory edge '112885002#0' not reachable by vehicle 'h23_26666'.
# Warning: The vehicle 'h23_26666' has no valid route.
# Reading up to time step: 83400.12
# Warning: No connection between edge '124060635' and edge '676612337' found.
# Warning: Mandatory edge '676612337' not reachable by vehicle 'h23_3257'.
# Warning: The vehicle 'h23_3257' has no valid route.
# Warning: No connection between edge '341536063' and edge '62023740' found.
# Warning: Mandatory edge '62023740' not reachable by vehicle 'h23_3716'.
# Warning: The vehicle 'h23_3716' has no valid route.
# Reading up to time step: 83600.12
# Warning: No connection between edge '156026386' and edge '684411596#0' found.
# Warning: Mandatory edge '684411596#0' not reachable by vehicle 'h23_26702'.
# Warning: The vehicle 'h23_26702' has no valid route.
# Warning: No connection between edge '793930821' and edge '413858624' found.
# Warning: Mandatory edge '413858624' not reachable by vehicle 'h23_25035'.
# Warning: The vehicle 'h23_25035' has no valid route.
# Warning: No connection between edge '543452526#0' and edge '143962123#1' found.
# Warning: Mandatory edge '143962123#1' not reachable by vehicle 'h23_5204'.
# Warning: The vehicle 'h23_5204' has no valid route.
# Reading up to time step: 83800.12
# Warning: No connection between edge '886635291' and edge '378355994#2' found.
# Warning: Mandatory edge '378355994#2' not reachable by vehicle 'h23_5747'.
# Warning: The vehicle 'h23_5747' has no valid route.
# Warning: No connection between edge '345730888' and edge '510193683' found.
# Warning: Mandatory edge '510193683' not reachable by vehicle 'h23_6635'.
# Warning: The vehicle 'h23_6635' has no valid route.
# Warning: No connection between edge '82172849#1' and edge '1060073977' found.
# Warning: Mandatory edge '1060073977' not reachable by vehicle 'h23_6737'.
# Warning: The vehicle 'h23_6737' has no valid route.
# Reading up to time step: 84000.12
# Warning: No connection between edge '345730900' and edge '188649571' found.
# Warning: Mandatory edge '188649571' not reachable by vehicle 'h23_7587'.
# Warning: The vehicle 'h23_7587' has no valid route.
# Warning: No connection between edge '61976436' and edge '112885002#1' found.
# Warning: Mandatory edge '112885002#1' not reachable by vehicle 'h23_7828'.
# Warning: The vehicle 'h23_7828' has no valid route.
# Reading up to time step: 84200.12
# Warning: No connection between edge '53256207' and edge '62023741' found.
# Warning: Mandatory edge '62023741' not reachable by vehicle 'h23_8243'.
# Warning: The vehicle 'h23_8243' has no valid route.
# Warning: No connection between edge '156580398' and edge '367820004' found.
# Warning: Mandatory edge '367820004' not reachable by vehicle 'h23_25732'.
# Warning: The vehicle 'h23_25732' has no valid route.
# Warning: No connection between edge '793930821' and edge '561004756' found.
# Warning: Mandatory edge '561004756' not reachable by vehicle 'h23_9110'.
# Warning: The vehicle 'h23_9110' has no valid route.
# Warning: No connection between edge '375686689#0' and edge '378355994#0' found.
# Warning: Mandatory edge '378355994#0' not reachable by vehicle 'h23_9196'.
# Warning: The vehicle 'h23_9196' has no valid route.
# Reading up to time step: 84400.12
# Warning: No connection between edge '688357782#1' and edge '297124164#3' found.
# Warning: Mandatory edge '297124164#3' not reachable by vehicle 'h23_9588'.
# Warning: The vehicle 'h23_9588' has no valid route.
# Warning: No connection between edge '54357727' and edge '378355994#2' found.
# Warning: Mandatory edge '378355994#2' not reachable by vehicle 'h23_9657'.
# Warning: The vehicle 'h23_9657' has no valid route.
# Warning: No connection between edge '47001613#3' and edge '62023728#1' found.
# Warning: Mandatory edge '62023728#1' not reachable by vehicle 'h23_9867'.
# Warning: The vehicle 'h23_9867' has no valid route.
# Warning: No connection between edge '365983900#2' and edge '62023728#1' found.
# Warning: Mandatory edge '62023728#1' not reachable by vehicle 'h23_26552'.
# Warning: The vehicle 'h23_26552' has no valid route.
# Warning: No connection between edge '1090553479' and edge '386307421#0' found.
# Warning: Mandatory edge '386307421#0' not reachable by vehicle 'h23_10137'.
# Warning: The vehicle 'h23_10137' has no valid route.
# Warning: No connection between edge '161387697' and edge '188649571' found.
# Warning: Mandatory edge '188649571' not reachable by vehicle 'h23_11798'.
# Warning: The vehicle 'h23_11798' has no valid route.
# Reading up to time step: 84800.12
# Warning: No connection between edge '888144637' and edge '188649571' found.
# Warning: Mandatory edge '188649571' not reachable by vehicle 'h23_12846'.
# Warning: The vehicle 'h23_12846' has no valid route.
# Warning: No connection between edge '50848255#2' and edge '62023741' found.
# Warning: Mandatory edge '62023741' not reachable by vehicle 'h23_13010'.
# Warning: The vehicle 'h23_13010' has no valid route.
# Reading up to time step: 85000.12
# Warning: No connection between edge '187409695' and edge '378355994#0' found.
# Warning: Mandatory edge '378355994#0' not reachable by vehicle 'h23_13421'.
# Warning: The vehicle 'h23_13421' has no valid route.
# Warning: No connection between edge '267200070#1' and edge '767313244' found.
# Warning: Mandatory edge '767313244' not reachable by vehicle 'h23_13757'.
# Warning: The vehicle 'h23_13757' has no valid route.
# Reading up to time step: 85200.12
# Warning: No connection between edge '27866154#0' and edge '143962120' found.
# Warning: Mandatory edge '143962120' not reachable by vehicle 'h23_14698'.
# Warning: The vehicle 'h23_14698' has no valid route.
# Warning: No connection between edge '169984982#0' and edge '143962123#1' found.
# Warning: Mandatory edge '143962123#1' not reachable by vehicle 'h23_15825'.
# Warning: The vehicle 'h23_15825' has no valid route.
# Reading up to time step: 85400.12
# Warning: No connection between edge '793930821' and edge '24257189#1' found.
# Warning: Mandatory edge '24257189#1' not reachable by vehicle 'h23_16464'.
# Warning: The vehicle 'h23_16464' has no valid route.
# Warning: No connection between edge '532273693' and edge '367820007' found.
# Warning: Mandatory edge '367820007' not reachable by vehicle 'h23_16528'.
# Warning: The vehicle 'h23_16528' has no valid route.
# Warning: No connection between edge '1029848409' and edge '188649571' found.
# Warning: Mandatory edge '188649571' not reachable by vehicle 'h23_16645'.
# Warning: The vehicle 'h23_16645' has no valid route.
# Warning: No connection between edge '27773399#1' and edge '767313243' found.
# Warning: Mandatory edge '767313243' not reachable by vehicle 'h23_16923'.
# Warning: The vehicle 'h23_16923' has no valid route.
# Warning: No connection between edge '113578820#0' and edge '510193683' found.
# Warning: Mandatory edge '510193683' not reachable by vehicle 'h23_17083'.
# Warning: The vehicle 'h23_17083' has no valid route.
# Warning: No connection between edge '793930821' and edge '379971907' found.
# Warning: Mandatory edge '379971907' not reachable by vehicle 'h23_17276'.
# Warning: The vehicle 'h23_17276' has no valid route.
# Reading up to time step: 85600.12
# Warning: No connection between edge '434130138' and edge '367820004' found.
# Warning: Mandatory edge '367820004' not reachable by vehicle 'h23_17488'.
# Warning: The vehicle 'h23_17488' has no valid route.
# Warning: No connection between edge '171835835#1' and edge '53334004' found.
# Warning: Mandatory edge '53334004' not reachable by vehicle 'h23_26339'.
# Warning: The vehicle 'h23_26339' has no valid route.
# Warning: No connection between edge '124060635' and edge '53189097#2' found.
# Warning: Mandatory edge '53189097#2' not reachable by vehicle 'h23_18276'.
# Warning: The vehicle 'h23_18276' has no valid route.
# Reading up to time step: 85800.12
# Warning: No connection between edge '53333869' and edge '62023728#0' found.
# Warning: Mandatory edge '62023728#0' not reachable by vehicle 'h23_18727'.
# Warning: The vehicle 'h23_18727' has no valid route.
# Warning: No connection between edge '445289546#4' and edge '367820007' found.
# Warning: Mandatory edge '367820007' not reachable by vehicle 'h23_18992'.
# Warning: The vehicle 'h23_18992' has no valid route.
# Reading up to time step: 86000.12
# Warning: No connection between edge '603578754' and edge '510193680' found.
# Warning: Mandatory edge '510193680' not reachable by vehicle 'h23_27218'.
# Warning: The vehicle 'h23_27218' has no valid route.
# Warning: No connection between edge '47001245#3' and edge '767313244' found.
# Warning: Mandatory edge '767313244' not reachable by vehicle 'h23_20171'.
# Warning: The vehicle 'h23_20171' has no valid route.
# Warning: No connection between edge '241433398#5' and edge '62023728#0' found.
# Warning: Mandatory edge '62023728#0' not reachable by vehicle 'h23_20175'.
# Warning: The vehicle 'h23_20175' has no valid route.
# Reading up to time step: 86200.12
# Warning: No connection between edge '124060635' and edge '46962536#1' found.
# Warning: Mandatory edge '46962536#1' not reachable by vehicle 'h23_21615'.
# Warning: The vehicle 'h23_21615' has no valid route.
# Warning: No connection between edge '162767523#0' and edge '143962123#2' found.
# Warning: Mandatory edge '143962123#2' not reachable by vehicle 'h23_22255'.
# Warning: The vehicle 'h23_22255' has no valid route.
# Warning: No connection between edge '54967033#9' and edge '112885002#1' found.
# Warning: Mandatory edge '112885002#1' not reachable by vehicle 'h23_22273'.
# Warning: The vehicle 'h23_22273' has no valid route.
# Warning: No connection between edge '90753315#3' and edge '62023740' found.
# Warning: Mandatory edge '62023740' not reachable by vehicle 'h23_27057'.
# Warning: The vehicle 'h23_27057' has no valid route.
# Warning: No connection between edge '36918729' and edge '143962123#0' found.
# Warning: Mandatory edge '143962123#0' not reachable by vehicle 'h23_22539'.
# Warning: The vehicle 'h23_22539' has no valid route.
# Reading up to time step: 86400.12
# Warning: No connection between edge '53513809#1' and edge '143962123#2' found.
# Warning: Mandatory edge '143962123#2' not reachable by vehicle 'h23_22710'.
# Warning: The vehicle 'h23_22710' has no valid route.
# Warning: No connection between edge '793930821' and edge '141678529#1' found.
# Warning: Mandatory edge '141678529#1' not reachable by vehicle 'h23_23787'.
# Warning: The vehicle 'h23_23787' has no valid route.
# Success.
# [DONE] Routes written in /home/hoai-linh.dao/Works/EVCS/CEREMA-Mini/result/experiments/20-05-25-old-taz-ignore-errors/route.xml
# [LOG] Output logged in /home/hoai-linh.dao/Works/EVCS/CEREMA-Mini/result/experiments/20-05-25-old-taz-ignore-errors/logs/duarouter.log

# %% [markdown]
# ## Updating Sumo-Config

# %%
updateSumoCfg(
    cfg_path=SUMOCFG_XML,
    output_path=SUMOCFG_XML,
    replacements=PATH_REPLACEMENTS
)
print(f"[DONE] New Sumo-Configuration in {SUMOCFG_XML} with all right paths.")
# Out:
# Updating net-file: /home/hoai-linh.dao/Works/EVCS/CEREMA-Mini/result/net-repairment/cleaned_p2_2_newtest-osm.net.xml -> /home/hoai-linh.dao/Works/EVCS/CEREMA-Mini/result/net-repairment/cleaned_p2_2_newtest-osm.net.xml
# Updating route-files: /home/hoai-linh.dao/Works/EVCS/CEREMA-Mini/result/experiments/20-05-25-olld-taz-debugging-10percent/route.xml -> /home/hoai-linh.dao/Works/EVCS/CEREMA-Mini/result/experiments/20-05-25-old-taz-ignore-errors/route.xml
# Updating statistic-output: /home/hoai-linh.dao/Works/EVCS/CEREMA-Mini/result/experiments/20-05-25-olld-taz-debugging-10percent/outputs/statistics.xml -> /home/hoai-linh.dao/Works/EVCS/CEREMA-Mini/result/experiments/20-05-25-old-taz-ignore-errors/outputs/statistics.xml
# Updating log: /home/hoai-linh.dao/Works/EVCS/CEREMA-Mini/result/experiments/20-05-25-olld-taz-debugging-10percent/outputs/log.txt -> /home/hoai-linh.dao/Works/EVCS/CEREMA-Mini/result/experiments/20-05-25-old-taz-ignore-errors/outputs/log.txt
# Updating summary-output: /home/hoai-linh.dao/Works/EVCS/CEREMA-Mini/result/experiments/20-05-25-olld-taz-debugging-10percent/outputs/summary.xml -> /home/hoai-linh.dao/Works/EVCS/CEREMA-Mini/result/experiments/20-05-25-old-taz-ignore-errors/outputs/summary.xml
# Updating tripinfo-output: /home/hoai-linh.dao/Works/EVCS/CEREMA-Mini/result/experiments/20-05-25-olld-taz-debugging-10percent/outputs/tripinfo.xml -> /home/hoai-linh.dao/Works/EVCS/CEREMA-Mini/result/experiments/20-05-25-old-taz-ignore-errors/outputs/tripinfo.xml
# Updating vehroute-output: /home/hoai-linh.dao/Works/EVCS/CEREMA-Mini/result/experiments/20-05-25-olld-taz-debugging-10percent/outputs/vehRoutes.xml -> /home/hoai-linh.dao/Works/EVCS/CEREMA-Mini/result/experiments/20-05-25-old-taz-ignore-errors/outputs/vehRoutes.xml
# Updating lanechange-output: /home/hoai-linh.dao/Works/EVCS/CEREMA-Mini/result/experiments/20-05-25-olld-taz-debugging-10percent/outputs/laneChanges.xml -> /home/hoai-linh.dao/Works/EVCS/CEREMA-Mini/result/experiments/20-05-25-old-taz-ignore-errors/outputs/laneChanges.xml
# Updating fcd-output: /home/hoai-linh.dao/Works/EVCS/CEREMA-Mini/result/experiments/20-05-25-olld-taz-debugging-10percent/outputs/sumoTrace.xml -> /home/hoai-linh.dao/Works/EVCS/CEREMA-Mini/result/experiments/20-05-25-old-taz-ignore-errors/outputs/sumoTrace.xml
# Updating battery-output: /home/hoai-linh.dao/Works/EVCS/CEREMA-Mini/result/experiments/20-05-25-olld-taz-debugging-10percent/outputs/battery.xml -> /home/hoai-linh.dao/Works/EVCS/CEREMA-Mini/result/experiments/20-05-25-old-taz-ignore-errors/outputs/battery.xml
# Updating collision-output: /home/hoai-linh.dao/Works/EVCS/CEREMA-Mini/result/experiments/20-05-25-olld-taz-debugging-10percent/outputs/collisions.xml -> /home/hoai-linh.dao/Works/EVCS/CEREMA-Mini/result/experiments/20-05-25-old-taz-ignore-errors/outputs/collisions.xml
# Updating edgedata-output: /home/hoai-linh.dao/Works/EVCS/CEREMA-Mini/result/experiments/20-05-25-olld-taz-debugging-10percent/outputs/edgeData-60s.xml -> /home/hoai-linh.dao/Works/EVCS/CEREMA-Mini/result/experiments/20-05-25-old-taz-ignore-errors/outputs/edgeData-60s.xml
# Updating lanedata-output: /home/hoai-linh.dao/Works/EVCS/CEREMA-Mini/result/experiments/20-05-25-olld-taz-debugging-10percent/outputs/laneData-60s.xml -> /home/hoai-linh.dao/Works/EVCS/CEREMA-Mini/result/experiments/20-05-25-old-taz-ignore-errors/outputs/laneData-60s.xml
# Updating queue-output: /home/hoai-linh.dao/Works/EVCS/CEREMA-Mini/result/experiments/20-05-25-olld-taz-debugging-10percent/outputs/queue.xml -> /home/hoai-linh.dao/Works/EVCS/CEREMA-Mini/result/experiments/20-05-25-old-taz-ignore-errors/outputs/queue.xml
# [DONE] New Sumo-Configuration in /home/hoai-linh.dao/Works/EVCS/CEREMA-Mini/result/experiments/20-05-25-old-taz-ignore-errors/run.sumocfg with all right paths.

# %% [markdown]
# ## Running

# %%
SIMULATION_CMD = [
    "sumo",             
    "-c", SUMOCFG_XML,
    "--no-step-log",      
    "--duration-log.statistics",
    "--xml-validation", "never"  
]

with open(SIMULATION_LOG, "w") as f:
    print("Running SUMO simulation ...")
    subprocess.run(SIMULATION_CMD, stdout=f, stderr=subprocess.STDOUT, check=True)
    print(f"[DONE] Simulation outputs are created in {SIMULATION_DIR}\n[LOG] Output logged in {SIMULATION_LOG}")
# Out:
# Running SUMO simulation ...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 11
#       9 with open(SIMULATION_LOG, "w") as f:
#      10     print("Running SUMO simulation ...")
# ---> 11     subprocess.run(SIMULATION_CMD, stdout=f, stderr=subprocess.STDOUT, check=True)
#      12     print(f"[DONE] Simulation outputs are created in {SIMULATION_DIR}\n[LOG] Output logged in {SIMULATION_LOG}")
#
# File ~/Envs/sumo-env/lib/python3.10/subprocess.py:505, in run(input, capture_output, timeout, check, *popenargs, **kwargs)
#     503 with Popen(*popenargs, **kwargs) as process:
#     504     try:
# --> 505         stdout, stderr = process.communicate(input, timeout=timeout)
#     506     except TimeoutExpired as exc:
#     507         process.kill()
#
# File ~/Envs/sumo-env/lib/python3.10/subprocess.py:1146, in Popen.communicate(self, input, timeout)
#    1144         stderr = self.stderr.read()
#    1145         self.stderr.close()
# -> 1146     self.wait()
#    1147 else:
#    1148     if timeout is not None:
#
# File ~/Envs/sumo-env/lib/python3.10/subprocess.py:1209, in Popen.wait(self, timeout)
#    1207     endtime = _time() + timeout
#    1208 try:
# -> 1209     return self._wait(timeout=timeout)
#    1210 except KeyboardInterrupt:
#    1211     # https://bugs.python.org/issue25942
#    1212     # The first keyboard interrupt waits briefly for the child to
#    1213     # exit under the common assumption that it also received the ^C
#    1214     # generated SIGINT and will exit rapidly.
#    1215     if timeout is not None:
#
# File ~/Envs/sumo-env/lib/python3.10/subprocess.py:1959, in Popen._wait(self, timeout)
#    1957 if self.returncode is not None:
#    1958     break  # Another thread waited.
# -> 1959 (pid, sts) = self._try_wait(0)
#    1960 # Check the pid and loop as waitpid has been known to
#    1961 # return 0 even without WNOHANG in odd situations.
#    1962 # http://bugs.python.org/issue14396.
#    1963 if pid == self.pid:
#
# File ~/Envs/sumo-env/lib/python3.10/subprocess.py:1917, in Popen._try_wait(self, wait_flags)
#    1915 """All callers to this function MUST hold self._waitpid_lock."""
#    1916 try:
# -> 1917     (pid, sts) = os.waitpid(self.pid, wait_flags)
#    1918 except ChildProcessError:
#    1919     # This happens if SIGCLD is set to be ignored or waiting
#    1920     # for child processes has otherwise been disabled for our
#    1921     # process.  This child is dead, we can't get the status.
#    1922     pid = self.pid
#
# KeyboardInterrupt:

# %% [markdown]
# # **VISUALIZATIONS**

# %%
# Departure times versus arrival times
PLOT_CMD_1 = [
    "python", PLOTXMLATTRIBUTES_PY,
    VEHROUTES_XML,                 
    "-x", "depart",      
    "-y", "arrival",             
    "-o", PLOT_1_PNG,
    "--scatterplot"
]

subprocess.run(PLOT_CMD_1, check=True)

# %%
# All trajectories over time 1
PLOT_CMD_2 = [
    "python", PLOTXMLATTRIBUTES_PY,
    TRACE_XML,                 
    "-x", "x",     
    "-y", "y",             
    "-o", PLOT_2_PNG,
    "--scatterplot"
]

subprocess.run(PLOT_CMD_2, check=True)

# %%
# Multiple timelines from summary-output
PLOT_CMD_3 = [
    "python", PLOTXMLATTRIBUTES_PY,
    SUMMARY_XML,
    "-x", "time",
    "-y", "running,halting",
    "-o", PLOT_3_PNG,
    "--legend"
]
subprocess.run(PLOT_CMD_3, check=True)

# %%
# Depart delay over time from TripInfo data
PLOT_CMD_4 = [
    "python", PLOTXMLATTRIBUTES_PY,
    TRIPINFO_XML,
    "-x", "depart",
    "-y", "departDelay",
    "--xlabel", "depart time [s]",
    "--ylabel", "depart delay [s]",
    "--ylim", "0,40",
    "--xticks", "0,1200,200,10",
    "--yticks", "0,40,5,10",
    "--xgrid", "--ygrid",
    "--title", "depart delay over depart time",
    "--titlesize", "16",
    "-o", PLOT_4_PNG
]
subprocess.run(PLOT_CMD_4, check=True)

# %%
QUERIED_VEH_ID = "carDist1"
# Selected trajectories over time
PLOT_CMD_5 = [
    "python", PLOTXMLATTRIBUTES_PY,
    TRACE_XML,
    "-x", "x",
    "-y", "y",
    "-i", "id",
    "--filter-ids", QUERIED_VEH_ID
    "--scatterplot",
    "--legend",
    "-o", PLOT_5_PNG
]
subprocess.run(PLOT_CMD_4, check=True)
