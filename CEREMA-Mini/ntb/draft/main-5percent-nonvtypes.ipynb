# %% [markdown]
# # **SETUP**

# %% [markdown]
# ## Libs && Envs

# %%
import os
import glob
from pathlib import Path
import subprocess
import sys
import shutil

import itertools
import random
import pandas as pd
import math
import csv
import re
from collections import OrderedDict, defaultdict
from typing import List, Dict, Tuple
from collections import Counter

import traci
import sumolib
import xml.etree.ElementTree as ET
from pyproj import Transformer, CRS
import networkx as nx
from shapely.geometry import Point, Polygon
from shapely.ops import unary_union
from shapely.errors import TopologicalError

from helpers import *

# export LD_LIBRARY_PATH=~/Libs/libnsl
# export SUMO_HOME=~/Envs/sumo-env/lib/python3.10/site-packages/sumo
os.environ["LD_LIBRARY_PATH"] = os.path.expanduser("~/Libs/libnsl")
os.environ["SUMO_HOME"] = os.path.expanduser("~/Envs/sumo-env/lib/python3.10/site-packages/sumo")
# Out:
# Failed to start the Kernel.
#
# Unable to start Kernel 'sumo-env (Python 3.10.16)' due to a timeout waiting for the ports to get used.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %% [markdown]
# ## Configs

# %%
# Fixed PATHs
NET_XML = Path("/home/hoai-linh.dao/Works/EVCS/CEREMA-Mini/data/newtest-osm.net.xml")
POLY_XML = "/home/hoai-linh.dao/Works/EVCS/AMP-Metropole/Task-1-Completion/results/p0/newtest-poly/bassin-based.poly.xml"
ORIG_VTYPES_XML = "/home/hoai-linh.dao/Works/EVCS/CEREMA-Mini/data/integrated-dist.add.xml"
GROUPED_POLY_XML = "/home/hoai-linh.dao/Works/EVCS/CEREMA-Mini/data/group-based.poly.xml"
FLOW_CSV = "/home/hoai-linh.dao/Works/EVCS/CEREMA-Mini/data/flow.csv"
MAIN_FLOW_CSV = "/home/hoai-linh.dao/Works/EVCS/CEREMA-Mini/result/main-flow.csv"

SUMO_TOOLS_DIR = Path("/home/hoai-linh.dao/Envs/sumo-env/lib/python3.10/site-packages/sumo/tools")
REROUTING_PY = SUMO_TOOLS_DIR / "generateContinuousRerouters.py"
NETCHECK_PY = SUMO_TOOLS_DIR / "net/netcheck.py"
RANDOMTRIPS_PY = SUMO_TOOLS_DIR / "randomTrips.py"
FINDALLROUTES_PY = SUMO_TOOLS_DIR / "findAllRoutes.py"
PLOTXMLATTRIBUTES_PY = SUMO_TOOLS_DIR / "visualization/plotXMLAttributes.py"
PLOTTRAJECTORIES_PY = SUMO_TOOLS_DIR / "plot_trajectories.py"
PLOTNETDUMP_PY = SUMO_TOOLS_DIR / "visualization/plot_net_dump.py"
PLOTNETSPEED_PY = SUMO_TOOLS_DIR / "visualization/plot_net_speed.py"
PLOTNETTRAFFICLIGHTS_PY = SUMO_TOOLS_DIR / "visualization/plot_net_trafficLights.py"
PLOTSUMMARY_PY = SUMO_TOOLS_DIR / "visualization/plot_summary.py"
PLOTTRIPINFODISTRIBUTIONS_PY = SUMO_TOOLS_DIR / "visualization/plot_tripinfo_distributions.py"
PLOTCSVTIMELINE_PY = SUMO_TOOLS_DIR / "visualization/plot_csv_timeline.py"
PLOTCSVPIE_PY = SUMO_TOOLS_DIR / "visualization/plot_csv_pie.py"
PLOTCSVBARS_PY = SUMO_TOOLS_DIR / "visualization/plot_csv_bars.py"
MACROUTPUT_PY = SUMO_TOOLS_DIR / "visualization/marcoOutput.py"
ROUTESTATS_PY = SUMO_TOOLS_DIR / "route/routeStats.py"
ROUTECHECK_PY = SUMO_TOOLS_DIR / "route/routecheck.py"

# Dynamic DIRs
SIMULATION_DIR = Path("/home/hoai-linh.dao/Works/EVCS/CEREMA-Mini/result/experiments/simulation-5percent-nonvtypes")

ODS_DIR = SIMULATION_DIR / "ods"
TRIPS_DIR = SIMULATION_DIR / "trips"
OUTPUTS_DIR = SIMULATION_DIR / "outputs"
LOGS_DIR = SIMULATION_DIR / "logs"
VISUALIZATIONS_DIR = SIMULATION_DIR / "visualizations"

SIMULATION_DIR.mkdir(parents=True, exist_ok=True)
for path in [ODS_DIR, TRIPS_DIR, OUTPUTS_DIR, LOGS_DIR, VISUALIZATIONS_DIR]:
    path.mkdir(parents=True, exist_ok=True)

# Dynamic PATHs
TAZ_XML = SIMULATION_DIR / "taz-ver2-40samples.add.xml"
VTYPES_DIST_XML = SIMULATION_DIR / "vtypes-dist.add.xml"
ALL_TRIPS_XML = SIMULATION_DIR / "trips.xml"
ROUTE_XML = SIMULATION_DIR / "route.xml"
ROUTE_ALT_XML = SIMULATION_DIR / "route.alt.xml"
REROUTER_XML = SIMULATION_DIR / "rerouter.add.xml"
SUMOCFG_XML = SIMULATION_DIR / "run.sumocfg"

DUAROUTER_LOG = LOGS_DIR / "duarouter.log"
SIMULATION_LOG = LOGS_DIR / "sumo_run.log"
REROUTING_LOG = LOGS_DIR / "rerouting.log"

# Outputs Paths
COLLISIONS_XML = OUTPUTS_DIR / "collisions.xml"
BATTERY_XML = OUTPUTS_DIR / "battery.xml"
LANECHANGES_XML = OUTPUTS_DIR / "laneChanges.xml"
STATISTICS_XML = OUTPUTS_DIR / "statistics.xml"
TRACE_XML = OUTPUTS_DIR / "sumoTrace.xml"
SUMMARY_XML = OUTPUTS_DIR / "summary.xml"
TRIPINFO_XML = OUTPUTS_DIR / "tripinfo.xml"
VEHROUTES_XML = OUTPUTS_DIR / "vehRoutes.xml"
NETSTATE_XML = OUTPUTS_DIR / "netstate.xml"
LOG_TXT = OUTPUTS_DIR / "log.txt"
EDGEDATA_XML = OUTPUTS_DIR / "edgeData-60s.xml"
LANEDATA_XML = OUTPUTS_DIR / "laneData-60s.xml"
QUEUE_XML = OUTPUTS_DIR / "queue.xml"
EMISSION_XML = OUTPUTS_DIR / "emission.xml"
SMS_XML = OUTPUTS_DIR / "sms.xml"

# Visualization Paths
PLOT_1_PNG = VISUALIZATIONS_DIR / "plot_1.png"
PLOT_2_PNG = VISUALIZATIONS_DIR / "plot_2.png"

# Net-Repairment Task
NET_REPAIRMENT_DIR = Path("/home/hoai-linh.dao/Works/EVCS/CEREMA-Mini/result/net-repairment")
CLEANED_NET_XML_1 = NET_REPAIRMENT_DIR /  f"cleaned_1_{NET_XML.name}"
CLEANED_NET_XML_2 = NET_REPAIRMENT_DIR /  f"cleaned_2_{NET_XML.name}"

KEEP_EDGES_TXT_1 = NET_REPAIRMENT_DIR / "keep-edges_1.txt"
KEEP_EDGES_TXT_2 = NET_REPAIRMENT_DIR / "keep-edges_2.txt"
COMPONENTS_NW_TXT_1 = NET_REPAIRMENT_DIR / "components_nw_1.txt"
COMPONENTS_NW_TXT_2 = NET_REPAIRMENT_DIR / "components_nw_2.txt"

NET_REPAIRMENT_LOGS_DIR = NET_REPAIRMENT_DIR / "logs"
NETCHECK_LOG_1 = NET_REPAIRMENT_LOGS_DIR / "netcheck_1.log"
NETCHECK_LOG_2 = NET_REPAIRMENT_LOGS_DIR / "netcheck_2.log"
NETCHECK_LOG_3 = NET_REPAIRMENT_LOGS_DIR / "netcheck_3.log"
NETCONVERT_LOG_1 = NET_REPAIRMENT_LOGS_DIR / "netconvert_1.log"
NETCONVERT_LOG_2 = NET_REPAIRMENT_LOGS_DIR / "netconvert_2.log"

# %%
TAZ_IDS = {
    'marseille': '1',
    'aix-en-provence': '2',
    'est-etang-de-berre': '3',
    'nord-ouest': '4',
    'ouest-etang-de-berre': '5',
    'sud-est': '6',
    'hors_amp': '99'
}

BORDER_RATIO = 0.40
REAL_ORIGIN   = 'marseille'

CAR_PREFIX = "carDist"              
EV_BRANDS = ["Renault", "Tesla", "Citroen", "Peugeot", "Dacia", "Volkswagen", "BMW", "Fiat", "KIA"]

EV_RATIO = 0.20

DIST_ID = "vehDist"

# Page 11
INCOMING_RATIO = 178729/(178729 + 174729)
OUTGOING_RATIO = 174729/(178729 + 174729)
INCOMING_RATIO, OUTGOING_RATIO

# Page 14 + Page 15
TRIPS_RATIO_0 = 1 # default
TRIPS_RATIO_1 = 0.40 # Marseille 
TRIPS_RATIO_2 = 0.41 # Marseille Bassin
TRIPS_RATIO_3 = 0.52 # AMP Bassin = CEREMA
TRIPS_RATIO_4 = 0.10 # test
TRIPS_RATIO_5 = 0.05

# %% [markdown]
# # **PREPARATION**

# %% [markdown]
# ## Processing Raw Flow

# %%
df = pd.read_csv(FLOW_CSV)

columns_inter = ['Est_Etang-de-Berre','Aix-en-Provence','Sud-Est','Ouest_Etang-de-Berre','Nord-Ouest','Hors_AMP']
df["Intra"] = df["Total"] - df[columns_inter].sum(axis=1)

df.columns = [col.lower() for col in df.columns]

df.to_csv(MAIN_FLOW_CSV, index=False)

# %% [markdown]
# ## Repairing Network

# %%
NETCHECK_CMD_1 = [
    "python", NETCHECK_PY,
    NET_XML,
    "--vclass", "passenger",
    "--component-output", COMPONENTS_NW_TXT_1
]

with open(NETCHECK_LOG_1, "w") as f:
    print(f"Running NETCHECK Step 1 ...")
    subprocess.run(NETCHECK_CMD_1, stdout=f, stderr=subprocess.STDOUT, check=True)
    print(f"[DONE] Components Ouput written to {COMPONENTS_NW_TXT_1}\n[LOG] Output logged in {NETCHECK_LOG_1}")

print()
print(f"Running extractMaxComponent ...")
extractMaxComponent(COMPONENTS_NW_TXT_1, KEEP_EDGES_TXT_1)

# %%
NETCONVERT_CMD_1 = [
    "netconvert",
    "--net-file", NET_XML,
    "--keep-edges.input-file", KEEP_EDGES_TXT_1,
    "--geometry.remove",
    "--geometry.remove.min-length", "2",
    "--geometry.max-segment-length", "20",
    "--geometry.min-dist", "0.1",
    "--geometry.max-angle", "150",
    "--geometry.max-angle.fix",
    "--remove-edges.isolated",
    "--junctions.join",
    "--junctions.join-dist", "60",
    "--roundabouts.guess",
    "--ramps.guess",
    "--keep-edges.by-vclass=passenger",
    "--osm.bike-access=false",
    "--osm.sidewalks=false",
    "--crossings.guess=false",
    "--tls.guess",
    "--tls.guess.threshold", "40",
    "--tls.join",
    "--tls.layout", "incoming",
    "--tls.discard-loaded",
    "--ptstop-output", "/dev/null",
    "--ptline-output", "/dev/null",
    "-o", CLEANED_NET_XML_1
]

with open(NETCONVERT_LOG_1, "w") as f:
    print(f"Running NETCONVERT Step 1 ...")
    subprocess.run(NETCONVERT_CMD_1, stdout=f, stderr=subprocess.STDOUT, check=True)
    print(f"[DONE] Cleaned Network written to {CLEANED_NET_XML_1}\n[LOG] Output logged in {NETCONVERT_LOG_1}")

# %%
NETCHECK_CMD_2 = [
    "python", NETCHECK_PY,
    CLEANED_NET_XML_1,
    "--vclass", "passenger",
    "--component-output", COMPONENTS_NW_TXT_2,
    "-t"
]

with open(NETCHECK_LOG_2, "w") as f:
    print(f"Running NETCHECK Step 2 ...")
    subprocess.run(NETCHECK_CMD_2, stdout=f, stderr=subprocess.STDOUT, check=True)
    print(f"[DONE] Output logged in {NETCHECK_LOG_2}")

print()
print(f"Running extractMaxComponent ...")
extractMaxComponent(COMPONENTS_NW_TXT_2, KEEP_EDGES_TXT_2)

# %%
NETCONVERT_CMD_2 = [
    "netconvert",
    "--net-file", CLEANED_NET_XML_1,
    "--keep-edges.input-file", KEEP_EDGES_TXT_2,
    "-o", CLEANED_NET_XML_2
]

with open(NETCONVERT_LOG_2, "w") as f:
    print(f"Running NETCONVERT Step 2 ...")
    subprocess.run(NETCONVERT_CMD_2, stdout=f, stderr=subprocess.STDOUT, check=True)
    print(f"[DONE] Cleaned Network written to {CLEANED_NET_XML_2}\n[LOG] Output logged in {NETCONVERT_LOG_2}")

# %%
/home/hoai-linh.dao/Works/EVCS/CEREMA-Mini/result/experiments/simulation-5percent-nonvtypesNETCHECK_CMD_3 = [
    "python", NETCHECK_PY,
    CLEANED_NET_XML_2,
    "--vclass", "passenger",
    "-t"

]

with open(NETCHECK_LOG_3, "w") as f:
    print(f"Running NETCHECK Step 3 ...")
    subprocess.run(NETCHECK_CMD_3, stdout=f, stderr=subprocess.STDOUT, check=True)
    print(f"[DONE] Output logged in {NETCHECK_LOG_3}")
# Out:
# Running NETCHECK Step 3 ...
# [DONE] Output logged in /home/hoai-linh.dao/Works/EVCS/CEREMA-Mini/result/net-repairment/logs/netcheck_3.log

# %%
net = sumolib.net.readNet(CLEANED_NET_XML_2)

# Chiều A → B
print("64502815#1  → 510193665:",
      net.getShortestPath(
          net.getEdge('64502815#1'),
          net.getEdge('510193665'))[0] is None)

# Chiều ngược lại B → A
print("510193665   → 64502815#1:",
      net.getShortestPath(
          net.getEdge('510193665'),
          net.getEdge('64502815#1'))[0] is None)
# Out:
# 64502815#1  → 510193665: True
# 510193665   → 64502815#1: False

# %% [markdown]
# ## Checking Route

# %%
ROUTESTATS_CMD = [
    "python", ROUTESTATS_PY,
    ROUTE_ALT_XML,
    # "-n", CLEANED_NET_XML_2,
    "-a", "routeLength",
    "--binwidth", "500",
    "--hist-output", "/home/hoai-linh.dao/Works/EVCS/CEREMA-Mini/result/hist.dat"
]
subprocess.run(ROUTESTATS_CMD, check=True)
# Out:
# Traceback (most recent call last):
#   File "/home/hoai-linh.dao/Envs/sumo-env/lib/python3.10/site-packages/sumo/tools/route/routeStats.py", line 158, in <module>
#     main()
#   File "/home/hoai-linh.dao/Envs/sumo-env/lib/python3.10/site-packages/sumo/tools/route/routeStats.py", line 127, in main
#     length = attribute_retriever(vehicle)
#   File "/home/hoai-linh.dao/Envs/sumo-env/lib/python3.10/site-packages/sumo/tools/route/routeStats.py", line 101, in attribute_retriever
#     return float(vehicle.routeLength)
# TypeError: float() argument must be a string or a real number, not 'NoneType'
# ---------------------------------------------------------------------------
# CalledProcessError                        Traceback (most recent call last)
# Cell In[10], line 9
#       1 ROUTESTATS_CMD = [
#       2     "python", ROUTESTATS_PY,
#       3     ROUTE_ALT_XML,
#    (...)
#       7     "--hist-output", "/home/hoai-linh.dao/Works/EVCS/CEREMA-Mini/result/hist.dat"
#       8 ]
# ----> 9 subprocess.run(ROUTESTATS_CMD, check=True)
#
# File ~/Envs/sumo-env/lib/python3.10/subprocess.py:526, in run(input, capture_output, timeout, check, *popenargs, **kwargs)
#     524     retcode = process.poll()
#     525     if check and retcode:
# --> 526         raise CalledProcessError(retcode, process.args,
#     527                                  output=stdout, stderr=stderr)
#     528 return CompletedProcess(process.args, retcode, stdout, stderr)
#
# CalledProcessError: Command '['python', PosixPath('/home/hoai-linh.dao/Envs/sumo-env/lib/python3.10/site-packages/sumo/tools/route/routeStats.py'), PosixPath('/home/hoai-linh.dao/Works/EVCS/CEREMA-Mini/result/vtypes-simulation/route.alt.xml'), '-a', 'routeLength', '--binwidth', '500', '--hist-output', '/home/hoai-linh.dao/Works/EVCS/CEREMA-Mini/result/hist.dat']' returned non-zero exit status 1.

# %% [markdown]
# # **MAIN**

# %% [markdown]
# ## Draft

# %%
poly_tree = ET.parse(GROUPED_POLY_XML)
poly_root = poly_tree.getroot()

region_polys = defaultdict(list)
for poly in poly_root.findall("poly"):
    region = poly.get("type")
    shape_str = poly.get("shape")
    if region and shape_str:
        polygon = parseShape(shape_str)
        if polygon is not None:
            region_polys[region].append(polygon)

region_geoms = {}
for region, polys in region_polys.items():
    if polys:
        try:
            region_geoms[region] = unary_union(polys)
        except TopologicalError as e:
            print(f"[ERROR] Topology error in bassin {region}: {e}")

print("[CHECK] BBs based on bassin:")
for region, geom in region_geoms.items():
    print(f"  {region}: {geom.bounds}")
# Out:
# [CHECK] BBs based on bassin:
#   Marseille: (681071.41, 4782435.09, 707896.24, 4809844.54)
#   Aix-En-Provence: (675875.66, 4806237.37, 726750.02, 4846094.13)
#   Est-Etang-de-Berre: (661512.74, 4799268.23, 692628.4, 4824635.74)
#   Nord-Ouest: (657332.98, 4821077.14, 684620.21, 4848686.82)
#   Ouest-Etang-de-Berre: (640339.8, 4798892.24, 671498.4, 4834166.7)
#   Sud-Est: (702844.16, 4781624.45, 724169.27, 4813232.06)

# %%
net = sumolib.net.readNet(CLEANED_NET_XML_2)
tree_net = ET.parse(CLEANED_NET_XML_2)
root_net = tree_net.getroot()
location_elem = root_net.find("location")
if location_elem is None or "projParameter" not in location_elem.attrib:
    raise ValueError("Not found <location> or projParameter in net.xml")
proj_param = location_elem.attrib["projParameter"]
target_crs = CRS.from_proj4(proj_param)
transformer = Transformer.from_crs("epsg:4326", target_crs, always_xy=True)

edges_by_region = defaultdict(list)
edges_hors = []

for edge in net.getEdges():
    if edge.getID().endswith("-source") or edge.getID().endswith("-sink"):
        continue
    shape = edge.getShape()
    if not shape:
        continue
    mid_pt = shape[len(shape)//2]
    pt = Point(mid_pt[0], mid_pt[1])

    assigned = False
    for region, geom in region_geoms.items():
        if geom.contains(pt):
            edges_by_region[region].append(edge)
            assigned = True
            break

    if not assigned:
        edges_hors.append(edge)
        
edges_by_region['hors_amp'] = edges_hors

# %%
net = sumolib.net.readNet(CLEANED_NET_XML_2)

def reachable(e_from, e_to):
    """True nếu có đường đi (theo passenger) từ e_from --> e_to"""
    return net.getShortestPath(e_from, e_to)[0] is not None

candidate_out  = defaultdict(list)
candidate_in   = defaultdict(list)

SAMPLE = 200

for reg_from, edges_from in edges_by_region.items():
    others = {r: es for r, es in edges_by_region.items() if r != reg_from}

    for e in edges_from:
        # --- OUT ---
        ok_out = False
        for reg_to, edges_to in others.items():
            sample_to = random.sample(edges_to, min(SAMPLE, len(edges_to)))
            if any(reachable(e, et) for et in sample_to):
                ok_out = True
                break
        if ok_out:
            candidate_out[reg_from].append(e)

        # --- IN ---
        ok_in = False
        for reg_from2, edges_from2 in others.items():
            sample_from2 = random.sample(edges_from2, min(SAMPLE, len(edges_from2)))
            if any(reachable(ef2, e) for ef2 in sample_from2):
                ok_in = True
                break
        if ok_in:
            candidate_in[reg_from].append(e)

root = ET.Element("tazs")
for region in edges_by_region:
    rid = region.lower()
    taz_id = TAZ_IDS.get(rid)
    if not taz_id:
        print(f"[WARN] No TAZ id for {region}, skip")
        continue

    geom = region_geoms.get(region)
    cx, cy = (geom.centroid.x, geom.centroid.y) if geom else (0, 0)
    taz = ET.SubElement(root, "taz", id=taz_id, x=f"{cx:.2f}", y=f"{cy:.2f}")

    Nsrc = Nsink = 300
    for e in random.sample(candidate_out[region],  min(Nsrc,  len(candidate_out[region]))):
        ET.SubElement(taz, "tazSource", id=e.getID(), weight="1.0")

    for e in random.sample(candidate_in[region],   min(Nsink, len(candidate_in[region]))):
        ET.SubElement(taz, "tazSink",   id=e.getID(), weight="1.0")

ET.ElementTree(root).write(TAZ_XML, encoding="utf-8", xml_declaration=True)
print(">> TAZ written to", TAZ_XML)

# %%
#  Direction statistics
net = sumolib.net.readNet(CLEANED_NET_XML_2)
internal_edges = [e for e in net.getEdges() if e.getID().startswith(':')]
normal_edges   = [e for e in net.getEdges(True)   # chỉ edge “thường”
                  if not e.getID().startswith(':')]

print(f"Normal edges  : {len(normal_edges):,}")
print(f"Internal edges: {len(internal_edges):,}")


counter = Counter()

for e in normal_edges:
    direction = "one_way"

  
    for rev in e.getToNode().getOutgoing():        
        if rev.getToNode() is e.getFromNode():     
            direction = "two_way"
            break

    counter[direction] += 1

print("\n--- Direction statistics ---")
print(f"One-way edges : {counter['one_way']:,}")
print(f"Two-way edges : {counter['two_way']:,}")
print(f"Total checked : {counter['one_way'] + counter['two_way']:,}")
# Out:
# Normal edges  : 165,808
# Internal edges: 0
#
# --- Direction statistics ---
# One-way edges : 34,316
# Two-way edges : 131,492
# Total checked : 165,808

# %%
# New proposed TAZ creation way
BORDER_RATIO          = 0.4  
SAMPLE_INNER          = 40  
SAMPLE_CROSS          = 40  
def parseShape(shape_str: str):
    try:
        coords = [tuple(map(float, p.split(','))) for p in shape_str.strip().split()]
    except ValueError:
        return None
    if len(coords) < 3:
        return None
    if coords[0] != coords[-1]:
        coords.append(coords[0])
    poly = Polygon(coords)
    if not poly.is_valid:
        poly = poly.buffer(0)
    return poly if poly.is_valid else None


def boundary_edges(edges, geom, ratio=0.1):
    if geom is None:
        return []
    minx, miny, maxx, maxy = geom.bounds
    th = min(maxx - minx, maxy - miny) * ratio
    boundary = geom.boundary
    return [e for e in edges if Point(e.getShape()[len(e.getShape())//2]).distance(boundary) < th]


def has_reverse(edge):
    fn, tn = edge.getFromNode(), edge.getToNode()
    return any(o.getToNode() is fn for o in tn.getOutgoing())


def is_valid_edge(edge):
    return (not edge.getID().startswith('-')  # skip reverse direction
            and not edge.getID().endswith(('-source', '-sink'))
            and edge.getShape()
            and has_reverse(edge))            # true two‑way road


def reachable(edge_from, edge_to, net):
    return net.getShortestPath(edge_from, edge_to)[0] is not None


def filter_reachable(pool, net, sample=SAMPLE_INNER):
    """Keep edges that can reach **and** be reached from ≥1 peer in *pool*."""
    if len(pool) <= 1:
        return pool
    keep = []
    for e in pool:
        targets = random.sample([x for x in pool if x is not e], min(sample, len(pool)-1))
        ok_out = any(reachable(e, t, net) for t in targets)
        ok_in  = any(reachable(t, e, net) for t in targets)
        if ok_out and ok_in:
            keep.append(e)
    return keep

# STEP‑1  Build basin geometries
print("[1] Reading basins …")
region_geoms = defaultdict(list)
for p in ET.parse(GROUPED_POLY_XML).getroot().findall('poly'):
    reg = p.get('type')
    geom = parseShape(p.get('shape', ''))
    if reg and geom:
        region_geoms[reg].append(geom)
for reg, polys in region_geoms.items():
    region_geoms[reg] = unary_union(polys) if len(polys) > 1 else polys[0]

# STEP‑2  Scan network & assign edges to basins
print("[2] Scanning network …")
NET = sumolib.net.readNet(CLEANED_NET_XML_2)

edges_by_region = defaultdict(list)
outside = []

for e in NET.getEdges():
    if not is_valid_edge(e):
        continue
    mid = Point(e.getShape()[len(e.getShape())//2])
    placed = False
    for reg, geom in region_geoms.items():
        if geom.contains(mid):
            edges_by_region[reg].append(e)
            placed = True
            break
    if not placed:
        outside.append(e)

edges_by_region['hors_amp'] = outside

# ── Inner‑basin connectivity 
print("[2a] Inner‑basin connectivity filter …")
for reg, pool in list(edges_by_region.items()):
    kept = filter_reachable(pool, NET, SAMPLE_INNER)
    if len(kept) < len(pool):
        print(f"  – {reg}: removed {len(pool)-len(kept)} isolated edges")
    edges_by_region[reg] = kept

# ── Cross‑basin connectivity 
print("[2b] Cross‑basin connectivity filter …")
for reg_from, pool_from in list(edges_by_region.items()):
    others = [e for r, p in edges_by_region.items() if r != reg_from for e in p]
    if not pool_from or not others:
        continue
    keep = []
    for e in pool_from:
        tgt_sample = random.sample(others, min(SAMPLE_CROSS, len(others)))
        ok_out = any(reachable(e, t, NET) for t in tgt_sample)
        ok_in  = any(reachable(t, e, NET) for t in tgt_sample)
        if ok_out and ok_in:
            keep.append(e)
    removed = len(pool_from) - len(keep)
    if removed:
        print(f"  – {reg_from}: removed {removed} edges not reachable cross‑basin")
    edges_by_region[reg_from] = keep

# STEP‑3  Write TAZ
print("[3] Writing TAZ …")
root = ET.Element('tazs')
for reg, pool in edges_by_region.items():
    if not pool:
        continue
    tid = TAZ_IDS.get(reg.lower())
    if tid is None:
        print(f"  ! no TAZ id for basin {reg}; skip")
        continue
    geom = region_geoms.get(reg)
    B = boundary_edges(pool, geom)
    I = [e for e in pool if e not in B]
    nb = int(BORDER_RATIO*len(pool))
    ni = len(pool)-nb
    chosen = random.sample(B, min(nb, len(B))) + random.sample(I, min(ni, len(I)))

    c = geom.centroid if geom else Point(0,0)
    taz = ET.SubElement(root, 'taz', id=str(tid), x=f"{c.x:.2f}", y=f"{c.y:.2f}")
    for e in sorted(chosen, key=lambda x:x.getID()):
        ET.SubElement(taz,'tazSource', id=e.getID(), weight='1.0')
        ET.SubElement(taz,'tazSink',   id=e.getID(), weight='1.0')

ET.ElementTree(root).write(TAZ_XML, encoding='utf-8', xml_declaration=True)
print(f"[DONE] {TAZ_XML} ready.  Run od2trips & duarouter next.")
# Out:
# [1] Reading basins …
# [2] Scanning network …
# [2a] Inner‑basin connectivity filter …
#   – Aix-En-Provence: removed 21 isolated edges
#   – Est-Etang-de-Berre: removed 11 isolated edges
#   – Marseille: removed 32 isolated edges
#   – Sud-Est: removed 10 isolated edges
#   – Ouest-Etang-de-Berre: removed 27 isolated edges
#   – hors_amp: removed 7 isolated edges
# [2b] Cross‑basin connectivity filter …

# %% [markdown]
# ## CREATING TAZ

# %%
poly_tree = ET.parse(GROUPED_POLY_XML)
poly_root = poly_tree.getroot()

region_polys = defaultdict(list)
for poly in poly_root.findall("poly"):
    region = poly.get("type")
    shape_str = poly.get("shape")
    if region and shape_str:
        polygon = parseShape(shape_str)
        if polygon is not None:
            region_polys[region].append(polygon)

region_geoms = {}
for region, polys in region_polys.items():
    if polys:
        try:
            region_geoms[region] = unary_union(polys)
        except TopologicalError as e:
            print(f"[ERROR] Topology error in bassin {region}: {e}")

print("[CHECK] Bounding boxes (per basin):")
for region, geom in region_geoms.items():
    print(f"  {region}: {geom.bounds}")
# Out:
# [CHECK] Bounding boxes (per basin):
#   Marseille: (681071.41, 4782435.09, 707896.24, 4809844.54)
#   Aix-En-Provence: (675875.66, 4806237.37, 726750.02, 4846094.13)
#   Est-Etang-de-Berre: (661512.74, 4799268.23, 692628.4, 4824635.74)
#   Nord-Ouest: (657332.98, 4821077.14, 684620.21, 4848686.82)
#   Ouest-Etang-de-Berre: (640339.8, 4798892.24, 671498.4, 4834166.7)
#   Sud-Est: (702844.16, 4781624.45, 724169.27, 4813232.06)

# %%
net = sumolib.net.readNet(CLEANED_NET_XML_2)

# store edges per basin; plus list for those outside any basin ("hors_amp")
edges_by_region = defaultdict(list)
edges_hors      = []

for edge in net.getEdges():
    # skip technical source/sink edges created by netconvert
    if edge.getID().endswith("-source") or edge.getID().endswith("-sink"):
        continue

    shape = edge.getShape()
    if not shape:
        continue
    mid_pt = shape[len(shape) // 2]
    pt = Point(mid_pt[0], mid_pt[1])

    assigned = False
    for region, geom in region_geoms.items():
        if geom.contains(pt):
            edges_by_region[region].append(edge)
            assigned = True
            break
    if not assigned:
        edges_hors.append(edge)

# add "hors_amp" (outside) group
edges_by_region["hors_amp"] = edges_hors

# %%
taz_root = ET.Element("tazs")

for region, edges in edges_by_region.items():
    rid    = region.lower()
    taz_id = TAZ_IDS.get(rid)
    if not taz_id:
        print(f"[ERROR] No TAZ ID for {region}, skip")
        continue

    geom = region_geoms.get(region)
    if geom is None:
        B, I = [], edges[:]
    else:
        B = selectBoundaryEdges(edges, geom, threshold_ratio=0.1)
        I = [e for e in edges if e not in B]

    if region == "hors_amp":
        conns = edges[:]
    else:
        total = len(B) + len(I)
        nB    = int(BORDER_RATIO * total)
        nI    = total - nB
        conns = random.sample(B, min(nB, len(B))) + \
                random.sample(I, min(nI, len(I)))

    print(f"[CHECK] Basin {region}: total={len(edges)} | B={len(B)} | I={len(I)} | selected={len(conns)}")

    cent = geom.centroid if geom is not None else Point(0, 0)
    taz  = ET.SubElement(taz_root, "taz", id=str(taz_id), x=f"{cent.x:.2f}", y=f"{cent.y:.2f}")
    for e in sorted(conns, key=lambda _e: _e.getID()):
        ET.SubElement(taz, "tazSource", id=e.getID(), weight="1.0")
        ET.SubElement(taz, "tazSink",   id=e.getID(), weight="1.0")

ET.ElementTree(taz_root).write(TAZ_XML, encoding="utf-8", xml_declaration=True)
print(f"\n[DONE] TAZ file written to {TAZ_XML}")
# Out:
# [CHECK] Basin Aix-En-Provence: total=40267 | B=16029 | I=24238 | selected=40190
# [CHECK] Basin Ouest-Etang-de-Berre: total=21546 | B=19557 | I=1989 | selected=10607
# [CHECK] Basin Est-Etang-de-Berre: total=23540 | B=8919 | I=14621 | selected=23043
# [CHECK] Basin Marseille: total=31481 | B=16169 | I=15312 | selected=27904
# [CHECK] Basin Sud-Est: total=16139 | B=7154 | I=8985 | selected=15440
# [CHECK] Basin Nord-Ouest: total=14904 | B=9852 | I=5052 | selected=11013
# [CHECK] Basin hors_amp: total=17931 | B=0 | I=17931 | selected=17931
#
# [DONE] TAZ file written to /home/hoai-linh.dao/Works/EVCS/CEREMA-Mini/result/experiments/simulation-10percent-nonvtypes/taz.add.xml

# %% [markdown]
# ## Creating Ods

# %%
matrix_files = generateOds(
    MAIN_FLOW_CSV,
    ODS_DIR,
    TAZ_IDS,
    real_origin="marseille",
    exclude_cols={"total","intra"},
    trips_ratio=TRIPS_RATIO_5,
    scale_in=INCOMING_RATIO,
    scale_out=OUTGOING_RATIO
)


for hour, path in matrix_files:
    size = os.path.getsize(path)
    print(f"[DONE] OD matrix hour {hour}: {path} ({size} bytes)")
# Out:
# [DONE] OD matrix hour 4: /home/hoai-linh.dao/Works/EVCS/CEREMA-Mini/result/experiments/simulation-5percent-nonvtypes/ods/od_matrix_04.txt (1688 bytes)
# [DONE] OD matrix hour 5: /home/hoai-linh.dao/Works/EVCS/CEREMA-Mini/result/experiments/simulation-5percent-nonvtypes/ods/od_matrix_05.txt (1688 bytes)
# [DONE] OD matrix hour 6: /home/hoai-linh.dao/Works/EVCS/CEREMA-Mini/result/experiments/simulation-5percent-nonvtypes/ods/od_matrix_06.txt (1688 bytes)
# [DONE] OD matrix hour 7: /home/hoai-linh.dao/Works/EVCS/CEREMA-Mini/result/experiments/simulation-5percent-nonvtypes/ods/od_matrix_07.txt (1688 bytes)
# [DONE] OD matrix hour 8: /home/hoai-linh.dao/Works/EVCS/CEREMA-Mini/result/experiments/simulation-5percent-nonvtypes/ods/od_matrix_08.txt (1688 bytes)
# [DONE] OD matrix hour 9: /home/hoai-linh.dao/Works/EVCS/CEREMA-Mini/result/experiments/simulation-5percent-nonvtypes/ods/od_matrix_09.txt (1689 bytes)
# [DONE] OD matrix hour 10: /home/hoai-linh.dao/Works/EVCS/CEREMA-Mini/result/experiments/simulation-5percent-nonvtypes/ods/od_matrix_10.txt (1690 bytes)
# [DONE] OD matrix hour 11: /home/hoai-linh.dao/Works/EVCS/CEREMA-Mini/result/experiments/simulation-5percent-nonvtypes/ods/od_matrix_11.txt (1690 bytes)
# [DONE] OD matrix hour 12: /home/hoai-linh.dao/Works/EVCS/CEREMA-Mini/result/experiments/simulation-5percent-nonvtypes/ods/od_matrix_12.txt (1690 bytes)
# [DONE] OD matrix hour 13: /home/hoai-linh.dao/Works/EVCS/CEREMA-Mini/result/experiments/simulation-5percent-nonvtypes/ods/od_matrix_13.txt (1690 bytes)
# [DONE] OD matrix hour 14: /home/hoai-linh.dao/Works/EVCS/CEREMA-Mini/result/experiments/simulation-5percent-nonvtypes/ods/od_matrix_14.txt (1690 bytes)
# [DONE] OD matrix hour 15: /home/hoai-linh.dao/Works/EVCS/CEREMA-Mini/result/experiments/simulation-5percent-nonvtypes/ods/od_matrix_15.txt (1690 bytes)
# [DONE] OD matrix hour 16: /home/hoai-linh.dao/Works/EVCS/CEREMA-Mini/result/experiments/simulation-5percent-nonvtypes/ods/od_matrix_16.txt (1690 bytes)
# [DONE] OD matrix hour 17: /home/hoai-linh.dao/Works/EVCS/CEREMA-Mini/result/experiments/simulation-5percent-nonvtypes/ods/od_matrix_17.txt (1690 bytes)
# [DONE] OD matrix hour 18: /home/hoai-linh.dao/Works/EVCS/CEREMA-Mini/result/experiments/simulation-5percent-nonvtypes/ods/od_matrix_18.txt (1690 bytes)
# [DONE] OD matrix hour 19: /home/hoai-linh.dao/Works/EVCS/CEREMA-Mini/result/experiments/simulation-5percent-nonvtypes/ods/od_matrix_19.txt (1690 bytes)
# [DONE] OD matrix hour 20: /home/hoai-linh.dao/Works/EVCS/CEREMA-Mini/result/experiments/simulation-5percent-nonvtypes/ods/od_matrix_20.txt (1690 bytes)
# [DONE] OD matrix hour 21: /home/hoai-linh.dao/Works/EVCS/CEREMA-Mini/result/experiments/simulation-5percent-nonvtypes/ods/od_matrix_21.txt (1690 bytes)
# [DONE] OD matrix hour 22: /home/hoai-linh.dao/Works/EVCS/CEREMA-Mini/result/experiments/simulation-5percent-nonvtypes/ods/od_matrix_22.txt (1690 bytes)
# [DONE] OD matrix hour 23: /home/hoai-linh.dao/Works/EVCS/CEREMA-Mini/result/experiments/simulation-5percent-nonvtypes/ods/od_matrix_23.txt (1690 bytes)
# [DONE] OD matrix hour 0: /home/hoai-linh.dao/Works/EVCS/CEREMA-Mini/result/experiments/simulation-5percent-nonvtypes/ods/od_matrix_00.txt (1688 bytes)
# [DONE] OD matrix hour 1: /home/hoai-linh.dao/Works/EVCS/CEREMA-Mini/result/experiments/simulation-5percent-nonvtypes/ods/od_matrix_01.txt (1688 bytes)
# [DONE] OD matrix hour 2: /home/hoai-linh.dao/Works/EVCS/CEREMA-Mini/result/experiments/simulation-5percent-nonvtypes/ods/od_matrix_02.txt (1688 bytes)
# [DONE] OD matrix hour 3: /home/hoai-linh.dao/Works/EVCS/CEREMA-Mini/result/experiments/simulation-5percent-nonvtypes/ods/od_matrix_03.txt (1688 bytes)

# %% [markdown]
# ## Creating Vtypes Distribution (Optional)

# %%
assignProbabilitiesToVtypes(
    vtypes_xml=ORIG_VTYPES_XML,
    dist_id="vehDist",
    ev_brands=EV_BRANDS,
    ev_ratio=0.2,
    output_xml=VTYPES_DIST_XML
)
# Out:
# [DETECTED] There are 100 ICEs, 66 EVs
# [DONE] vType probabilities written to /home/hoai-linh.dao/Works/EVCS/CEREMA-Mini/result/experiments/simulation-10percent/vtypes-dist.add.xml

# %% [markdown]
# ## Creating Trips from Ods

# %%
print("Call od2trips for all ...")
trips_files = od2tripsForAll(TAZ_XML, TRIPS_DIR, ODS_DIR)
print()
print("[DONE] Finished 24 Trips based on hours.")

mergeTrips(TRIPS_DIR, ALL_TRIPS_XML)
# Out:
# Call od2trips for all ...
# Success.time 3597.70
# Generated /home/hoai-linh.dao/Works/EVCS/CEREMA-Mini/result/experiments/simulation-5percent-nonvtypes/trips/trips_00.xml
# Success.time 7195.21
# Generated /home/hoai-linh.dao/Works/EVCS/CEREMA-Mini/result/experiments/simulation-5percent-nonvtypes/trips/trips_01.xml
# Success.time 10788.00
# Generated /home/hoai-linh.dao/Works/EVCS/CEREMA-Mini/result/experiments/simulation-5percent-nonvtypes/trips/trips_02.xml
# Success.time 14318.18
# Generated /home/hoai-linh.dao/Works/EVCS/CEREMA-Mini/result/experiments/simulation-5percent-nonvtypes/trips/trips_03.xml
# Success.time 17960.00
# Generated /home/hoai-linh.dao/Works/EVCS/CEREMA-Mini/result/experiments/simulation-5percent-nonvtypes/trips/trips_04.xml
# Success.time 21595.38
# Generated /home/hoai-linh.dao/Works/EVCS/CEREMA-Mini/result/experiments/simulation-5percent-nonvtypes/trips/trips_05.xml
# Success.time 25198.49
# Generated /home/hoai-linh.dao/Works/EVCS/CEREMA-Mini/result/experiments/simulation-5percent-nonvtypes/trips/trips_06.xml
# Success.time 28799.62
# Generated /home/hoai-linh.dao/Works/EVCS/CEREMA-Mini/result/experiments/simulation-5percent-nonvtypes/trips/trips_07.xml
# Success.time 32399.33
# Generated /home/hoai-linh.dao/Works/EVCS/CEREMA-Mini/result/experiments/simulation-5percent-nonvtypes/trips/trips_08.xml
# Success.time 35999.39
# Generated /home/hoai-linh.dao/Works/EVCS/CEREMA-Mini/result/experiments/simulation-5percent-nonvtypes/trips/trips_09.xml
# Success.time 39599.75
# Generated /home/hoai-linh.dao/Works/EVCS/CEREMA-Mini/result/experiments/simulation-5percent-nonvtypes/trips/trips_10.xml
# Success.time 43199.75
# Generated /home/hoai-linh.dao/Works/EVCS/CEREMA-Mini/result/experiments/simulation-5percent-nonvtypes/trips/trips_11.xml
# Success.time 46798.94
# Generated /home/hoai-linh.dao/Works/EVCS/CEREMA-Mini/result/experiments/simulation-5percent-nonvtypes/trips/trips_12.xml
# Success.time 50399.78
# Generated /home/hoai-linh.dao/Works/EVCS/CEREMA-Mini/result/experiments/simulation-5percent-nonvtypes/trips/trips_13.xml
# Success.time 53999.76
# Generated /home/hoai-linh.dao/Works/EVCS/CEREMA-Mini/result/experiments/simulation-5percent-nonvtypes/trips/trips_14.xml
# Success.time 57599.22
# Generated /home/hoai-linh.dao/Works/EVCS/CEREMA-Mini/result/experiments/simulation-5percent-nonvtypes/trips/trips_15.xml
# Success.time 61199.78
# Generated /home/hoai-linh.dao/Works/EVCS/CEREMA-Mini/result/experiments/simulation-5percent-nonvtypes/trips/trips_16.xml
# Success.time 64799.84
# Generated /home/hoai-linh.dao/Works/EVCS/CEREMA-Mini/result/experiments/simulation-5percent-nonvtypes/trips/trips_17.xml
# Success.time 68399.85
# Generated /home/hoai-linh.dao/Works/EVCS/CEREMA-Mini/result/experiments/simulation-5percent-nonvtypes/trips/trips_18.xml
# Success.time 71999.38
# Generated /home/hoai-linh.dao/Works/EVCS/CEREMA-Mini/result/experiments/simulation-5percent-nonvtypes/trips/trips_19.xml
# Success.time 75599.07
# Generated /home/hoai-linh.dao/Works/EVCS/CEREMA-Mini/result/experiments/simulation-5percent-nonvtypes/trips/trips_20.xml
# Success.time 79199.48
# Generated /home/hoai-linh.dao/Works/EVCS/CEREMA-Mini/result/experiments/simulation-5percent-nonvtypes/trips/trips_21.xml
# Success.time 82799.03
# Generated /home/hoai-linh.dao/Works/EVCS/CEREMA-Mini/result/experiments/simulation-5percent-nonvtypes/trips/trips_22.xml
# Success.time 86398.49
# Generated /home/hoai-linh.dao/Works/EVCS/CEREMA-Mini/result/experiments/simulation-5percent-nonvtypes/trips/trips_23.xml
#
# [DONE] Finished 24 Trips based on hours.
# [DONE] Merged 24 trip files to /home/hoai-linh.dao/Works/EVCS/CEREMA-Mini/result/experiments/simulation-5percent-nonvtypes/trips.xml

# %% [markdown]
# ## Creating Route

# %%
DUAROUTER_ADDS = ",".join([str(VTYPES_DIST_XML), str(TAZ_XML)])
DUAROUTER_CMD = [
    "duarouter",
    "-n", CLEANED_NET_XML_2,            
    "-r", ALL_TRIPS_XML,            
    # "-a", DUAROUTER_ADDS,
    # "-a", VTYPES_DIST_XML, # Turn off for nonvtypes
    # "--keep-vtype-distributions",
    # "--with-taz",
    # "--repair",                      
    # "--remove-loops",               
    "--randomize-flows",         
    "-o", ROUTE_XML,    
    "--log", DUAROUTER_LOG,
    "--exit-times",
    "--named-routes",
    "--route-length",
    "--write-costs",
    "--ignore-errors"
]

print("Running DUAROUTER Step ...")
subprocess.run(DUAROUTER_CMD, check=True)
print(f"[DONE] Routes written in {ROUTE_XML}\n[LOG] Output logged in {DUAROUTER_LOG}")
# Out:
# Running DUAROUTER Step ...
# Success.up to time step: 86402.30ng up to time step: 24402.30ep: 48402.30ding up to time step: 72602.30
# [DONE] Routes written in /home/hoai-linh.dao/Works/EVCS/CEREMA-Mini/result/experiments/simulation-5percent-nonvtypes/route.xml
# [LOG] Output logged in /home/hoai-linh.dao/Works/EVCS/CEREMA-Mini/result/experiments/simulation-5percent-nonvtypes/logs/duarouter.log

# %% [markdown]
# ## Creating ReRouter (Optional)

# %%
REROUTING_CMD = [
    "python", REROUTING_PY,
    "-n", CLEANED_NET_XML_2,
    "-o", REROUTER_XML,
    "--vclass", "passenger",
]

with open(REROUTING_LOG, "w") as f:
    print("Running REROUTING Step ...")
    subprocess.run(REROUTING_CMD, stdout=f, stderr=subprocess.STDOUT, check=True)
    print(f"[DONE] Rerouter file is created in {REROUTER_XML}\n[LOG] Output logged in {REROUTING_LOG}")

# %% [markdown]
# ## Updating SUMOCFG

# %%
PATH_REPLACEMENTS = {
    'net-file': CLEANED_NET_XML_2,
    'route-files': ROUTE_XML,
    'summary-output': SUMMARY_XML,
    'tripinfo-output': TRIPINFO_XML,
    'fcd-output': TRACE_XML,
    'lanechange-output': LANECHANGES_XML,
    'battery-output': BATTERY_XML,
    'vehroute-output': VEHROUTES_XML,
    'collision-output': COLLISIONS_XML,
    'netstate-dump': NETSTATE_XML,
    'statistic-output': STATISTICS_XML,
    'log': LOG_TXT,
    'lanedata-output': LANEDATA_XML,
    'edgedata-output': EDGEDATA_XML,
    'device.ssm.file': SMS_XML,
    'emission-output': EMISSION_XML,
    'queue-output': QUEUE_XML
}
updateSumoCfg(
    cfg_path=SUMOCFG_XML,
    output_path=SUMOCFG_XML,
    replacements=PATH_REPLACEMENTS
)
# Out:
# Updating net-file: /home/hoai-linh.dao/Works/EVCS/CEREMA-Mini/result/net-repairment/cleaned_2_newtest-osm.net.xml -> /home/hoai-linh.dao/Works/EVCS/CEREMA-Mini/result/net-repairment/cleaned_2_newtest-osm.net.xml
# Updating route-files: /home/hoai-linh.dao/Works/EVCS/CEREMA-Mini/result/experiments/simulation-5percent-nonvtypes/route.xml -> /home/hoai-linh.dao/Works/EVCS/CEREMA-Mini/result/experiments/simulation-5percent-nonvtypes/route.xml
# Updating device.ssm.file: /home/hoai-linh.dao/Works/EVCS/CEREMA-Mini/result/experiments/simulation-5percent-nonvtypes/outputs/sms.xml -> /home/hoai-linh.dao/Works/EVCS/CEREMA-Mini/result/experiments/simulation-5percent-nonvtypes/outputs/sms.xml
# Updating statistic-output: /home/hoai-linh.dao/Works/EVCS/CEREMA-Mini/result/experiments/simulation-5percent-nonvtypes/outputs/statistics.xml -> /home/hoai-linh.dao/Works/EVCS/CEREMA-Mini/result/experiments/simulation-5percent-nonvtypes/outputs/statistics.xml
# Updating log: /home/hoai-linh.dao/Works/EVCS/CEREMA-Mini/result/experiments/simulation-5percent-nonvtypes/outputs/log.txt -> /home/hoai-linh.dao/Works/EVCS/CEREMA-Mini/result/experiments/simulation-5percent-nonvtypes/outputs/log.txt
# Updating summary-output: /home/hoai-linh.dao/Works/EVCS/CEREMA-Mini/result/experiments/simulation-5percent-nonvtypes/outputs/summary.xml -> /home/hoai-linh.dao/Works/EVCS/CEREMA-Mini/result/experiments/simulation-5percent-nonvtypes/outputs/summary.xml
# Updating tripinfo-output: /home/hoai-linh.dao/Works/EVCS/CEREMA-Mini/result/experiments/simulation-5percent-nonvtypes/outputs/tripinfo.xml -> /home/hoai-linh.dao/Works/EVCS/CEREMA-Mini/result/experiments/simulation-5percent-nonvtypes/outputs/tripinfo.xml
# Updating vehroute-output: /home/hoai-linh.dao/Works/EVCS/CEREMA-Mini/result/experiments/simulation-5percent-nonvtypes/outputs/vehRoutes.xml -> /home/hoai-linh.dao/Works/EVCS/CEREMA-Mini/result/experiments/simulation-5percent-nonvtypes/outputs/vehRoutes.xml
# Updating lanechange-output: /home/hoai-linh.dao/Works/EVCS/CEREMA-Mini/result/experiments/simulation-5percent-nonvtypes/outputs/laneChanges.xml -> /home/hoai-linh.dao/Works/EVCS/CEREMA-Mini/result/experiments/simulation-5percent-nonvtypes/outputs/laneChanges.xml
# Updating fcd-output: /home/hoai-linh.dao/Works/EVCS/CEREMA-Mini/result/experiments/simulation-5percent-nonvtypes/outputs/sumoTrace.xml -> /home/hoai-linh.dao/Works/EVCS/CEREMA-Mini/result/experiments/simulation-5percent-nonvtypes/outputs/sumoTrace.xml
# Updating battery-output: /home/hoai-linh.dao/Works/EVCS/CEREMA-Mini/result/experiments/simulation-5percent-nonvtypes/outputs/battery.xml -> /home/hoai-linh.dao/Works/EVCS/CEREMA-Mini/result/experiments/simulation-5percent-nonvtypes/outputs/battery.xml
# Updating collision-output: /home/hoai-linh.dao/Works/EVCS/CEREMA-Mini/result/experiments/simulation-5percent-nonvtypes/outputs/collisions.xml -> /home/hoai-linh.dao/Works/EVCS/CEREMA-Mini/result/experiments/simulation-5percent-nonvtypes/outputs/collisions.xml
# Updating edgedata-output: /home/hoai-linh.dao/Works/EVCS/CEREMA-Mini/result/experiments/simulation-5percent-nonvtypes/outputs/edgeData-60s.xml -> /home/hoai-linh.dao/Works/EVCS/CEREMA-Mini/result/experiments/simulation-5percent-nonvtypes/outputs/edgeData-60s.xml
# Updating lanedata-output: /home/hoai-linh.dao/Works/EVCS/CEREMA-Mini/result/experiments/simulation-5percent-nonvtypes/outputs/laneData-60s.xml -> /home/hoai-linh.dao/Works/EVCS/CEREMA-Mini/result/experiments/simulation-5percent-nonvtypes/outputs/laneData-60s.xml
# Updating queue-output: .../queue.xml -> /home/hoai-linh.dao/Works/EVCS/CEREMA-Mini/result/experiments/simulation-5percent-nonvtypes/outputs/queue.xml
# Updating emission-output: /home/hoai-linh.dao/Works/EVCS/CEREMA-Mini/result/experiments/simulation-5percent-nonvtypes/outputs/emission.xml -> /home/hoai-linh.dao/Works/EVCS/CEREMA-Mini/result/experiments/simulation-5percent-nonvtypes/outputs/emission.xml

# %% [markdown]
# ## Running

# %%
import multiprocessing, platform

info = {
    "OS": platform.platform(),
    "Python version": platform.python_version(),
    "Logical cores": multiprocessing.cpu_count()
}
print(info)
# Out:
# {'OS': 'Linux-6.1.135-1.el9.elrepo.x86_64-x86_64-with-glibc2.34', 'Python version': '3.10.16', 'Logical cores': 128}

# %%
import os
import sys
import time
import shutil
import subprocess
import collections
import argparse
import traci
import traci.constants as tc

SUMO_BINARY   = "sumo"                            #  hoặc "sumo-gui"
PORT          = 8873

THREADS     = 64
STEP_LENGTH = 1.0

GREEN_MIN   = 10
GREEN_MAX   = 60
QUEUE_TH    = 15

REPLAN_INT  = 60
OCC_TH      = 50
CONGEST_TH  = 0.25

# --------------------------------------------------
# 2.  TIỆN ÍCH
# --------------------------------------------------
def build_sumo_cmd():
    """List lệnh SUMO – KHÔNG chứa --remote-port (TraCI sẽ thêm)."""
    return [
        SUMO_BINARY,
        "-c", str(SUMOCFG_XML),
        "--step-length", str(STEP_LENGTH),
        "--threads", str(THREADS),
        "--no-step-log",
        "--duration-log.statistics",
        "--xml-validation", "never",
    ]

def ensure_log_dir():
    os.makedirs(SIMULATION_DIR, exist_ok=True)

def log(msg):
    print(time.strftime("[%H:%M:%S] "), msg, flush=True)

# --------------------------------------------------
# 3.  VÒNG LẶP TRACI
# --------------------------------------------------
def run_controller():
    ensure_log_dir()
    sumo_cmd = build_sumo_cmd()
    log("Starting SUMO: " + " ".join(sumo_cmd))

    # Truyền port=PORT – TraCI sẽ thêm đúng 1 lần --remote-port PORT
    traci.start(sumo_cmd, port=PORT)
    log("Connected to TraCI")

    phase_timer = collections.defaultdict(int)
    step        = 0
    last_replan = -REPLAN_INT

    try:
        while traci.simulation.getMinExpectedNumber() > 0:
            traci.simulationStep()
            step += 1
            PHASE_COUNT = {}

            # ---------- ĐIỀU KHIỂN ĐÈN ----------
            for tls_id in traci.trafficlight.getIDList():
                if tls_id not in PHASE_COUNT:
                    logic = traci.trafficlight.getCompleteRedYellowGreenDefinition(tls_id)[0]
                    PHASE_COUNT[tls_id] = len(logic.getPhases())

                lanes   = traci.trafficlight.getControlledLanes(tls_id)
                q_len   = [traci.lane.getLastStepHaltingNumber(l) for l in lanes]
                max_q   = max(q_len) if q_len else 0

                curr_ph = traci.trafficlight.getPhase(tls_id)
                phase_timer[(tls_id, curr_ph)] += 1
                num_ph  = PHASE_COUNT[tls_id]

                if (max_q > QUEUE_TH and phase_timer[(tls_id, curr_ph)] >= GREEN_MIN) or \
                phase_timer[(tls_id, curr_ph)] >= GREEN_MAX:
                    next_ph = (curr_ph + 1) % num_ph
                    traci.trafficlight.setPhase(tls_id, next_ph)
                    phase_timer[(tls_id, curr_ph)] = 0

            # ---------- PHÂN LUỒNG ----------
            if (step - last_replan) * STEP_LENGTH >= REPLAN_INT:
                last_replan = step
                edges     = traci.edge.getIDList()
                congested = {e for e in edges
                             if traci.edge.getLaneNumber(e) and
                                traci.edge.getLastStepOccupancy(e) > OCC_TH}

                if len(congested) / max(1, len(edges)) > CONGEST_TH:
                    for veh in traci.vehicle.getIDList():
                        route = traci.vehicle.getRoute(veh)
                        if route and route[0] in congested:
                            try:
                                traci.vehicle.rerouteTraveltime(veh)
                            except traci.TraCIException:
                                pass

    except (traci.exceptions.FatalTraCIError, KeyboardInterrupt):
        log("Simulation interrupted.")
    finally:
        traci.close()
        log("TraCI closed.")

# --------------------------------------------------
# 4.  MAIN
# --------------------------------------------------
if __name__ == "__main__":
    if "SUMO_HOME" not in os.environ:
        sys.exit("⚠️  Bạn cần đặt biến SUMO_HOME trước khi chạy.")
    # Thêm tools vào PYTHONPATH
    os.environ["PYTHONPATH"] = os.path.join(os.environ["SUMO_HOME"], "tools") + \
                               os.pathsep + os.environ.get("PYTHONPATH", "")

    try:
        run_controller()
        log("Simulation finished OK.")
    except subprocess.CalledProcessError as e:
        sys.exit(f"SUMO exited with error: {e}")
# Out:
# [00:05:51]  Starting SUMO: sumo -c /home/hoai-linh.dao/Works/EVCS/CEREMA-Mini/result/experiments/simulation-5percent-nonvtypes/run.sumocfg --step-length 1.0 --threads 64 --no-step-log --duration-log.statistics --xml-validation never
#  Retrying in 1 seconds
# ***Starting server on port 8873 ***
# Loading net-file from '/home/hoai-linh.dao/Works/EVCS/CEREMA-Mini/result/net-repairment/cleaned_2_newtest-osm.net.xml' ... done (24647ms).
# Loading route-files incrementally from '/home/hoai-linh.dao/Works/EVCS/CEREMA-Mini/result/experiments/simulation-5percent-nonvtypes/route.xml'
# Loading done.
# Vehicle 'h00_0' does not supply vehicle parameter 'device.ssm.thresholds'. Using default of ''.
# Vehicle 'h00_0' does not supply vehicle parameter 'device.ssm.trajectories'. Using default of '0'.
# Vehicle 'h00_0' does not supply vehicle parameter 'device.ssm.range'. Using default of '50.00'.
# Vehicle 'h00_0' does not supply vehicle parameter 'device.ssm.extratime'. Using default of '5.00'.
# Vehicle 'h00_0' does not supply vehicle parameter 'device.ssm.geo'. Using default of '0'.
# Vehicle 'h00_0' does not supply vehicle parameter 'device.ssm.write-positions'. Using default of '0'.
# Vehicle 'h00_0' does not supply vehicle parameter 'device.ssm.write-positions'. Using default of '0'.
# Vehicle 'h00_0' does not supply vehicle parameter 'device.ssm.exclude-conflict-types'. Using default of ''.
# Simulation version v1_22_0+0959-576b58424eb started with time: 0.00.
# [00:06:22]  Connected to TraCI
# Warning: The battery device is active for vehicle 'h00_12' but no emission class is set. Please consider setting an explicit emission class or battery outputs might be inconsistent with emission outputs!
# Warning: The battery device is active for vehicle 'h00_16' but no emission class is set. Please consider setting an explicit emission class or battery outputs might be inconsistent with emission outputs!
# Warning: The battery device is active for vehicle 'h00_20' but no emission class is set. Please consider setting an explicit emission class or battery outputs might be inconsistent with emission outputs!
# Warning: The battery device is active for vehicle 'h00_32' but no emission class is set. Please consider setting an explicit emission class or battery outputs might be inconsistent with emission outputs!
# Warning: The battery device is active for vehicle 'h00_36' but no emission class is set. Please consider setting an explicit emission class or battery outputs might be inconsistent with emission outputs!
# Warning: The battery device is active for vehicle 'h00_50' but no emission class is set. Please consider setting an explicit emission class or battery outputs might be inconsistent with emission outputs!
# Warning: The battery device is active for vehicle 'h00_53' but no emission class is set. Please consider setting an explicit emission class or battery outputs might be inconsistent with emission outputs!
# Warning: The battery device is active for vehicle 'h00_55' but no emission class is set. Please consider setting an explicit emission class or battery outputs might be inconsistent with emission outputs!
# Warning: The battery device is active for vehicle 'h00_58' but no emission class is set. Please consider setting an explicit emission class or battery outputs might be inconsistent with emission outputs!
# Warning: The battery device is active for vehicle 'h00_60' but no emission class is set. Please consider setting an explicit emission class or battery outputs might be inconsistent with emission outputs!
# Warning: The battery device is active for vehicle 'h00_66' but no emission class is set. Please consider setting an explicit emission class or battery outputs might be inconsistent with emission outputs!
# Warning: The battery device is active for vehicle 'h00_68' but no emission class is set. Please consider setting an explicit emission class or battery outputs might be inconsistent with emission outputs!
# Warning: The battery device is active for vehicle 'h00_838' but no emission class is set. Please consider setting an explicit emission class or battery outputs might be inconsistent with emission outputs!
# Warning: The battery device is active for vehicle 'h00_74' but no emission class is set. Please consider setting an explicit emission class or battery outputs might be inconsistent with emission outputs!
# Warning: The battery device is active for vehicle 'h00_77' but no emission class is set. Please consider setting an explicit emission class or battery outputs might be inconsistent with emission outputs!
# Warning: The battery device is active for vehicle 'h00_86' but no emission class is set. Please consider setting an explicit emission class or battery outputs might be inconsistent with emission outputs!
# Warning: The battery device is active for vehicle 'h00_92' but no emission class is set. Please consider setting an explicit emission class or battery outputs might be inconsistent with emission outputs!
# Warning: The battery device is active for vehicle 'h00_813' but no emission class is set. Please consider setting an explicit emission class or battery outputs might be inconsistent with emission outputs!
# Warning: The battery device is active for vehicle 'h00_868' but no emission class is set. Please consider setting an explicit emission class or battery outputs might be inconsistent with emission outputs!
# Warning: The battery device is active for vehicle 'h00_101' but no emission class is set. Please consider setting an explicit emission class or battery outputs might be inconsistent with emission outputs!
# Warning: The battery device is active for vehicle 'h00_107' but no emission class is set. Please consider setting an explicit emission class or battery outputs might be inconsistent with emission outputs!
# Warning: The battery device is active for vehicle 'h00_114' but no emission class is set. Please consider setting an explicit emission class or battery outputs might be inconsistent with emission outputs!
# Warning: The battery device is active for vehicle 'h00_122' but no emission class is set. Please consider setting an explicit emission class or battery outputs might be inconsistent with emission outputs!
# Warning: The battery device is active for vehicle 'h00_125' but no emission class is set. Please consider setting an explicit emission class or battery outputs might be inconsistent with emission outputs!
# Warning: The battery device is active for vehicle 'h00_135' but no emission class is set. Please consider setting an explicit emission class or battery outputs might be inconsistent with emission outputs!
# Warning: The battery device is active for vehicle 'h00_138' but no emission class is set. Please consider setting an explicit emission class or battery outputs might be inconsistent with emission outputs!
# Warning: The battery device is active for vehicle 'h00_140' but no emission class is set. Please consider setting an explicit emission class or battery outputs might be inconsistent with emission outputs!
# Warning: The battery device is active for vehicle 'h00_141' but no emission class is set. Please consider setting an explicit emission class or battery outputs might be inconsistent with emission outputs!
# Warning: The battery device is active for vehicle 'h00_142' but no emission class is set. Please consider setting an explicit emission class or battery outputs might be inconsistent with emission outputs!
# Warning: The battery device is active for vehicle 'h00_144' but no emission class is set. Please consider setting an explicit emission class or battery outputs might be inconsistent with emission outputs!
# Warning: The battery device is active for vehicle 'h00_145' but no emission class is set. Please consider setting an explicit emission class or battery outputs might be inconsistent with emission outputs!
# Warning: The battery device is active for vehicle 'h00_151' but no emission class is set. Please consider setting an explicit emission class or battery outputs might be inconsistent with emission outputs!
# Warning: The battery device is active for vehicle 'h00_155' but no emission class is set. Please consider setting an explicit emission class or battery outputs might be inconsistent with emission outputs!
# Warning: The battery device is active for vehicle 'h00_167' but no emission class is set. Please consider setting an explicit emission class or battery outputs might be inconsistent with emission outputs!
# Warning: The battery device is active for vehicle 'h00_168' but no emission class is set. Please consider setting an explicit emission class or battery outputs might be inconsistent with emission outputs!
# Warning: The battery device is active for vehicle 'h00_169' but no emission class is set. Please consider setting an explicit emission class or battery outputs might be inconsistent with emission outputs!
# Warning: The battery device is active for vehicle 'h00_170' but no emission class is set. Please consider setting an explicit emission class or battery outputs might be inconsistent with emission outputs!
# Warning: The battery device is active for vehicle 'h00_172' but no emission class is set. Please consider setting an explicit emission class or battery outputs might be inconsistent with emission outputs!
# Warning: The battery device is active for vehicle 'h00_173' but no emission class is set. Please consider setting an explicit emission class or battery outputs might be inconsistent with emission outputs!
# Warning: The battery device is active for vehicle 'h00_175' but no emission class is set. Please consider setting an explicit emission class or battery outputs might be inconsistent with emission outputs!
# Warning: The battery device is active for vehicle 'h00_177' but no emission class is set. Please consider setting an explicit emission class or battery outputs might be inconsistent with emission outputs!
# Warning: The battery device is active for vehicle 'h00_180' but no emission class is set. Please consider setting an explicit emission class or battery outputs might be inconsistent with emission outputs!
# Warning: The battery device is active for vehicle 'h00_182' but no emission class is set. Please consider setting an explicit emission class or battery outputs might be inconsistent with emission outputs!
# Warning: The battery device is active for vehicle 'h00_185' but no emission class is set. Please consider setting an explicit emission class or battery outputs might be inconsistent with emission outputs!
# Warning: The battery device is active for vehicle 'h00_187' but no emission class is set. Please consider setting an explicit emission class or battery outputs might be inconsistent with emission outputs!
# Warning: The battery device is active for vehicle 'h00_192' but no emission class is set. Please consider setting an explicit emission class or battery outputs might be inconsistent with emission outputs!
# Warning: The battery device is active for vehicle 'h00_197' but no emission class is set. Please consider setting an explicit emission class or battery outputs might be inconsistent with emission outputs!
# Warning: The battery device is active for vehicle 'h00_202' but no emission class is set. Please consider setting an explicit emission class or battery outputs might be inconsistent with emission outputs!
# Warning: The battery device is active for vehicle 'h00_205' but no emission class is set. Please consider setting an explicit emission class or battery outputs might be inconsistent with emission outputs!
# Warning: The battery device is active for vehicle 'h00_206' but no emission class is set. Please consider setting an explicit emission class or battery outputs might be inconsistent with emission outputs!
# Warning: The battery device is active for vehicle 'h00_841' but no emission class is set. Please consider setting an explicit emission class or battery outputs might be inconsistent with emission outputs!
# Warning: The battery device is active for vehicle 'h00_221' but no emission class is set. Please consider setting an explicit emission class or battery outputs might be inconsistent with emission outputs!
# Warning: The battery device is active for vehicle 'h00_223' but no emission class is set. Please consider setting an explicit emission class or battery outputs might be inconsistent with emission outputs!
# Warning: The battery device is active for vehicle 'h00_229' but no emission class is set. Please consider setting an explicit emission class or battery outputs might be inconsistent with emission outputs!
# Warning: The battery device is active for vehicle 'h00_230' but no emission class is set. Please consider setting an explicit emission class or battery outputs might be inconsistent with emission outputs!
# Warning: The battery device is active for vehicle 'h00_233' but no emission class is set. Please consider setting an explicit emission class or battery outputs might be inconsistent with emission outputs!
# Warning: The battery device is active for vehicle 'h00_821' but no emission class is set. Please consider setting an explicit emission class or battery outputs might be inconsistent with emission outputs!
# Warning: The battery device is active for vehicle 'h00_833' but no emission class is set. Please consider setting an explicit emission class or battery outputs might be inconsistent with emission outputs!
# Warning: The battery device is active for vehicle 'h00_244' but no emission class is set. Please consider setting an explicit emission class or battery outputs might be inconsistent with emission outputs!
# Warning: The battery device is active for vehicle 'h00_246' but no emission class is set. Please consider setting an explicit emission class or battery outputs might be inconsistent with emission outputs!
# Warning: The battery device is active for vehicle 'h00_247' but no emission class is set. Please consider setting an explicit emission class or battery outputs might be inconsistent with emission outputs!
# Warning: The battery device is active for vehicle 'h00_249' but no emission class is set. Please consider setting an explicit emission class or battery outputs might be inconsistent with emission outputs!
# Warning: The battery device is active for vehicle 'h00_253' but no emission class is set. Please consider setting an explicit emission class or battery outputs might be inconsistent with emission outputs!
# Warning: The battery device is active for vehicle 'h00_260' but no emission class is set. Please consider setting an explicit emission class or battery outputs might be inconsistent with emission outputs!
# Warning: The battery device is active for vehicle 'h00_263' but no emission class is set. Please consider setting an explicit emission class or battery outputs might be inconsistent with emission outputs!
# Warning: The battery device is active for vehicle 'h00_267' but no emission class is set. Please consider setting an explicit emission class or battery outputs might be inconsistent with emission outputs!
# Warning: The battery device is active for vehicle 'h00_842' but no emission class is set. Please consider setting an explicit emission class or battery outputs might be inconsistent with emission outputs!
# Warning: The battery device is active for vehicle 'h00_270' but no emission class is set. Please consider setting an explicit emission class or battery outputs might be inconsistent with emission outputs!
# Warning: The battery device is active for vehicle 'h00_802' but no emission class is set. Please consider setting an explicit emission class or battery outputs might be inconsistent with emission outputs!
# Warning: The battery device is active for vehicle 'h00_271' but no emission class is set. Please consider setting an explicit emission class or battery outputs might be inconsistent with emission outputs!
# Warning: The battery device is active for vehicle 'h00_272' but no emission class is set. Please consider setting an explicit emission class or battery outputs might be inconsistent with emission outputs!
# Warning: The battery device is active for vehicle 'h00_277' but no emission class is set. Please consider setting an explicit emission class or battery outputs might be inconsistent with emission outputs!
# Warning: The battery device is active for vehicle 'h00_279' but no emission class is set. Please consider setting an explicit emission class or battery outputs might be inconsistent with emission outputs!
# Warning: The battery device is active for vehicle 'h00_877' but no emission class is set. Please consider setting an explicit emission class or battery outputs might be inconsistent with emission outputs!
# Warning: The battery device is active for vehicle 'h00_288' but no emission class is set. Please consider setting an explicit emission class or battery outputs might be inconsistent with emission outputs!
# Warning: The battery device is active for vehicle 'h00_289' but no emission class is set. Please consider setting an explicit emission class or battery outputs might be inconsistent with emission outputs!
# Warning: The battery device is active for vehicle 'h00_292' but no emission class is set. Please consider setting an explicit emission class or battery outputs might be inconsistent with emission outputs!
# Warning: The battery device is active for vehicle 'h00_814' but no emission class is set. Please consider setting an explicit emission class or battery outputs might be inconsistent with emission outputs!
# Warning: The battery device is active for vehicle 'h00_294' but no emission class is set. Please consider setting an explicit emission class or battery outputs might be inconsistent with emission outputs!
# Warning: The battery device is active for vehicle 'h00_295' but no emission class is set. Please consider setting an explicit emission class or battery outputs might be inconsistent with emission outputs!
# Warning: The battery device is active for vehicle 'h00_297' but no emission class is set. Please consider setting an explicit emission class or battery outputs might be inconsistent with emission outputs!
# Warning: The battery device is active for vehicle 'h00_300' but no emission class is set. Please consider setting an explicit emission class or battery outputs might be inconsistent with emission outputs!
# Warning: The battery device is active for vehicle 'h00_310' but no emission class is set. Please consider setting an explicit emission class or battery outputs might be inconsistent with emission outputs!
# Warning: The battery device is active for vehicle 'h00_313' but no emission class is set. Please consider setting an explicit emission class or battery outputs might be inconsistent with emission outputs!
# Warning: The battery device is active for vehicle 'h00_788' but no emission class is set. Please consider setting an explicit emission class or battery outputs might be inconsistent with emission outputs!
# Warning: The battery device is active for vehicle 'h00_325' but no emission class is set. Please consider setting an explicit emission class or battery outputs might be inconsistent with emission outputs!
# Warning: The battery device is active for vehicle 'h00_331' but no emission class is set. Please consider setting an explicit emission class or battery outputs might be inconsistent with emission outputs!
# Warning: The battery device is active for vehicle 'h00_332' but no emission class is set. Please consider setting an explicit emission class or battery outputs might be inconsistent with emission outputs!
# Warning: The battery device is active for vehicle 'h00_336' but no emission class is set. Please consider setting an explicit emission class or battery outputs might be inconsistent with emission outputs!
# Warning: The battery device is active for vehicle 'h00_343' but no emission class is set. Please consider setting an explicit emission class or battery outputs might be inconsistent with emission outputs!
# Warning: The battery device is active for vehicle 'h00_345' but no emission class is set. Please consider setting an explicit emission class or battery outputs might be inconsistent with emission outputs!
# Warning: The battery device is active for vehicle 'h00_346' but no emission class is set. Please consider setting an explicit emission class or battery outputs might be inconsistent with emission outputs!
# Warning: The battery device is active for vehicle 'h00_347' but no emission class is set. Please consider setting an explicit emission class or battery outputs might be inconsistent with emission outputs!
# Warning: The battery device is active for vehicle 'h00_351' but no emission class is set. Please consider setting an explicit emission class or battery outputs might be inconsistent with emission outputs!
# Warning: The battery device is active for vehicle 'h00_366' but no emission class is set. Please consider setting an explicit emission class or battery outputs might be inconsistent with emission outputs!
# Warning: The battery device is active for vehicle 'h00_844' but no emission class is set. Please consider setting an explicit emission class or battery outputs might be inconsistent with emission outputs!
# Warning: The battery device is active for vehicle 'h00_375' but no emission class is set. Please consider setting an explicit emission class or battery outputs might be inconsistent with emission outputs!
# Warning: The battery device is active for vehicle 'h00_384' but no emission class is set. Please consider setting an explicit emission class or battery outputs might be inconsistent with emission outputs!
# Warning: The battery device is active for vehicle 'h00_387' but no emission class is set. Please consider setting an explicit emission class or battery outputs might be inconsistent with emission outputs!
# Warning: The battery device is active for vehicle 'h00_393' but no emission class is set. Please consider setting an explicit emission class or battery outputs might be inconsistent with emission outputs!
# Warning: The battery device is active for vehicle 'h00_399' but no emission class is set. Please consider setting an explicit emission class or battery outputs might be inconsistent with emission outputs!
# Warning: The battery device is active for vehicle 'h00_414' but no emission class is set. Please consider setting an explicit emission class or battery outputs might be inconsistent with emission outputs!
# Warning: The battery device is active for vehicle 'h00_421' but no emission class is set. Please consider setting an explicit emission class or battery outputs might be inconsistent with emission outputs!
# Warning: The battery device is active for vehicle 'h00_431' but no emission class is set. Please consider setting an explicit emission class or battery outputs might be inconsistent with emission outputs!
# Warning: The battery device is active for vehicle 'h00_435' but no emission class is set. Please consider setting an explicit emission class or battery outputs might be inconsistent with emission outputs!
# Warning: The battery device is active for vehicle 'h00_439' but no emission class is set. Please consider setting an explicit emission class or battery outputs might be inconsistent with emission outputs!
# Warning: The battery device is active for vehicle 'h00_880' but no emission class is set. Please consider setting an explicit emission class or battery outputs might be inconsistent with emission outputs!
# Warning: The battery device is active for vehicle 'h00_443' but no emission class is set. Please consider setting an explicit emission class or battery outputs might be inconsistent with emission outputs!
# Warning: The battery device is active for vehicle 'h00_444' but no emission class is set. Please consider setting an explicit emission class or battery outputs might be inconsistent with emission outputs!
# Warning: The battery device is active for vehicle 'h00_805' but no emission class is set. Please consider setting an explicit emission class or battery outputs might be inconsistent with emission outputs!
# Warning: The battery device is active for vehicle 'h00_451' but no emission class is set. Please consider setting an explicit emission class or battery outputs might be inconsistent with emission outputs!
# Warning: The battery device is active for vehicle 'h00_456' but no emission class is set. Please consider setting an explicit emission class or battery outputs might be inconsistent with emission outputs!
# Warning: The battery device is active for vehicle 'h00_460' but no emission class is set. Please consider setting an explicit emission class or battery outputs might be inconsistent with emission outputs!
# Warning: The battery device is active for vehicle 'h00_466' but no emission class is set. Please consider setting an explicit emission class or battery outputs might be inconsistent with emission outputs!
# Warning: The battery device is active for vehicle 'h00_469' but no emission class is set. Please consider setting an explicit emission class or battery outputs might be inconsistent with emission outputs!
# Warning: The battery device is active for vehicle 'h00_472' but no emission class is set. Please consider setting an explicit emission class or battery outputs might be inconsistent with emission outputs!
# Warning: The battery device is active for vehicle 'h00_881' but no emission class is set. Please consider setting an explicit emission class or battery outputs might be inconsistent with emission outputs!
# Warning: The battery device is active for vehicle 'h00_495' but no emission class is set. Please consider setting an explicit emission class or battery outputs might be inconsistent with emission outputs!
# Warning: The battery device is active for vehicle 'h00_500' but no emission class is set. Please consider setting an explicit emission class or battery outputs might be inconsistent with emission outputs!
# Warning: The battery device is active for vehicle 'h00_508' but no emission class is set. Please consider setting an explicit emission class or battery outputs might be inconsistent with emission outputs!
# Warning: The battery device is active for vehicle 'h00_509' but no emission class is set. Please consider setting an explicit emission class or battery outputs might be inconsistent with emission outputs!
# Warning: The battery device is active for vehicle 'h00_510' but no emission class is set. Please consider setting an explicit emission class or battery outputs might be inconsistent with emission outputs!
# Warning: The battery device is active for vehicle 'h00_806' but no emission class is set. Please consider setting an explicit emission class or battery outputs might be inconsistent with emission outputs!
# Warning: The battery device is active for vehicle 'h00_514' but no emission class is set. Please consider setting an explicit emission class or battery outputs might be inconsistent with emission outputs!
# Warning: The battery device is active for vehicle 'h00_515' but no emission class is set. Please consider setting an explicit emission class or battery outputs might be inconsistent with emission outputs!
# Warning: The battery device is active for vehicle 'h00_516' but no emission class is set. Please consider setting an explicit emission class or battery outputs might be inconsistent with emission outputs!
# Warning: The battery device is active for vehicle 'h00_528' but no emission class is set. Please consider setting an explicit emission class or battery outputs might be inconsistent with emission outputs!
# Warning: The battery device is active for vehicle 'h00_530' but no emission class is set. Please consider setting an explicit emission class or battery outputs might be inconsistent with emission outputs!
# Warning: The battery device is active for vehicle 'h00_537' but no emission class is set. Please consider setting an explicit emission class or battery outputs might be inconsistent with emission outputs!
# Warning: The battery device is active for vehicle 'h00_543' but no emission class is set. Please consider setting an explicit emission class or battery outputs might be inconsistent with emission outputs!
# Warning: The battery device is active for vehicle 'h00_882' but no emission class is set. Please consider setting an explicit emission class or battery outputs might be inconsistent with emission outputs!
# Warning: The battery device is active for vehicle 'h00_549' but no emission class is set. Please consider setting an explicit emission class or battery outputs might be inconsistent with emission outputs!
# Warning: The battery device is active for vehicle 'h00_559' but no emission class is set. Please consider setting an explicit emission class or battery outputs might be inconsistent with emission outputs!
# Warning: The battery device is active for vehicle 'h00_561' but no emission class is set. Please consider setting an explicit emission class or battery outputs might be inconsistent with emission outputs!
# Warning: The battery device is active for vehicle 'h00_564' but no emission class is set. Please consider setting an explicit emission class or battery outputs might be inconsistent with emission outputs!
# Warning: The battery device is active for vehicle 'h00_570' but no emission class is set. Please consider setting an explicit emission class or battery outputs might be inconsistent with emission outputs!
# Warning: The battery device is active for vehicle 'h00_586' but no emission class is set. Please consider setting an explicit emission class or battery outputs might be inconsistent with emission outputs!
# Warning: The battery device is active for vehicle 'h00_588' but no emission class is set. Please consider setting an explicit emission class or battery outputs might be inconsistent with emission outputs!
# Warning: The battery device is active for vehicle 'h00_593' but no emission class is set. Please consider setting an explicit emission class or battery outputs might be inconsistent with emission outputs!
# Warning: The battery device is active for vehicle 'h00_610' but no emission class is set. Please consider setting an explicit emission class or battery outputs might be inconsistent with emission outputs!
# Warning: The battery device is active for vehicle 'h00_849' but no emission class is set. Please consider setting an explicit emission class or battery outputs might be inconsistent with emission outputs!
# Warning: The battery device is active for vehicle 'h00_620' but no emission class is set. Please consider setting an explicit emission class or battery outputs might be inconsistent with emission outputs!
# Warning: The battery device is active for vehicle 'h00_627' but no emission class is set. Please consider setting an explicit emission class or battery outputs might be inconsistent with emission outputs!
# Warning: The battery device is active for vehicle 'h00_628' but no emission class is set. Please consider setting an explicit emission class or battery outputs might be inconsistent with emission outputs!
# Warning: The battery device is active for vehicle 'h00_630' but no emission class is set. Please consider setting an explicit emission class or battery outputs might be inconsistent with emission outputs!
# Warning: The battery device is active for vehicle 'h00_637' but no emission class is set. Please consider setting an explicit emission class or battery outputs might be inconsistent with emission outputs!
# Warning: The battery device is active for vehicle 'h00_640' but no emission class is set. Please consider setting an explicit emission class or battery outputs might be inconsistent with emission outputs!
# Warning: The battery device is active for vehicle 'h00_646' but no emission class is set. Please consider setting an explicit emission class or battery outputs might be inconsistent with emission outputs!
# Warning: The battery device is active for vehicle 'h00_648' but no emission class is set. Please consider setting an explicit emission class or battery outputs might be inconsistent with emission outputs!
# Warning: The battery device is active for vehicle 'h00_650' but no emission class is set. Please consider setting an explicit emission class or battery outputs might be inconsistent with emission outputs!
# Warning: The battery device is active for vehicle 'h00_653' but no emission class is set. Please consider setting an explicit emission class or battery outputs might be inconsistent with emission outputs!
# Warning: The battery device is active for vehicle 'h00_659' but no emission class is set. Please consider setting an explicit emission class or battery outputs might be inconsistent with emission outputs!
# Warning: The battery device is active for vehicle 'h00_664' but no emission class is set. Please consider setting an explicit emission class or battery outputs might be inconsistent with emission outputs!
# Warning: The battery device is active for vehicle 'h00_670' but no emission class is set. Please consider setting an explicit emission class or battery outputs might be inconsistent with emission outputs!
# Warning: The battery device is active for vehicle 'h00_671' but no emission class is set. Please consider setting an explicit emission class or battery outputs might be inconsistent with emission outputs!
# Warning: The battery device is active for vehicle 'h00_672' but no emission class is set. Please consider setting an explicit emission class or battery outputs might be inconsistent with emission outputs!
# Warning: The battery device is active for vehicle 'h00_674' but no emission class is set. Please consider setting an explicit emission class or battery outputs might be inconsistent with emission outputs!
# Warning: The battery device is active for vehicle 'h00_675' but no emission class is set. Please consider setting an explicit emission class or battery outputs might be inconsistent with emission outputs!
# Warning: The battery device is active for vehicle 'h00_681' but no emission class is set. Please consider setting an explicit emission class or battery outputs might be inconsistent with emission outputs!
# Warning: The battery device is active for vehicle 'h00_683' but no emission class is set. Please consider setting an explicit emission class or battery outputs might be inconsistent with emission outputs!
# Warning: The battery device is active for vehicle 'h00_685' but no emission class is set. Please consider setting an explicit emission class or battery outputs might be inconsistent with emission outputs!
# Warning: The battery device is active for vehicle 'h00_686' but no emission class is set. Please consider setting an explicit emission class or battery outputs might be inconsistent with emission outputs!
# Warning: The battery device is active for vehicle 'h00_695' but no emission class is set. Please consider setting an explicit emission class or battery outputs might be inconsistent with emission outputs!
# Warning: The battery device is active for vehicle 'h00_702' but no emission class is set. Please consider setting an explicit emission class or battery outputs might be inconsistent with emission outputs!
# Warning: The battery device is active for vehicle 'h00_830' but no emission class is set. Please consider setting an explicit emission class or battery outputs might be inconsistent with emission outputs!
# Warning: The battery device is active for vehicle 'h00_891' but no emission class is set. Please consider setting an explicit emission class or battery outputs might be inconsistent with emission outputs!
# Warning: The battery device is active for vehicle 'h00_709' but no emission class is set. Please consider setting an explicit emission class or battery outputs might be inconsistent with emission outputs!
# Warning: The battery device is active for vehicle 'h00_710' but no emission class is set. Please consider setting an explicit emission class or battery outputs might be inconsistent with emission outputs!
# Warning: The battery device is active for vehicle 'h00_711' but no emission class is set. Please consider setting an explicit emission class or battery outputs might be inconsistent with emission outputs!
# Warning: The battery device is active for vehicle 'h00_717' but no emission class is set. Please consider setting an explicit emission class or battery outputs might be inconsistent with emission outputs!
# Warning: The battery device is active for vehicle 'h00_724' but no emission class is set. Please consider setting an explicit emission class or battery outputs might be inconsistent with emission outputs!
# Warning: The battery device is active for vehicle 'h00_725' but no emission class is set. Please consider setting an explicit emission class or battery outputs might be inconsistent with emission outputs!
# Warning: The battery device is active for vehicle 'h00_726' but no emission class is set. Please consider setting an explicit emission class or battery outputs might be inconsistent with emission outputs!
# Warning: The battery device is active for vehicle 'h00_734' but no emission class is set. Please consider setting an explicit emission class or battery outputs might be inconsistent with emission outputs!
# Warning: The battery device is active for vehicle 'h00_737' but no emission class is set. Please consider setting an explicit emission class or battery outputs might be inconsistent with emission outputs!
# Warning: The battery device is active for vehicle 'h00_744' but no emission class is set. Please consider setting an explicit emission class or battery outputs might be inconsistent with emission outputs!
# Warning: The battery device is active for vehicle 'h00_747' but no emission class is set. Please consider setting an explicit emission class or battery outputs might be inconsistent with emission outputs!
# Warning: The battery device is active for vehicle 'h00_751' but no emission class is set. Please consider setting an explicit emission class or battery outputs might be inconsistent with emission outputs!
# Warning: The battery device is active for vehicle 'h00_810' but no emission class is set. Please consider setting an explicit emission class or battery outputs might be inconsistent with emission outputs!
# Warning: The battery device is active for vehicle 'h00_865' but no emission class is set. Please consider setting an explicit emission class or battery outputs might be inconsistent with emission outputs!
# Warning: The battery device is active for vehicle 'h00_886' but no emission class is set. Please consider setting an explicit emission class or battery outputs might be inconsistent with emission outputs!
# Warning: The battery device is active for vehicle 'h00_852' but no emission class is set. Please consider setting an explicit emission class or battery outputs might be inconsistent with emission outputs!
# Warning: The battery device is active for vehicle 'h00_759' but no emission class is set. Please consider setting an explicit emission class or battery outputs might be inconsistent with emission outputs!
# Warning: The battery device is active for vehicle 'h00_764' but no emission class is set. Please consider setting an explicit emission class or battery outputs might be inconsistent with emission outputs!
# Warning: The battery device is active for vehicle 'h00_770' but no emission class is set. Please consider setting an explicit emission class or battery outputs might be inconsistent with emission outputs!
# Warning: The battery device is active for vehicle 'h00_771' but no emission class is set. Please consider setting an explicit emission class or battery outputs might be inconsistent with emission outputs!
# Warning: The battery device is active for vehicle 'h00_775' but no emission class is set. Please consider setting an explicit emission class or battery outputs might be inconsistent with emission outputs!
# Warning: The battery device is active for vehicle 'h00_776' but no emission class is set. Please consider setting an explicit emission class or battery outputs might be inconsistent with emission outputs!
# Warning: The battery device is active for vehicle 'h00_779' but no emission class is set. Please consider setting an explicit emission class or battery outputs might be inconsistent with emission outputs!
# Simulation ended at time: 108.00.
# Reason: TraCI requested termination.
# Performance:
#  Duration: 744.59s
#  TraCI-Duration: 728.85s
#  Real time factor: 0.145046
#  UPS: 1.619681
# Vehicles:
#  Inserted: 22 (Loaded: 893)
#  Running: 22
#  Waiting: 0
# Statistics (avg of 22):
#  RouteLength: 339.05
#  Speed: 5.88
#  Duration: 54.82
#  WaitingTime: 17.95
#  TimeLoss: 31.93
#  DepartDelay: 0.45
#  DepartDelayWaiting: 0.42
# DijkstraRouter answered 6 queries and explored 9062.33 edges on average.
# DijkstraRouter spent 0.08s answering queries (13.33ms on average).
# [00:18:51]  TraCI closed.
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[3], line 116
#     112 os.environ["PYTHONPATH"] = os.path.join(os.environ["SUMO_HOME"], "tools") + \
#     113                            os.pathsep + os.environ.get("PYTHONPATH", "")
#     115 try:
# --> 116     run_controller()
#     117     log("Simulation finished OK.")
#     118 except subprocess.CalledProcessError as e:
#
# Cell In[3], line 78, in run_controller()
#      74 phase_timer[(tls_id, curr_ph)] += 1
#      76 if (max_q > QUEUE_TH and phase_timer[(tls_id, curr_ph)] >= GREEN_MIN) or \
#      77    phase_timer[(tls_id, curr_ph)] >= GREEN_MAX:
# ---> 78     next_ph = (curr_ph + 1) % traci.trafficlight.getPhaseNumber(tls_id)
#      79     traci.trafficlight.setPhase(tls_id, next_ph)
#      80     phase_timer[(tls_id, curr_ph)] = 0
#
# AttributeError: 'TrafficLightDomain' object has no attribute 'getPhaseNumber'

# %% [markdown]
# # **VISUALIZATIONS**

# %%
PLOT_CMD_1 = [
    "python", PLOTXMLATTRIBUTES_PY,
    VEHROUTES_XML,                 
    "-x", "depart",      
    "-y", "arrival",             
    "-o", PLOT_1_PNG,
    "--scatterplot"
]

subprocess.run(PLOT_CMD_1, check=True)
# Out:
# Warning: Skipped 131494 lines because of missing attributes 'arrival'.
# Figure(1400x900)
# CompletedProcess(args=['python', PosixPath('/home/hoai-linh.dao/Envs/sumo-env/lib/python3.10/site-packages/sumo/tools/visualization/plotXMLAttributes.py'), PosixPath('/home/hoai-linh.dao/Works/EVCS/CEREMA-Mini/result/experiments/simulation-10percent-nonvtypes/outputs/vehRoutes.xml'), '-x', 'depart', '-y', 'arrival', '-o', PosixPath('/home/hoai-linh.dao/Works/EVCS/CEREMA-Mini/result/experiments/simulation-10percent-nonvtypes/visualizations/plot_1.png'), '--scatterplot'], returncode=0)

# %%
PLOT_CMD_2 = [
    "python", PLOTXMLATTRIBUTES_PY,
    TRACE_XML,                 
    "-x", "x",     
    "-y", "y",             
    "-o", PLOT_2_PNG,
    "--scatterplot"
]

subprocess.run(PLOT_CMD_2, check=True)

# %%
! od2trips --help
# Out:
# Eclipse SUMO od2trips Version v1_22_0+0959-576b58424eb
#  Copyright (C) 2001-2025 German Aerospace Center (DLR) and others; https://sumo.dlr.de
# Importer of O/D-matrices for the microscopic, multi-modal traffic simulation
#  SUMO.
#
# Usage: od2trips [OPTION]*
# Configuration Options:
#   -c, --configuration-file FILE    Loads the named config on startup
#   -C, --save-configuration FILE    Saves current configuration into FILE
#   --save-configuration.relative    Enforce relative paths when saving the
#                                     configuration
#   --save-template FILE             Saves a configuration template (empty) into
#                                     FILE
#   --save-schema FILE               Saves the configuration schema into FILE
#   --save-commented                 Adds comments to saved template,
#                                     configuration, or schema
#
# Input Options:
#   -n, --taz-files FILE             Loads TAZ (districts;
#                                     also from networks) from FILE(s)
#   -d, --od-matrix-files FILE       Loads O/D-files from FILE(s)
#   --od-amitran-files FILE          Loads O/D-matrix in Amitran format from
#                                     FILE(s)
#   -z, --tazrelation-files FILE     Loads O/D-matrix in tazRelation format from
#                                     FILE(s)
#   --tazrelation-attribute STR      Define data attribute for loading counts
#                                     (default 'count')
#
# Output Options:
#   --write-license                  Include license info into every output file
#   --output-prefix STR              Prefix which is applied to all output files.
#                                     The special string 'TIME' is replaced by the
#                                     current time.
#   --precision INT                  Defines the number of digits after the comma
#                                     for floating point output
#   --precision.geo INT              Defines the number of digits after the comma
#                                     for lon,lat output
#   -H, --human-readable-time        Write time values as hour:minute:second or
#                                     day:hour:minute:second rather than seconds
#   -o, --output-file FILE           Writes trip definitions into FILE
#   --flow-output FILE               Writes flow definitions into FILE
#   --flow-output.probability        Writes probabilistic flow instead of evenly
#                                     spaced flow
#   --pedestrians                    Writes pedestrians instead of vehicles
#   --persontrips                    Writes persontrips instead of vehicles
#   --persontrips.modes STR[]        Add modes attribute to personTrips
#   --ignore-vehicle-type            Does not save vtype information
#   --junctions                      Writes trips between junctions
#
# Time Options:
#   -b, --begin TIME                 Defines the begin time;
#                                     Previous trips will be discarded
#   -e, --end TIME                   Defines the end time;
#                                     Later trips will be discarded;
#                                     Defaults to the maximum time that SUMO can
#                                     represent
#
# Processing Options:
#   -s, --scale FLOAT                Scales the loaded flows by FLOAT
#   --spread.uniform                 Spreads trips uniformly over each time
#                                     period
#   --different-source-sink          Always choose source and sink edge which are
#                                     not identical
#   --vtype STR                      Defines the name of the vehicle type to use
#   --prefix STR                     Defines the prefix for vehicle names
#   --timeline STR[]                 Uses STR[] as a timeline definition
#   --timeline.day-in-hours          Uses STR as a 24h-timeline definition
#   --no-step-log                    Disable console output of current time step
#
# Defaults Options:
#   --departlane STR                 Assigns a default depart lane
#   --departpos STR                  Assigns a default depart position
#   --departspeed STR                Assigns a default depart speed
#   --arrivallane STR                Assigns a default arrival lane
#   --arrivalpos STR                 Assigns a default arrival position
#   --arrivalspeed STR               Assigns a default arrival speed
#
# Report Options:
#   -v, --verbose                    Switches to verbose output
#   --print-options                  Prints option values before processing
#   -?, --help                       Prints this screen or selected topics
#   -V, --version                    Prints the current version
#   -X, --xml-validation STR         Set schema validation scheme of XML inputs
#                                     ("never", "local", "auto" or "always")
#   -W, --no-warnings                Disables output of warnings
#   --aggregate-warnings INT         Aggregate warnings of the same type whenever
#                                     more than INT occur
#   -l, --log FILE                   Writes all messages to FILE (implies
#                                     verbose)
#   --message-log FILE               Writes all non-error messages to FILE
#                                     (implies verbose)
#   --error-log FILE                 Writes all warnings and errors to FILE
#   --log.timestamps                 Writes timestamps in front of all messages
#   --log.processid                  Writes process ID in front of all messages
#   --language STR                   Language to use in messages
#   --ignore-errors                  Continue on broken input
#
# Random Number Options:
#   --random                         Initialises the random number generator with
#                                     the current system time
#   --seed INT                       Initialises the random number generator with
#                                     the given value
#
#
# Examples:
#   od2trips -c <CONFIGURATION>
#     run with configuration file
#
# Report bugs at <https://github.com/eclipse-sumo/sumo/issues>.
# Get in contact via <sumo@dlr.de>.
