# %%
#!/usr/bin/env python3
import os
import re
from pathlib import Path

# --------------------------------------------------------------------
# 1. Thay đường dẫn cho phù hợp
# --------------------------------------------------------------------
SMOOTH_ROUTES_DIR   = "/home/hoai-linh.dao/Works/EVCS/CEREMA-Mini/data/processed-data/total_scenario/smooth-routes"
OUTPUT_INTER_ROUTES = "/home/hoai-linh.dao/Works/EVCS/CEREMA-Mini/data/processed-data/total_scenario/new-strategy/routes_inter_all.xml"

# --------------------------------------------------------------------
# 2. Biến toàn cục để track đã seen ID
# --------------------------------------------------------------------
seen_vtype = set()
seen_route = set()

# Pattern để phát hiện vType id="..."
_pattern_vtype = re.compile(r'<\s*vType\b[^>]*\bid\s*=\s*"([^"]+)"')
# Pattern để phát hiện route id="..."
_pattern_route = re.compile(r'<\s*route\b[^>]*\bid\s*=\s*"([^"]+)"')
# Pattern để phát hiện vehicle with fromTaz="X" toTaz="Y"
# Dùng non-greedy để bắt đúng giá trị
_pattern_vehicle = re.compile(
    r'<\s*vehicle\b[^>]*\bfromTaz\s*=\s*"([^"]+)"[^>]*\btoTaz\s*=\s*"([^"]+)"'
)

def merge_inter_routes_linebased():
    # Mở file output
    os.makedirs(os.path.dirname(OUTPUT_INTER_ROUTES), exist_ok=True)
    fout = open(OUTPUT_INTER_ROUTES, "w", encoding="utf-8")

    # 1) Ghi header <routes>
    fout.write('<?xml version="1.0" encoding="UTF-8"?>\n')
    fout.write('<routes xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance"\n')
    fout.write('        xsi:noNamespaceSchemaLocation="http://sumo.dlr.de/xsd/routes_file.xsd">\n')

    # 2) Duyệt từng file trong SMOOTH_ROUTES_DIR
    for file_path in sorted(Path(SMOOTH_ROUTES_DIR).iterdir(), key=lambda p: p.name):
        name = file_path.name
        # Chỉ lấy file routes_*.xml, không lấy routes_*.alt.xml hoặc routes_*.log
        if not name.startswith("routes_") or not name.endswith(".xml") or name.endswith(".alt.xml"):
            continue

        with open(file_path, "r", encoding="utf-8") as fin:
            for raw_line in fin:
                line = raw_line.strip()
                if not line:
                    continue

                # 2.1. Nếu là <vType ... id="VID" .../>
                if line.startswith("<vType"):
                    m = _pattern_vtype.search(line)
                    if m:
                        vid = m.group(1)
                        if vid not in seen_vtype:
                            seen_vtype.add(vid)
                            fout.write(f"    {line}\n")
                    continue

                # 2.2. Nếu là <route id="RID" .../>
                if line.startswith("<route"):
                    m = _pattern_route.search(line)
                    if m:
                        rid = m.group(1)
                        if rid not in seen_route:
                            seen_route.add(rid)
                            fout.write(f"    {line}\n")
                    continue

                # 2.3. Nếu là <vehicle ... fromTaz="X" ... toTaz="Y" .../>
                if line.startswith("<vehicle"):
                    m = _pattern_vehicle.search(line)
                    if m:
                        from_taz = m.group(1)
                        to_taz   = m.group(2)
                        if from_taz != to_taz:
                            fout.write(f"    {line}\n")
                    continue

                # Mọi dòng khác (routeDistribution, flow, comment, log, alt, ...) bỏ qua

    # 3) Đóng thẻ </routes>
    fout.write("</routes>\n")
    fout.close()
    print(f"Đã gộp xong routes_inter_all.xml tại: {OUTPUT_INTER_ROUTES}")


if __name__ == "__main__":
    merge_inter_routes_linebased()
# Out:
# Đã gộp xong routes_inter_all.xml tại: /home/hoai-linh.dao/Works/EVCS/CEREMA-Mini/data/processed-data/total_scenario/new-strategy/routes_inter_all.xml

# %%
#!/usr/bin/env python3
import os
import csv
import traci
from sumolib import checkBinary
import xml.etree.ElementTree as ET

# --------------------------------------------------------------------
# 1. Cấu hình các đường dẫn (điều chỉnh cho đúng chỗ của bạn)
# --------------------------------------------------------------------
NET_XML          = "/home/hoai-linh.dao/Works/EVCS/CEREMA-Mini/result/net-creation/310525-AMP-test-func/connected-network.net.xml"
VTYPES_XML       = "/home/hoai-linh.dao/Works/EVCS/CEREMA-Mini/data/additional-files/vtypes/eidm-1.xml"
ROUTES_INTER_ALL = "/home/hoai-linh.dao/Works/EVCS/CEREMA-Mini/data/processed-data/total_scenario/new-strategy/routes_inter_all.xml"
TAZ_XML          = "/home/hoai-linh.dao/Works/EVCS/CEREMA-Mini/result/net-creation/310525-AMP-test-func/taz.xml"
CROSSING_LOG_CSV = "/home/hoai-linh.dao/Works/EVCS/CEREMA-Mini/data/processed-data/total_scenario/new-strategy/crossing_log.csv"

os.environ["LD_LIBRARY_PATH"] = os.path.expanduser("~/Libs/libnsl")
os.environ["SUMO_HOME"] = os.path.expanduser("~/Envs/sumo-env/lib/python3.10/site-packages/sumo")

SIM_END          = 24 * 3600   # Giả sử chạy đủ 24h

# --------------------------------------------------------------------
# 2. Hàm đọc TAZ_XML, build edge_to_taz
# --------------------------------------------------------------------
def load_edge_to_taz(taz_file: str) -> dict[str, str]:
    """
    Đọc TAZ_XML, tạo dict { edgeID: tazID } từ <tazSource id="..."/> và <tazSink id="..."/>.
    Giả định <taz id="Z">, mỗi <tazSource id="E"/> hoặc <tazSink id="E"/> chỉ ra
    rằng edge E được xem là 'biên' (entry/exit) của zone Z (và ta gán region = Z).
    """
    edge_to_taz: dict[str, str] = {}
    tree = ET.parse(taz_file)
    root = tree.getroot()
    for taz in root.findall(".//taz"):
        zid = taz.get("id")
        if zid is None:
            continue
        for src in taz.findall("tazSource"):
            eid = src.get("id")
            if eid:
                edge_to_taz[eid] = zid
        for sink in taz.findall("tazSink"):
            eid = sink.get("id")
            if eid:
                edge_to_taz[eid] = zid
    print(f"[INFO] load_edge_to_taz: Đã đọc {len(edge_to_taz)} biên từ TAZ_XML")
    return edge_to_taz

# --------------------------------------------------------------------
# 3. Chạy Inter-region Simulation, ghi crossing_log.csv
# --------------------------------------------------------------------
def run_inter_region():
    edge_to_taz = load_edge_to_taz(TAZ_XML)

    # Mở CSV để ghi header
    with open(CROSSING_LOG_CSV, "w", newline="") as csvfile:
        writer = csv.writer(csvfile)
        writer.writerow([
            "vehID",      # ID gốc của vehicle
            "departTime", # thời điểm nó depart
            "enterTime",  # thời điểm nó chạm biên (vào TAZ mới)
            "fromTaz",    # TAZ gốc
            "toTaz",      # TAZ đích (theo attr trong <vehicle>)
            "fromRegion", # = fromTaz (vì region = taz)
            "toRegion",   # region đích = toTaz
            "borderEdge", # edge mà nó chạm vào biên
            "vType"       # loại phương tiện
        ])

    # Các dict lưu trạng thái
    veh_origin_taz: dict[str, str] = {}   # vehID -> fromTaz
    veh_depart_time: dict[str, float] = {}# vehID -> departTime
    veh_logged: dict[str, bool] = {}      # vehID -> đã log crossing?

    # SUMO command
    sumo_cmd = [
        checkBinary("sumo"),
        "-n", NET_XML,
        # "--additional-files", VTYPES_XML,    # Nếu cần dùng thêm vtypes
        "-r", ROUTES_INTER_ALL,
        "--no-step-log", "true",
        "--step-length", "1.0",
        "--start", "true"
    ]
    print("[RUN ]", " ".join(sumo_cmd))
    traci.start(sumo_cmd)

    sim_time = 0
    while sim_time <= SIM_END:
        traci.simulationStep()

        # 3.4.1: Lấy danh sách xe vừa depart, lưu depart_time và fromTaz
        for vehID in traci.simulation.getDepartedIDList():
            from_taz = traci.vehicle.getParameter(vehID, "fromTaz")
            to_taz   = traci.vehicle.getParameter(vehID, "toTaz")
            if from_taz is None or to_taz is None:
                continue
            veh_origin_taz[vehID] = from_taz
            veh_depart_time[vehID] = sim_time  # lưu thời điểm depart = sim_time
            veh_logged[vehID] = False

        # 3.4.2: Duyệt toàn bộ xe đang chạy
        for vehID in traci.vehicle.getIDList():
            # Nếu đã log crossing, bỏ qua
            if veh_logged.get(vehID, False):
                continue

            current_edge = traci.vehicle.getRoadID(vehID)
            if current_edge not in edge_to_taz:
                # Chưa chạm biên
                continue

            entered_taz = edge_to_taz[current_edge]
            origin_taz  = veh_origin_taz.get(vehID)
            # Nếu indeed crossing: entered_taz ≠ origin_taz
            if origin_taz is not None and entered_taz != origin_taz:
                enter_time = sim_time
                vtype      = traci.vehicle.getTypeID(vehID)
                depart_time= veh_depart_time.get(vehID, 0.0)
                to_taz     = traci.vehicle.getParameter(vehID, "toTaz") or ""

                with open(CROSSING_LOG_CSV, "a", newline="") as csvfile:
                    writer = csv.writer(csvfile)
                    writer.writerow([
                        vehID,
                        f"{depart_time:.2f}",
                        f"{enter_time:.2f}",
                        origin_taz,
                        to_taz,
                        origin_taz,    # fromRegion = origin_taz
                        entered_taz,   # toRegion = entered_taz
                        current_edge,
                        vtype
                    ])
                veh_logged[vehID] = True

        sim_time += 1

    traci.close()
    print("[DONE] Inter-region kết thúc. Log đã ghi vào:", CROSSING_LOG_CSV)


if __name__ == "__main__":
    run_inter_region()
# Out:
# [INFO] load_edge_to_taz: Đã đọc 81242 biên từ TAZ_XML
# [RUN ] /home/hoai-linh.dao/Envs/sumo-env/lib/python3.10/site-packages/sumo/bin/sumo -n /home/hoai-linh.dao/Works/EVCS/CEREMA-Mini/result/net-creation/310525-AMP-test-func/connected-network.net.xml -r /home/hoai-linh.dao/Works/EVCS/CEREMA-Mini/data/processed-data/total_scenario/new-strategy/routes_inter_all.xml --no-step-log true --step-length 1.0 --start true
#  Retrying in 1 seconds
# Warning: Vehicle 'h00_1of1_2546' performs emergency braking on lane '5072463#2_0' with decel=9.00, wished=4.00, severity=1.00, time=3952.00.
# Warning: Vehicle 'h01_1of1_1141' performs emergency braking on lane '34960794#0_0' with decel=9.00, wished=4.00, severity=1.00, time=4849.00.
# Warning: Vehicle 'h00_1of1_1436' performs emergency braking on lane '119213315#2_0' with decel=9.00, wished=4.00, severity=1.00, time=4942.00.
# Warning: Vehicle 'h01_1of1_1867' performs emergency braking on lane ':269367665_2_0' with decel=9.00, wished=4.00, severity=1.00, time=5119.00.
# Warning: Vehicle 'h00_1of1_3583' performs emergency braking on lane '872881247#0_0' with decel=9.00, wished=4.00, severity=1.00, time=5212.00.
# Warning: Vehicle 'h01_1of1_2636' performs emergency braking on lane '326390748#0_0' with decel=9.00, wished=4.00, severity=1.00, time=5569.00.
# Warning: Vehicle 'h01_1of1_3294' performs emergency braking on lane '-201102549#1_0' with decel=9.00, wished=4.00, severity=1.00, time=6382.00.
# Warning: Vehicle 'h01_1of1_2305' performs emergency braking on lane '-35155868#4_0' with decel=9.00, wished=4.00, severity=1.00, time=6562.00.
# Warning: Vehicle 'h01_1of1_1947' performs emergency braking on lane ':304964095_4_1' with decel=9.00, wished=4.00, severity=1.00, time=6739.00.
# Warning: Vehicle 'h01_1of1_1233' performs emergency braking on lane '6313524#11_0' with decel=9.00, wished=4.00, severity=1.00, time=6922.00.
# Warning: Vehicle 'h02_1of1_606' performs emergency braking on lane '388202560#0_0' with decel=9.00, wished=4.00, severity=1.00, time=7639.00.
# Warning: Vehicle 'h02_1of1_724' performs emergency braking on lane '23976225_0' with decel=9.00, wished=4.00, severity=1.00, time=10252.00.
# Warning: Vehicle 'h02_1of1_559' performs emergency braking on lane '-201101698#2_0' with decel=9.00, wished=4.00, severity=1.00, time=11872.00.
# Warning: Vehicle 'h03_1of1_7' performs emergency braking on lane '28051104#0_2' with decel=9.00, wished=4.00, severity=1.00, time=12589.00.
# Warning: Vehicle 'h03_1of1_900' performs emergency braking on lane ':2291849273_1_1' with decel=9.00, wished=4.00, severity=1.00, time=14032.00.
# Warning: Vehicle 'h04_1of1_6809' performs emergency braking on lane '-162767523#5_0' with decel=9.00, wished=4.00, severity=1.00, time=14750.00.
# Warning: Vehicle 'h04_1of1_6011' performs emergency braking on lane '326390748#0_0' with decel=9.00, wished=4.00, severity=1.00, time=15199.00.
# Warning: Vehicle 'h04_1of1_8959' performs emergency braking on lane ':504646898_0_0' with decel=9.00, wished=4.00, severity=1.00, time=15740.00.
# Warning: Vehicle 'h04_1of1_6937' performs emergency braking on lane ':26761382_0_0' with decel=9.00, wished=4.00, severity=1.00, time=16549.00.
# Warning: Vehicle 'h03_1of1_899' performs emergency braking on lane ':414760781_4_0' with decel=9.00, wished=4.00, severity=1.00, time=17629.00.
# Warning: Vehicle 'h04_1of1_2355' performs emergency braking on lane '35163311#1_0' with decel=9.00, wished=4.00, severity=1.00, time=18344.00.
# Warning: Vehicle 'h05_1of1_26423' performs emergency braking on lane '795692748#1_0' with decel=9.00, wished=4.00, severity=1.00, time=18532.00.
# Warning: Vehicle 'h04_1of1_4257' performs emergency braking on lane '129088232#3_0' with decel=9.00, wished=4.00, severity=1.00, time=18619.00.
# Warning: Vehicle 'h05_1of1_20651' performs emergency braking on lane ':4153077803_2_0' with decel=9.00, wished=4.00, severity=1.00, time=19162.00.
# Warning: Vehicle 'h05_1of1_10378' performs emergency braking on lane '626118645_0' with decel=9.00, wished=4.00, severity=1.00, time=19339.00.
# Warning: Vehicle 'h05_1of1_10344' performs emergency braking on lane '403909949#1_0' with decel=9.00, wished=4.00, severity=1.00, time=19432.00.
# Warning: Vehicle 'h05_1of1_30358' performs emergency braking on lane '-326356012#2_0' with decel=9.00, wished=4.00, severity=1.00, time=19522.00.
# Warning: Teleporting vehicle 'h05_1of1_11142'; waited too long (yield), lane='-614080167#1_0', time=19776.00.
# Warning: Vehicle 'h05_1of1_11142' ends teleporting on edge '267197984', time=19776.00.
# Warning: Vehicle 'h05_1of1_19831' performs emergency braking on lane '984453684#1_0' with decel=9.00, wished=4.00, severity=1.00, time=19792.00.
# Warning: Vehicle 'h05_1of1_20985' performs emergency braking on lane ':1147563268_3_0' with decel=9.00, wished=4.00, severity=1.00, time=19969.00.
# Warning: Vehicle 'h05_1of1_20124' performs emergency braking on lane '99205761#6_0' with decel=9.00, wished=4.00, severity=1.00, time=20059.00.
# Warning: Vehicle 'h05_1of1_10989' performs emergency braking on lane '758217784#3_0' with decel=9.00, wished=4.00, severity=1.00, time=20199.00.
# Warning: Vehicle 'h05_1of1_26665' performs emergency braking on lane '414118227#0_0' with decel=9.00, wished=4.00, severity=1.00, time=20240.00.
# Warning: Vehicle 'h05_1of1_10396' performs emergency braking on lane '326390748#0_0' with decel=9.00, wished=4.00, severity=1.00, time=20419.00.
# Warning: Vehicle 'h05_1of1_10446' performs emergency braking on lane '436469878#2_1' with decel=9.00, wished=4.00, severity=1.00, time=20509.00.
# Warning: Vehicle 'h05_1of1_11200' performs emergency braking on lane ':674532849_8_0' with decel=9.00, wished=4.00, severity=1.00, time=20599.00.
# Warning: Vehicle 'h05_1of1_10672' performs emergency braking on lane '49191961#0_0' with decel=9.00, wished=4.00, severity=1.00, time=20779.00.
# Warning: Vehicle 'h05_1of1_11469' performs emergency braking on lane '-577143178#2_0' with decel=9.00, wished=4.00, severity=1.00, time=20959.00.
# Warning: Vehicle 'h04_1of1_6892' performs emergency braking on lane '91672829#3_0' with decel=9.00, wished=4.00, severity=1.00, time=20959.00.
# Warning: Vehicle 'h05_1of1_29960' performs emergency braking on lane '28051104#0_2' with decel=9.00, wished=4.00, severity=1.00, time=21049.00.
# Warning: Vehicle 'h05_1of1_10788' performs emergency braking on lane '-91672797#3_0' with decel=9.00, wished=4.00, severity=1.00, time=21139.00.
# Warning: Teleporting vehicle 'h05_1of1_11589'; waited too long (jam), lane=':1157599035_4_0', time=21223.00.
# Warning: Teleporting vehicle 'h05_1of1_20479'; waited too long (yield), lane='-26537748#0_0', time=21223.00.
# Warning: Vehicle 'h05_1of1_11589' ends teleporting on edge '398891915#1', time=21223.00.
# Warning: Vehicle 'h05_1of1_20479' ends teleporting on edge '100143560#7', time=21223.00.
# Warning: Vehicle 'h05_1of1_10349' performs emergency braking on lane '579502115#1_0' with decel=9.00, wished=4.00, severity=1.00, time=21229.00.
# Warning: Vehicle 'h05_1of1_10873' performs emergency braking on lane ':3831495623_0_0' with decel=9.00, wished=4.00, severity=1.00, time=21230.00.
# Warning: Vehicle 'h05_1of1_39338' performs emergency braking on lane '-61539759#0_0' with decel=9.00, wished=4.00, severity=1.00, time=21560.00.
# Warning: Vehicle 'h05_1of1_26663' performs emergency braking on lane '32566250#11_0' with decel=9.00, wished=4.00, severity=1.00, time=21589.00.
# Warning: Vehicle 'h05_1of1_20663' performs emergency braking on lane ':4232157451_2_0' with decel=9.00, wished=4.00, severity=1.00, time=21589.00.
# Warning: Vehicle 'h05_1of1_10962' performs emergency braking on lane ':12156594_1_0' with decel=9.00, wished=4.00, severity=1.00, time=21682.00.
# Warning: Vehicle 'h05_1of1_10960' performs emergency braking on lane '-61539759#0_0' with decel=9.00, wished=4.00, severity=1.00, time=21707.00.
# Warning: Vehicle 'h05_1of1_10567' performs emergency braking on lane ':703111629_4_0' with decel=9.00, wished=4.00, severity=1.00, time=21860.00.
# Warning: Vehicle 'h05_1of1_30220' performs emergency braking on lane '134288595#0_0' with decel=9.00, wished=4.00, severity=1.00, time=22042.00.
# Warning: Vehicle 'h05_1of1_39498' performs emergency braking on lane '91672829#5_0' with decel=9.00, wished=4.00, severity=1.00, time=22129.00.
# Warning: Vehicle 'h06_1of1_99963' performs emergency braking on lane '201102998#2_0' with decel=9.00, wished=4.00, severity=1.00, time=22219.00.
# Warning: Vehicle 'h06_1of1_37356' performs emergency braking on lane '-470227084#4_0' with decel=9.00, wished=4.00, severity=1.00, time=22219.00.
# Warning: Vehicle 'h05_1of1_35985' performs emergency braking on lane '366469482#0_0' with decel=9.00, wished=4.00, severity=1.00, time=22219.00.
# Warning: Vehicle 'h06_1of1_84197' performs emergency braking on lane ':21313787_2_0' with decel=9.00, wished=4.00, severity=1.00, time=22219.00.
# Warning: Vehicle 'h06_1of1_97622' performs emergency braking on lane '1123617677#0_0' with decel=9.00, wished=4.00, severity=1.00, time=22249.00.
# Warning: Vehicle 'h06_1of1_85766' performs emergency braking on lane '52505119#1_0' with decel=9.00, wished=4.00, severity=1.00, time=22309.00.
# Warning: Vehicle 'h06_1of1_97625' performs emergency braking on lane '-397805346#19_0' with decel=9.00, wished=4.00, severity=1.00, time=22399.00.
# Warning: Vehicle 'h06_1of1_37222' performs emergency braking on lane '423658709#4_0' with decel=9.00, wished=4.00, severity=1.00, time=22399.00.
# Warning: Vehicle 'h06_1of1_69394' performs emergency braking on lane '875807716#1_0' with decel=9.00, wished=4.00, severity=1.00, time=22400.00.
# Warning: Vehicle 'h06_1of1_126024' performs emergency braking on lane '-342150049#3_0' with decel=9.00, wished=4.00, severity=1.00, time=22402.00.
# Warning: Teleporting vehicle 'h06_1of1_66076'; waited too long (yield), lane='-1189406598#0_0', time=22475.00.
# Warning: Vehicle 'h06_1of1_66076' ends teleporting on edge '960769080#1', time=22475.00.
# Warning: Vehicle 'h06_1of1_37388' performs emergency stop at the end of lane ':4632581252_0_0' for unknown reasons (decel=-4.95, offset=3.26), time=22492.00.
# Warning: Vehicle 'h06_1of1_126058' performs emergency braking on lane '6313124#2_0' with decel=9.00, wished=4.00, severity=1.00, time=22492.00.
# Warning: Vehicle 'h06_1of1_85754' performs emergency braking on lane '159567150#2_0' with decel=9.00, wished=4.00, severity=1.00, time=22549.00.
# Warning: Vehicle 'h06_1of1_69452' performs emergency braking on lane '581986214#7_0' with decel=9.00, wished=4.00, severity=1.00, time=22579.00.
# Warning: Vehicle 'h05_1of1_10893' performs emergency braking on lane '436469878#2_1' with decel=9.00, wished=4.00, severity=1.00, time=22669.00.
# Warning: Vehicle 'h05_1of1_39923' performs emergency braking on lane '-27112356#2_0' with decel=9.00, wished=4.00, severity=1.00, time=22759.00.
# Warning: Vehicle 'h06_1of1_99042' performs emergency braking on lane '356962706#0_0' with decel=9.00, wished=4.00, severity=1.00, time=22759.00.
# Warning: Vehicle 'h06_1of1_66594' performs emergency braking on lane ':507914927_13_0' with decel=9.00, wished=4.00, severity=1.00, time=22760.00.
# Warning: Vehicle 'h06_1of1_37475' performs emergency braking on lane '24374338#0_0' with decel=9.00, wished=4.00, severity=1.00, time=22762.00.
# Warning: Vehicle 'h05_1of1_21159' performs emergency braking on lane '477469397_0' with decel=9.00, wished=4.00, severity=1.00, time=22989.00.
# Warning: Vehicle 'h05_1of1_11627' performs emergency braking on lane ':648232097_2_0' with decel=9.00, wished=4.00, severity=1.00, time=23029.00.
# Warning: Vehicle 'h06_1of1_86367' performs emergency braking on lane '39791925#12_0' with decel=9.00, wished=4.00, severity=1.00, time=23032.00.
# Warning: Vehicle 'h06_1of1_37532' performs emergency braking on lane '-342150049#3_0' with decel=9.00, wished=4.00, severity=1.00, time=23122.00.
# Warning: Vehicle 'h05_1of1_20066' performs emergency braking on lane '49191961#0_0' with decel=9.00, wished=4.00, severity=1.00, time=23209.00.
# Warning: Vehicle 'h06_1of1_65990' performs emergency braking on lane '872881247#0_0' with decel=9.00, wished=4.00, severity=1.00, time=23212.00.
# Warning: Vehicle 'h05_1of1_26800' performs emergency braking on lane '73519072#2_0' with decel=9.00, wished=4.00, severity=1.00, time=23227.00.
# Warning: Vehicle 'h06_1of1_67642' performs emergency braking on lane '23246380#0_0' with decel=9.00, wished=4.00, severity=1.00, time=23300.00.
# Warning: Vehicle 'h06_1of1_126304' performs emergency braking on lane '28051104#0_2' with decel=9.00, wished=4.00, severity=1.00, time=23389.00.
# Warning: Vehicle 'h06_1of1_36560' performs emergency braking on lane '422866748#0_1' with decel=9.00, wished=4.00, severity=1.00, time=23392.00.
# Warning: Vehicle 'h06_1of1_36545' performs emergency braking on lane '6313524#7_0' with decel=9.00, wished=4.00, severity=1.00, time=23428.00.
# Warning: Vehicle 'h06_1of1_126561' performs emergency braking on lane ':8048255843_0_0' with decel=9.00, wished=4.00, severity=1.00, time=23446.00.
# Warning: Vehicle 'h05_1of1_20878' performs emergency braking on lane ':246674598_8_1' with decel=9.00, wished=4.00, severity=1.00, time=23569.00.
# Warning: Vehicle 'h06_1of1_66882' performs emergency braking on lane '-388215204#3_1' with decel=9.00, wished=4.00, severity=1.00, time=23569.00.
# Warning: Vehicle 'h06_1of1_65306' performs emergency braking on lane ':264469146_8_0' with decel=9.00, wished=4.00, severity=1.00, time=23569.00.
# Warning: Vehicle 'h05_1of1_20056' performs emergency braking on lane '684437151#0_1' with decel=9.00, wished=4.00, severity=1.00, time=23572.00.
# Warning: Vehicle 'h06_1of1_99362' performs emergency braking on lane '159567150#1_0' with decel=9.00, wished=4.00, severity=1.00, time=23625.00.
# Warning: Vehicle 'h06_1of1_38951' performs emergency braking on lane ':674532849_8_0' with decel=9.00, wished=4.00, severity=1.00, time=23659.00.
# Warning: Vehicle 'h06_1of1_38939' performs emergency braking on lane '707440335#1_0' with decel=9.00, wished=4.00, severity=1.00, time=23660.00.
# Warning: Vehicle 'h06_1of1_36666' performs emergency braking on lane '269802241#2_0' with decel=9.00, wished=4.00, severity=1.00, time=23698.00.
# Warning: Vehicle 'h05_1of1_26605' performs emergency braking on lane '-24220778#1_0' with decel=9.00, wished=4.00, severity=1.00, time=23722.00.
# Warning: Vehicle 'h06_1of1_39319' performs emergency braking on lane '356962706#0_0' with decel=9.00, wished=4.00, severity=1.00, time=23749.00.
# Warning: Vehicle 'h06_1of1_36335' performs emergency braking on lane '622018031#0_0' with decel=9.00, wished=4.00, severity=1.00, time=23800.00.
# Warning: Vehicle 'h06_1of1_86532' performs emergency braking on lane ':335373687_1_0' with decel=9.00, wished=4.00, severity=1.00, time=23818.00.
# Warning: Vehicle 'h05_1of1_26685' performs emergency braking on lane '32566250#11_0' with decel=9.00, wished=4.00, severity=1.00, time=23839.00.
# Warning: Vehicle 'h06_1of1_36567' performs emergency braking on lane '366469482#0_0' with decel=9.00, wished=4.00, severity=1.00, time=23839.00.
# Warning: Teleporting vehicle 'h06_1of1_115432'; waited too long (yield), lane='158282486#3_0', time=23904.00.
# Warning: Vehicle 'h06_1of1_115432' ends teleporting on edge '642234364#2', time=23906.00.
# Warning: Vehicle 'h06_1of1_65198' performs emergency braking on lane '81130048#9_0' with decel=9.00, wished=4.00, severity=1.00, time=23929.00.
# Warning: Vehicle 'h06_1of1_38485' performs emergency braking on lane ':26761382_0_0' with decel=9.00, wished=4.00, severity=1.00, time=23929.00.
# Warning: Vehicle 'h06_1of1_39011' performs emergency braking on lane ':1548585624_3_0' with decel=9.00, wished=4.00, severity=1.00, time=24019.00.
# Warning: Vehicle 'h06_1of1_67820' performs emergency braking on lane '628242566#1_1' with decel=9.00, wished=4.00, severity=1.00, time=24075.00.
# Warning: Vehicle 'h06_1of1_37678' performs emergency braking on lane '366469482#0_0' with decel=9.00, wished=4.00, severity=1.00, time=24109.00.
# Warning: Vehicle 'h06_1of1_66375' performs emergency braking on lane '28525536#0_0' with decel=9.00, wished=4.00, severity=1.00, time=24112.00.
# Warning: Vehicle 'h05_1of1_11569' performs emergency braking on lane ':304980313_2_1' with decel=9.00, wished=4.00, severity=1.00, time=24199.00.
# Warning: Vehicle 'h05_1of1_11641' performs emergency braking on lane ':648232097_2_0' with decel=9.00, wished=4.00, severity=1.00, time=24289.00.
# Warning: Vehicle 'h06_1of1_39000' performs emergency braking on lane ':673008048_3_0' with decel=9.00, wished=4.00, severity=1.00, time=24292.00.
# Warning: Vehicle 'h06_1of1_86501' performs emergency braking on lane ':335373687_1_0' with decel=9.00, wished=4.00, severity=1.00, time=24417.00.
# Warning: Vehicle 'h06_1of1_99495' performs emergency braking on lane '1319978476_0' with decel=9.00, wished=4.00, severity=1.00, time=24428.00.
# Warning: Vehicle 'h06_1of1_37730' performs emergency braking on lane '82285292#3_0' with decel=9.00, wished=4.00, severity=1.00, time=24469.00.
# Warning: Vehicle 'h06_1of1_98365' performs emergency braking on lane ':335373687_1_0' with decel=9.00, wished=4.00, severity=1.00, time=24524.00.
# Warning: Vehicle 'h05_1of1_26797' performs emergency braking on lane ':4232157451_2_0' with decel=9.00, wished=4.00, severity=1.00, time=24559.00.
# Warning: Vehicle 'h05_1of1_29955' performs emergency braking on lane ':5605262452_5_0' with decel=9.00, wished=4.00, severity=1.00, time=24650.00.
# Warning: Vehicle 'h06_1of1_38293' performs emergency braking on lane '891982390#0_0' with decel=9.00, wished=4.00, severity=1.00, time=24650.00.
# Warning: Vehicle 'h06_1of1_115870' performs emergency braking on lane '-406748287_0' with decel=9.00, wished=4.00, severity=1.00, time=24668.00.
# Warning: Vehicle 'h06_1of1_37905' performs emergency braking on lane '423658709#4_0' with decel=9.00, wished=4.00, severity=1.00, time=24739.00.
# Warning: Vehicle 'h06_1of1_68689' performs emergency braking on lane ':33781345_9_0' with decel=9.00, wished=4.00, severity=1.00, time=24740.00.
# Warning: Vehicle 'h06_1of1_99105' performs emergency braking on lane '-86188333#1_0' with decel=9.00, wished=4.00, severity=1.00, time=24749.00.
# Warning: Vehicle 'h06_1of1_66777' performs emergency braking on lane '143819493#1_0' with decel=9.00, wished=4.00, severity=1.00, time=24758.00.
# Warning: Vehicle 'h06_1of1_68902' performs emergency braking on lane '675124858#0_0' with decel=9.00, wished=4.00, severity=1.00, time=24789.00.
# Warning: Vehicle 'h06_1of1_67754' performs emergency braking on lane '181777025#0_0' with decel=9.00, wished=4.00, severity=1.00, time=24909.00.
# Warning: Vehicle 'h06_1of1_86705' performs emergency braking on lane ':335373687_1_0' with decel=9.00, wished=4.00, severity=1.00, time=24919.00.
# Warning: Vehicle 'h06_1of1_97782' performs emergency braking on lane '579502117#1_1' with decel=9.00, wished=4.00, severity=1.00, time=24922.00.
# Warning: Vehicle 'h06_1of1_124746' performs emergency braking on lane ':265721060_1_0' with decel=9.00, wished=4.00, severity=1.00, time=24922.00.
# Warning: Teleporting vehicle 'h06_1of1_67998'; waited too long (yield), lane='505242723#0_0', time=24942.00.
# Warning: Vehicle 'h06_1of1_67998' ends teleporting on edge '505242723#1', time=24942.00.
# Warning: Teleporting vehicle 'h06_1of1_125663'; waited too long (jam), lane=':1724772833_2_0', time=24948.00.
# Warning: Vehicle 'h06_1of1_125663' ends teleporting on edge '505242724', time=24950.00.
# Warning: Teleporting vehicle 'h06_1of1_68047'; waited too long (yield), lane='901120776_0', time=24951.00.
# Warning: Vehicle 'h06_1of1_68047' ends teleporting on edge '5079432#0', time=24951.00.
# Warning: Teleporting vehicle 'h06_1of1_68090'; waited too long (yield), lane='-901120776_0', time=24953.00.
# Warning: Vehicle 'h06_1of1_68090' ends teleporting on edge '159558429#0', time=24953.00.
# Warning: Vehicle 'h06_1of1_68715' performs emergency braking on lane ':4256938922_1_0' with decel=9.00, wished=4.00, severity=1.00, time=25009.00.
# Warning: Vehicle 'h06_1of1_39928' performs emergency braking on lane '363325782#1_0' with decel=9.00, wished=4.00, severity=1.00, time=25009.00.
# Warning: Vehicle 'h06_1of1_37081' performs emergency braking on lane '1097052623_0' with decel=9.00, wished=4.00, severity=1.00, time=25009.00.
# Warning: Vehicle 'h06_1of1_98870' performs emergency braking on lane ':490051434_13_0' with decel=9.00, wished=4.00, severity=1.00, time=25009.00.
# Warning: Vehicle 'h06_1of1_98311' performs emergency braking on lane ':34550795_5_1' with decel=9.00, wished=4.00, severity=1.00, time=25012.00.
# Warning: Teleporting vehicle 'h06_1of1_69128'; waited too long (jam), lane=':12379251648_7_0', time=25013.00.
# Warning: Vehicle 'h06_1of1_69128' ends teleporting on edge '1338338586#4', time=25013.00.
# Warning: Teleporting vehicle 'h06_1of1_115565'; waited too long (yield), lane='642218148#1_0', time=25023.00.
# Warning: Vehicle 'h06_1of1_115565' ends teleporting on edge '165723910#0', time=25023.00.
# Warning: Teleporting vehicle 'h06_1of1_67749'; waited too long (yield), lane='642218147_0', time=25028.00.
# Warning: Vehicle 'h06_1of1_67749' ends teleporting on edge '3625548', time=25028.00.
# Warning: Vehicle 'h06_1of1_99665' performs emergency braking on lane '1319978476_0' with decel=9.00, wished=4.00, severity=1.00, time=25084.00.
# Warning: Vehicle 'h06_1of1_38072' performs emergency braking on lane '24376451#0_0' with decel=9.00, wished=4.00, severity=1.00, time=25102.00.
# Warning: Vehicle 'h06_1of1_124521' performs emergency braking on lane '-417855829#3_0' with decel=9.00, wished=4.00, severity=1.00, time=25149.00.
# Warning: Vehicle 'h06_1of1_39180' performs emergency braking on lane '269802241#2_0' with decel=9.00, wished=4.00, severity=1.00, time=25175.00.
# Warning: Vehicle 'h06_1of1_39887' performs emergency braking on lane '614946279#1_0' with decel=9.00, wished=4.00, severity=1.00, time=25192.00.
# Warning: Vehicle 'h06_1of1_65945' performs emergency braking on lane ':265000804_0_0' with decel=9.00, wished=4.00, severity=1.00, time=25272.00.
# Warning: Vehicle 'h06_1of1_38240' performs emergency braking on lane ':33780887_10_0' with decel=9.00, wished=4.00, severity=1.00, time=25282.00.
# Warning: Vehicle 'h06_1of1_40514' performs emergency braking on lane '788485903#0_0' with decel=9.00, wished=4.00, severity=1.00, time=25282.00.
# Warning: Vehicle 'h06_1of1_68840' performs emergency braking on lane '435705786#0_0' with decel=9.00, wished=4.00, severity=1.00, time=25286.00.
# Warning: Teleporting vehicle 'h06_1of1_70008'; waited too long (yield), lane='28283870_0', time=25300.00.
# Warning: Vehicle 'h06_1of1_70008' ends teleporting on edge '-28283860', time=25300.00.
# Warning: Teleporting vehicle 'h06_1of1_84336'; waited too long (yield), lane='-28283870_0', time=25303.00.
# Warning: Vehicle 'h06_1of1_84336' ends teleporting on edge '1064573603', time=25303.00.
# Warning: Vehicle 'h06_1of1_98700' performs emergency braking on lane '-28071830#4_0' with decel=9.00, wished=4.00, severity=1.00, time=25329.00.
# Warning: Teleporting vehicle 'h06_1of1_115521'; waited too long (jam), lane=':2431137780_1_0', time=25352.00.
# Warning: Teleporting vehicle 'h06_1of1_115591'; waited too long (yield), lane='642218148#1_0', time=25353.00.
# Warning: Vehicle 'h06_1of1_115591' ends teleporting on edge '165723910#0', time=25353.00.
# Warning: Teleporting vehicle 'h06_1of1_39551'; waited too long (yield), lane='642218149#0_0', time=25354.00.
# Warning: Vehicle 'h06_1of1_39551' ends teleporting on edge '642218149#1', time=25354.00.
# Warning: Vehicle 'h06_1of1_115521' ends teleporting on edge '642218148#0', time=25354.00.
# Warning: Teleporting vehicle 'h06_1of1_66987'; waited too long (yield), lane='642218147_0', time=25355.00.
# Warning: Vehicle 'h06_1of1_66987' ends teleporting on edge '3625548', time=25355.00.
# Warning: Teleporting vehicle 'h06_1of1_115602'; waited too long (jam), lane=':6046600728_0_0', time=25359.00.
# Warning: Vehicle 'h06_1of1_69014' performs emergency braking on lane '962905276#3_0' with decel=9.00, wished=4.00, severity=1.00, time=25362.00.
# Warning: Vehicle 'h06_1of1_116517' performs emergency braking on lane '-32566250#1_1' with decel=9.00, wished=4.00, severity=1.00, time=25362.00.
# Warning: Teleporting vehicle 'h06_1of1_36656'; waited too long (jam), lane='683571245#2_0', time=25363.00.
# Warning: Teleporting vehicle 'h06_1of1_40125'; waited too long (jam), lane='642215300#3_0', time=25364.00.
# Warning: Vehicle 'h06_1of1_40125' ends teleporting on edge '642218141', time=25366.00.
# Warning: Vehicle 'h06_1of1_115602' ends teleporting on edge '165723910#0', time=25366.00.
# Warning: Vehicle 'h07_1of3_65957' performs emergency braking on lane '437670369#0_0' with decel=9.00, wished=4.00, severity=1.00, time=25369.00.
# Warning: Teleporting vehicle 'h06_1of1_66226'; waited too long (yield), lane='160432843_0', time=25388.00.
# Warning: Teleporting vehicle 'h06_1of1_66344'; waited too long (yield), lane='505242723#0_0', time=25388.00.
# Warning: Vehicle 'h06_1of1_66226' ends teleporting on edge '505242723#0', time=25388.00.
# Warning: Vehicle 'h06_1of1_66344' ends teleporting on edge '505242723#1', time=25388.00.
# Warning: Vehicle 'h06_1of1_86111' performs emergency braking on lane ':313182544_1_0' with decel=9.00, wished=4.00, severity=1.00, time=25391.00.
# Warning: Teleporting vehicle 'h06_1of1_125666'; waited too long (jam), lane=':1724772833_2_0', time=25392.00.
# Warning: Teleporting vehicle 'h06_1of1_37449'; waited too long (jam), lane='160432869#1_0', time=25394.00.
# Warning: Vehicle 'h06_1of1_37449' ends teleporting on edge '27248598', time=25394.00.
# Warning: Vehicle 'h06_1of1_125666' ends teleporting on edge '505242724', time=25394.00.
# Warning: Teleporting vehicle 'h06_1of1_125711'; waited too long (jam), lane='27679782_0', time=25403.00.
# Warning: Teleporting vehicle 'h06_1of1_126826'; waited too long (jam), lane='34105021_0', time=25409.00.
# Warning: Teleporting vehicle 'h06_1of1_126838'; waited too long (jam), lane='34105020_0', time=25417.00.
# Warning: Vehicle 'h06_1of1_36656' ends teleporting on edge '642218149#1', time=25420.00.
# Warning: Vehicle 'h06_1of1_126102' performs emergency braking on lane ':3666939765_1_0' with decel=9.00, wished=4.00, severity=1.00, time=25437.00.
# Warning: Vehicle 'h07_1of3_66284' performs emergency braking on lane '23813952#1_0' with decel=9.00, wished=4.00, severity=1.00, time=25446.00.
# Warning: Vehicle 'h06_1of1_125711' ends teleporting on edge '160432865#0', time=25451.00.
# Warning: Teleporting vehicle 'h06_1of1_98695'; waited too long (jam), lane='28283853#0_0', time=25457.00.
# Warning: Vehicle 'h05_1of1_10558' performs emergency braking on lane '308622954#1_0' with decel=9.00, wished=4.00, severity=1.00, time=25462.00.
# Warning: Vehicle 'h06_1of1_98695' ends teleporting on edge '28283853#1', time=25484.00.
# Warning: Vehicle 'h06_1of1_126838' ends teleporting on edge '27679782', time=25489.00.
# Warning: Vehicle 'h05_1of1_30313' performs emergency braking on lane '1319978476_0' with decel=9.00, wished=4.00, severity=1.00, time=25520.00.
# Warning: Vehicle 'h06_1of1_126826' ends teleporting on edge '160432865#1', time=25521.00.
# Warning: Vehicle 'h07_1of3_23527' performs emergency braking on lane '269802241#2_0' with decel=9.00, wished=4.00, severity=1.00, time=25545.00.
# Warning: Vehicle 'h07_1of3_38669' performs emergency braking on lane '-23411141#0_1' with decel=9.00, wished=4.00, severity=1.00, time=25549.00.
# Warning: Vehicle 'h06_1of1_85989' performs emergency braking on lane '616721087_0' with decel=9.00, wished=4.00, severity=1.00, time=25579.00.
# Warning: Teleporting vehicle 'h06_1of1_36853'; waited too long (jam), lane='181781578#2_0', time=25588.00.
# Warning: Vehicle 'h06_1of1_36853' ends teleporting on edge '181781578#3', time=25588.00.
# Warning: Vehicle 'h07_1of3_53237' performs emergency braking on lane '34427137_0' with decel=9.00, wished=4.00, severity=1.00, time=25599.00.
# Warning: Vehicle 'h07_1of3_36969' performs emergency braking on lane '159567150#1_0' with decel=9.00, wished=4.00, severity=1.00, time=25614.00.
# Warning: Teleporting vehicle 'h06_1of1_38568'; waited too long (jam), lane=':8907188067_0_0', time=25622.00.
# Warning: Vehicle 'h06_1of1_39429' performs emergency braking on lane '221060892_1' with decel=9.00, wished=4.00, severity=1.00, time=25626.00.
# Warning: Vehicle 'h06_1of1_68786' performs emergency braking on lane '-99272314#3_0' with decel=9.00, wished=4.00, severity=1.00, time=25640.00.
# Warning: Vehicle 'h07_1of3_24152' performs emergency braking on lane '685430889#0_1' with decel=9.00, wished=4.00, severity=1.00, time=25642.00.
# Warning: Teleporting vehicle 'h06_1of1_36537'; waited too long (yield), lane='642218149#0_0', time=25662.00.
# Warning: Vehicle 'h06_1of1_36537' ends teleporting on edge '642218149#1', time=25662.00.
# Warning: Teleporting vehicle 'h06_1of1_115575'; waited too long (yield), lane='642218148#1_0', time=25681.00.
# Warning: Vehicle 'h06_1of1_115575' ends teleporting on edge '165723910#0', time=25681.00.
# Warning: Teleporting vehicle 'h07_1of3_60628'; waited too long (jam), lane=':412366378_1_0', time=25724.00.
# Warning: Vehicle 'h07_1of3_60628' ends teleporting on edge '-35156385#0', time=25724.00.
# Warning: Vehicle 'h07_1of3_23259' performs emergency braking on lane '112765938_0' with decel=9.00, wished=4.00, severity=1.00, time=25729.00.
# Warning: Vehicle 'h06_1of1_38568' ends teleporting on edge '181781578#2', time=25747.00.
# Warning: Vehicle 'h06_1of1_98198' performs emergency braking on lane '24220769#5_0' with decel=9.00, wished=4.00, severity=1.00, time=25761.00.
# Warning: Vehicle 'h06_1of1_68757' performs emergency braking on lane ':958255439_3_0' with decel=9.00, wished=4.00, severity=1.00, time=25808.00.
# Warning: Teleporting vehicle 'h06_1of1_36890'; waited too long (jam), lane='436469878#4_1', time=25814.00.
# Warning: Vehicle 'h07_1of3_38748' performs emergency braking on lane '-201880302#1_0' with decel=9.00, wished=4.00, severity=1.00, time=25819.00.
# Warning: Vehicle 'h07_1of3_39268' performs emergency braking on lane '39304029#5_1' with decel=9.00, wished=4.00, severity=1.00, time=25819.00.
# Warning: Vehicle 'h06_1of1_85304' performs emergency braking on lane '578082803_0' with decel=9.00, wished=4.00, severity=1.00, time=25819.00.
# Warning: Vehicle 'h07_1of3_60306' performs emergency braking on lane '-39791925#19_0' with decel=9.00, wished=4.00, severity=1.00, time=25822.00.
# Warning: Vehicle 'h07_1of3_53324' performs emergency braking on lane '886768898#0_1' with decel=9.00, wished=4.00, severity=1.00, time=25837.00.
# Warning: Vehicle 'h06_1of1_36890' ends teleporting on edge '181781578#1', time=25885.00.
# Warning: Teleporting vehicle 'h06_1of1_38543'; waited too long (jam), lane=':1424936979_1_0', time=25889.00.
# Warning: Vehicle 'h06_1of1_38543' ends teleporting on edge '436469878#1', time=25889.00.
# Warning: Teleporting vehicle 'h06_1of1_37128'; waited too long (jam), lane=':773179301_1_0', time=25892.00.
# Warning: Vehicle 'h06_1of1_37128' ends teleporting on edge '436469878#0', time=25892.00.
# Warning: Vehicle 'h06_1of1_86282' performs emergency braking on lane '31450970#3_0' with decel=9.00, wished=4.00, severity=1.00, time=25906.00.
# Warning: Vehicle 'h07_1of3_37026' performs emergency braking on lane '-862077735#2_1' with decel=9.00, wished=4.00, severity=1.00, time=25909.00.
# Warning: Vehicle 'h07_1of3_47327' performs emergency braking on lane '-696130907#2_0' with decel=9.00, wished=4.00, severity=1.00, time=25909.00.
# Warning: Vehicle 'h06_1of1_36547' performs emergency braking on lane ':443069305_5_1' with decel=9.00, wished=4.00, severity=1.00, time=25912.00.
# Warning: Vehicle 'h06_1of1_85531' performs emergency braking on lane '653458447#0_0' with decel=9.00, wished=4.00, severity=1.00, time=25912.00.
# Warning: Vehicle 'h06_1of1_126318' performs emergency braking on lane '-61539759#0_0' with decel=9.00, wished=4.00, severity=1.00, time=25972.00.
# Warning: Teleporting vehicle 'h06_1of1_67852'; waited too long (yield), lane='642218147_0', time=25977.00.
# Warning: Vehicle 'h06_1of1_67852' ends teleporting on edge '3625548', time=25977.00.
# Warning: Teleporting vehicle 'h06_1of1_38982'; waited too long (jam), lane='642218139_0', time=25983.00.
# Warning: Vehicle 'h06_1of1_38982' ends teleporting on edge '642247964', time=25986.00.
# Warning: Teleporting vehicle 'h06_1of1_36711'; waited too long (jam), lane='683571245#2_0', time=25987.00.
# Warning: Teleporting vehicle 'h06_1of1_67992'; waited too long (yield), lane='505242723#0_0', time=25992.00.
# Warning: Vehicle 'h06_1of1_67992' ends teleporting on edge '505242723#1', time=25992.00.
# Warning: Teleporting vehicle 'h06_1of1_115633'; waited too long (jam), lane='-235004911#0_0', time=25997.00.
# Warning: Vehicle 'h07_1of3_46689' performs emergency braking on lane '-34934785#3_0' with decel=9.00, wished=4.00, severity=1.00, time=26000.00.
# Warning: Teleporting vehicle 'h07_1of3_53261'; waited too long (yield), lane='-161432890#0_0', time=26002.00.
# Warning: Vehicle 'h06_1of1_115633' ends teleporting on edge '642218145', time=26005.00.
# Warning: Vehicle 'h06_1of1_36711' ends teleporting on edge '642218149#1', time=26009.00.
# Warning: Vehicle 'h07_1of3_53261' ends teleporting on edge '962905272#1', time=26010.00.
# Warning: Teleporting vehicle 'h06_1of1_126409'; waited too long (jam), lane=':34018264_0_0', time=26016.00.
# Warning: Vehicle 'h06_1of1_126409' ends teleporting on edge '505242723#1', time=26016.00.
# Warning: Teleporting vehicle 'h06_1of1_66464'; waited too long (jam), lane='27679782_0', time=26024.00.
# Warning: Vehicle 'h07_1of3_67057' performs emergency braking on lane ':7077367263_0_0' with decel=9.00, wished=4.00, severity=1.00, time=26059.00.
# Warning: Vehicle 'h06_1of1_40099' performs emergency braking on lane '962905276#1_1' with decel=9.00, wished=4.00, severity=1.00, time=26059.00.
# Warning: Teleporting vehicle 'h06_1of1_37101'; waited too long (yield), lane='24968767_0', time=26063.00.
# Warning: Teleporting vehicle 'h07_1of3_37164'; waited too long (yield), lane=':1300632697_4_0', time=26065.00.
# Warning: Vehicle 'h07_1of3_37164' ends teleporting on edge '114941446', time=26065.00.
# Warning: Vehicle 'h06_1of1_66464' ends teleporting on edge '505242723#1', time=26072.00.
# Warning: Teleporting vehicle 'h07_1of3_60328'; waited too long (yield), lane='-53189547#0_0', time=26082.00.
# Warning: Teleporting vehicle 'h07_1of3_47548'; waited too long (yield), lane='554506207_0', time=26086.00.
# Warning: Vehicle 'h07_1of3_47548' ends teleporting on edge '39154176', time=26086.00.
# Warning: Teleporting vehicle 'h07_1of3_37730'; waited too long (yield), lane='-554506207_0', time=26088.00.
# Warning: Vehicle 'h07_1of3_37730' ends teleporting on edge '554515800', time=26088.00.
# Warning: Vehicle 'h06_1of1_40130' performs emergency braking on lane '27775349#2_0' with decel=9.00, wished=4.00, severity=1.00, time=26089.00.
# Warning: Vehicle 'h07_1of3_60895' performs emergency braking on lane ':505533363_0_0' with decel=9.00, wished=4.00, severity=1.00, time=26090.00.
# Warning: Teleporting vehicle 'h07_1of3_60961'; waited too long (yield), lane='25277565_0', time=26137.00.
# Warning: Teleporting vehicle 'h06_1of1_69912'; waited too long (yield), lane='257769845#1_0', time=26137.00.
# Warning: Vehicle 'h06_1of1_69912' ends teleporting on edge '257769813', time=26137.00.
# Warning: Teleporting vehicle 'h07_1of3_66525'; waited too long (yield), lane='257777077#0_0', time=26140.00.
# Warning: Vehicle 'h07_1of3_60961' ends teleporting on edge '237122862#0', time=26141.00.
# Warning: Vehicle 'h07_1of3_60328' ends teleporting on edge '-39791925#3', time=26141.00.
# Warning: Vehicle 'h07_1of3_66525' ends teleporting on edge '27633627#2', time=26142.00.
# Warning: Vehicle 'h07_1of3_23256' performs emergency braking on lane '49263619#2_1' with decel=9.00, wished=4.00, severity=1.00, time=26161.00.
# Warning: Vehicle 'h07_1of3_66143' performs emergency braking on lane ':308849279_0_0' with decel=9.00, wished=4.00, severity=1.00, time=26179.00.
# Warning: Vehicle 'h07_1of3_67096' performs emergency braking on lane '-326425045#2_0' with decel=9.00, wished=4.00, severity=1.00, time=26179.00.
# Warning: Vehicle 'h06_1of1_85112' performs emergency braking on lane '473534068_1' with decel=9.00, wished=4.00, severity=1.00, time=26190.00.
# Warning: Teleporting vehicle 'h06_1of1_115514'; waited too long (jam), lane='-39791925#15_0', time=26216.00.
# Warning: Vehicle 'h06_1of1_37101' ends teleporting on edge '396859211#1', time=26217.00.
# Warning: Teleporting vehicle 'h07_1of3_38656'; waited too long (jam), lane='-39791925#16_0', time=26229.00.
# Warning: Vehicle 'h07_1of3_37751' performs emergency braking on lane '73519072#2_0' with decel=9.00, wished=4.00, severity=1.00, time=26233.00.
# Warning: Vehicle 'h07_1of3_38656' ends teleporting on edge '-39791925#15', time=26244.00.
# Warning: Teleporting vehicle 'h07_1of3_24165'; waited too long (yield), lane=':673008048_4_0', time=26246.00.
# Warning: Vehicle 'h07_1of3_24165' ends teleporting on edge '53189547#1', time=26248.00.
# Warning: Vehicle 'h06_1of1_65574' performs emergency braking on lane '-1160552339#0_0' with decel=9.00, wished=4.00, severity=1.00, time=26262.00.
# Warning: Vehicle 'h07_1of3_22477' performs emergency braking on lane '23813952#1_0' with decel=9.00, wished=4.00, severity=1.00, time=26266.00.
# Warning: Teleporting vehicle 'h07_1of3_39310'; waited too long (yield), lane='-26537748#0_0', time=26267.00.
# Warning: Teleporting vehicle 'h06_1of1_65478'; waited too long (yield), lane='414124745_0', time=26267.00.
# Warning: Vehicle 'h06_1of1_65478' ends teleporting on edge '554737931#0', time=26267.00.
# Warning: Vehicle 'h07_1of3_39310' ends teleporting on edge '100143560#7', time=26267.00.
# Warning: Teleporting vehicle 'h07_1of3_23658'; waited too long (yield), lane='-414124745_0', time=26269.00.
# Warning: Vehicle 'h07_1of3_60683' performs emergency braking on lane ':33781774_0_0' with decel=9.00, wished=4.00, severity=1.00, time=26269.00.
# Warning: Vehicle 'h07_1of3_23658' ends teleporting on edge '-33563218#1', time=26271.00.
# Warning: Vehicle 'h07_1of3_60383' performs emergency braking on lane '335356961#7_0' with decel=9.00, wished=4.00, severity=1.00, time=26272.00.
# Warning: Teleporting vehicle 'h06_1of1_37989'; waited too long (jam), lane='181781578#0_0', time=26282.00.
# Warning: Vehicle 'h06_1of1_37989' ends teleporting on edge '181781578#2', time=26284.00.
# Warning: Teleporting vehicle 'h07_1of3_52176'; waited too long (jam), lane=':8907188067_0_1', time=26285.00.
# Warning: Vehicle 'h07_1of3_52176' ends teleporting on edge '181781578#2', time=26285.00.
# Warning: Teleporting vehicle 'h07_1of3_24240'; waited too long (yield), lane='-414122732#0_0', time=26286.00.
# Warning: Vehicle 'h07_1of3_24240' ends teleporting on edge '414122731#1', time=26286.00.
# Warning: Teleporting vehicle 'h06_1of1_38359'; waited too long (jam), lane='181781578#0_0', time=26287.00.
# Warning: Vehicle 'h06_1of1_38359' ends teleporting on edge '181781578#2', time=26289.00.
# Warning: Teleporting vehicle 'h06_1of1_126809'; waited too long (yield), lane='160432865#0_0', time=26298.00.
# Warning: Teleporting vehicle 'h06_1of1_39324'; waited too long (yield), lane='642218149#0_0', time=26300.00.
# Warning: Vehicle 'h06_1of1_39324' ends teleporting on edge '642218149#1', time=26300.00.
# Warning: Vehicle 'h06_1of1_126809' ends teleporting on edge '505242724', time=26300.00.
# Warning: Teleporting vehicle 'h06_1of1_37865'; waited too long (jam), lane=':773179301_1_1', time=26305.00.
# Warning: Vehicle 'h06_1of1_37865' ends teleporting on edge '436469878#1', time=26307.00.
# Warning: Teleporting vehicle 'h06_1of1_115633'; waited too long (jam), lane=':2431137780_1_0', time=26312.00.
# Warning: Vehicle 'h06_1of1_115633' ends teleporting on edge '642218143', time=26312.00.
# Warning: Teleporting vehicle 'h06_1of1_38893'; waited too long (yield), lane='642218147_0', time=26313.00.
# Warning: Teleporting vehicle 'h06_1of1_115662'; waited too long (yield), lane='642218148#1_0', time=26313.00.
# Warning: Vehicle 'h06_1of1_38893' ends teleporting on edge '3625548', time=26313.00.
# Warning: Vehicle 'h06_1of1_115662' ends teleporting on edge '165723910#0', time=26313.00.
# Warning: Teleporting vehicle 'h07_1of3_23677'; waited too long (jam), lane='100143560#5_0', time=26315.00.
# Warning: Teleporting vehicle 'h05_1of1_39990'; waited too long (jam), lane='962905273#0_1', time=26323.00.
# Warning: Teleporting vehicle 'h07_1of3_47281'; waited too long (jam), lane='-39791925#12_0', time=26323.00.
# Warning: Teleporting vehicle 'h06_1of1_98593'; waited too long (jam), lane='5056595#0_0', time=26324.00.
# Warning: Vehicle 'h06_1of1_98593' ends teleporting on edge '5056595#1', time=26324.00.
# Warning: Vehicle 'h05_1of1_39990' ends teleporting on edge '962905273#2', time=26325.00.
# Warning: Vehicle 'h07_1of3_23677' ends teleporting on edge '100143560#7', time=26327.00.
# Warning: Teleporting vehicle 'h07_1of3_52921'; waited too long (jam), lane='-235004911#3_0', time=26328.00.
# Warning: Teleporting vehicle 'h06_1of1_115656'; waited too long (jam), lane='-235004911#2_0', time=26329.00.
# Warning: Vehicle 'h06_1of1_115656' ends teleporting on edge '-235004911#1', time=26329.00.
# Warning: Vehicle 'h07_1of3_52921' ends teleporting on edge '-235004911#2', time=26329.00.
# Warning: Teleporting vehicle 'h06_1of1_115678'; waited too long (jam), lane='-235004911#2_0', time=26330.00.
# Warning: Teleporting vehicle 'h06_1of1_38858'; waited too long (jam), lane='683571245#1_0', time=26353.00.
# Warning: Vehicle 'h06_1of1_38858' ends teleporting on edge '683571245#2', time=26358.00.
# Warning: Vehicle 'h07_1of3_60702' performs emergency braking on lane ':503869220_5_1' with decel=9.00, wished=4.00, severity=1.00, time=26359.00.
# Warning: Vehicle 'h06_1of1_66898' performs emergency braking on lane '326390748#0_0' with decel=9.00, wished=4.00, severity=1.00, time=26359.00.
# Warning: Vehicle 'h06_1of1_68906' performs emergency braking on lane '52505119#1_0' with decel=9.00, wished=4.00, severity=1.00, time=26359.00.
# Warning: Teleporting vehicle 'h06_1of1_70179'; waited too long (yield), lane='166577431_0', time=26369.00.
# Warning: Vehicle 'h06_1of1_70179' ends teleporting on edge '414122731#3', time=26369.00.
# Warning: Teleporting vehicle 'h06_1of1_39413'; waited too long (jam), lane='235015214_0', time=26385.00.
# Warning: Teleporting vehicle 'h07_1of3_53338'; waited too long (yield), lane='-53189547#0_0', time=26390.00.
# Warning: Teleporting vehicle 'h06_1of1_37208'; waited too long (yield), lane='24968767_0', time=26408.00.
# Warning: Teleporting vehicle 'h06_1of1_39177'; waited too long (jam), lane='236123645_0', time=26411.00.
# Warning: Vehicle 'h06_1of1_39177' ends teleporting on edge '235015214', time=26414.00.
# Warning: Vehicle 'h06_1of1_69126' performs emergency braking on lane '-577143178#1_0' with decel=9.00, wished=4.00, severity=1.00, time=26418.00.
# Warning: Vehicle 'h06_1of1_115678' ends teleporting on edge '165723910#0', time=26420.00.
# Warning: Teleporting vehicle 'h06_1of1_37156'; waited too long (jam), lane='-39791925#4_0', time=26421.00.
# Warning: Teleporting vehicle 'h06_1of1_39174'; waited too long (jam), lane='1175823314_0', time=26421.00.
# Warning: Vehicle 'h06_1of1_37156' ends teleporting on edge '-39791925#3', time=26421.00.
# Warning: Vehicle 'h07_1of3_53338' ends teleporting on edge '-39791925#4', time=26421.00.
# Warning: Vehicle 'h06_1of1_39174' ends teleporting on edge '236123645', time=26424.00.
# Warning: Teleporting vehicle 'h06_1of1_37165'; waited too long (jam), lane='-39791925#6_0', time=26437.00.
# Warning: Teleporting vehicle 'h06_1of1_39115'; waited too long (jam), lane='3625544#1_0', time=26438.00.
# Warning: Vehicle 'h06_1of1_39115' ends teleporting on edge '1175823314', time=26440.00.
# Warning: Teleporting vehicle 'h06_1of1_116490'; waited too long (jam), lane=':3774634390_0_0', time=26445.00.
# Warning: Vehicle 'h06_1of1_116490' ends teleporting on edge '24374711#2', time=26445.00.
# Warning: Vehicle 'h07_1of3_60668' performs emergency braking on lane ':751404356_1_0' with decel=9.00, wished=4.00, severity=1.00, time=26449.00.
# Warning: Vehicle 'h06_1of1_68983' performs emergency braking on lane '50848255#0_0' with decel=9.00, wished=4.00, severity=1.00, time=26449.00.
# Warning: Vehicle 'h07_1of3_53019' performs emergency braking on lane '388890742#0_0' with decel=9.00, wished=4.00, severity=1.00, time=26449.00.
# Warning: Vehicle 'h06_1of1_99853' performs emergency braking on lane '1021597224#0_0' with decel=9.00, wished=4.00, severity=1.00, time=26452.00.
# Warning: Teleporting vehicle 'h07_1of3_52180'; waited too long (yield), lane='-39791925#10_0', time=26459.00.
# Warning: Teleporting vehicle 'h07_1of3_60705'; waited too long (yield), lane='-901120776_0', time=26459.00.
# Warning: Vehicle 'h07_1of3_52180' ends teleporting on edge '-39791925#9', time=26459.00.
# Warning: Vehicle 'h07_1of3_60705' ends teleporting on edge '159558429#0', time=26459.00.
# Warning: Teleporting vehicle 'h07_1of3_22441'; waited too long (yield), lane='901120776_0', time=26463.00.
# Warning: Vehicle 'h07_1of3_22441' ends teleporting on edge '5079432#0', time=26463.00.
# Warning: Vehicle 'h07_1of3_22303' performs emergency braking on lane '49263619#2_1' with decel=9.00, wished=4.00, severity=1.00, time=26470.00.
# Warning: Teleporting vehicle 'h06_1of1_126352'; waited too long (jam), lane='396859209#2_0', time=26485.00.
# Warning: Teleporting vehicle 'h06_1of1_124503'; waited too long (jam), lane='-90753456_0', time=26491.00.
# Warning: Vehicle 'h06_1of1_124503' ends teleporting on edge '24374711#0', time=26491.00.
# Warning: Vehicle 'h06_1of1_37165' ends teleporting on edge '-39791925#3', time=26496.00.
# Warning: Vehicle 'h06_1of1_115514' ends teleporting on edge '-39791925#3', time=26541.00.
# Warning: Teleporting vehicle 'h06_1of1_116522'; waited too long (yield), lane='396859209#1_0', time=26558.00.
# Warning: Vehicle 'h06_1of1_116522' ends teleporting on edge '396859209#2', time=26558.00.
# Warning: Vehicle 'h06_1of1_37208' ends teleporting on edge '396859211#1', time=26562.00.
# Warning: Vehicle 'h06_1of1_126352' ends teleporting on edge '161025505', time=26564.00.
# Warning: Teleporting vehicle 'h07_1of3_23004'; waited too long (jam), lane=':1157599035_4_0', time=26569.00.
# Warning: Teleporting vehicle 'h06_1of1_40459'; waited too long (jam), lane=':1157599035_1_0', time=26569.00.
# Warning: Vehicle 'h06_1of1_40459' ends teleporting on edge '398891915#1', time=26569.00.
# Warning: Vehicle 'h07_1of3_23004' ends teleporting on edge '398891915#1', time=26569.00.
# Warning: Teleporting vehicle 'h07_1of3_47314'; waited too long (jam), lane='100143560#6_0', time=26574.00.
# Warning: Vehicle 'h07_1of3_47314' ends teleporting on edge '100143560#7', time=26574.00.
# Warning: Teleporting vehicle 'h06_1of1_86062'; waited too long (yield), lane='24428238#2_0', time=26592.00.
# Warning: Vehicle 'h06_1of1_86062' ends teleporting on edge '660261110#0', time=26594.00.
# Warning: Teleporting vehicle 'h06_1of1_68196'; waited too long (yield), lane='-60575790_0', time=26596.00.
# Warning: Vehicle 'h06_1of1_68196' ends teleporting on edge '-24428238#2', time=26597.00.
# Warning: Vehicle 'h06_1of1_67136' performs emergency braking on lane '159567150#1_0' with decel=9.00, wished=4.00, severity=1.00, time=26607.00.
# Warning: Teleporting vehicle 'h06_1of1_38853'; waited too long (yield), lane='642218149#0_0', time=26612.00.
# Warning: Vehicle 'h06_1of1_38853' ends teleporting on edge '642218149#1', time=26612.00.
# Warning: Teleporting vehicle 'h06_1of1_115633'; waited too long (yield), lane='642218148#1_0', time=26620.00.
# Warning: Vehicle 'h06_1of1_115633' ends teleporting on edge '165723910#0', time=26620.00.
# Warning: Teleporting vehicle 'h06_1of1_38875'; waited too long (yield), lane='642218147_0', time=26622.00.
# Warning: Vehicle 'h06_1of1_38875' ends teleporting on edge '3625548', time=26622.00.
# Warning: Teleporting vehicle 'h06_1of1_69549'; waited too long (jam), lane='-235004911#0_0', time=26624.00.
# Warning: Vehicle 'h06_1of1_69549' ends teleporting on edge '642247964', time=26627.00.
# ...
# Warning: Teleporting vehicle 'h07_3of3_58853'; waited too long (yield), lane=':1147563664_1_0', time=29073.00.
# Warning: Vehicle 'h07_3of3_58853' ends teleporting on edge '99205828', time=29073.00.
# Warning: Teleporting vehicle 'h07_3of3_73418'; waited too long (yield), lane=':392185487_5_0', time=29074.00.
# Warning: Vehicle 'h07_3of3_73418' ends teleporting on edge '131821097#0', time=29074.00.
# Warning: Vehicle 'h08_1of3_76483' performs emergency braking on lane ':1671540281_1_0' with decel=9.00, wished=4.00, severity=1.00, time=29079.00.
# Warning: Teleporting vehicle 'h07_3of3_73245'; waited too long (yield), lane=':599287233_4_0', time=29093.00.
# Warning: Vehicle 'h07_3of3_43211' ends teleporting on edge '862077740#0', time=29101.00.
# Warning: Teleporting vehicle 'h07_1of3_38863'; waited too long (yield), lane='37788760_0', time=29104.00.
# Warning: Vehicle 'h07_1of3_66280' ends teleporting on edge '660277188', time=29109.00.
# Warning: Teleporting vehicle 'h07_3of3_43090'; waited too long (jam), lane='91672829#5_0', time=29115.00.
# Warning: Vehicle 'h07_3of3_41431' ends teleporting on edge '183744260#0', time=29121.00.
# Warning: Teleporting vehicle 'h06_1of1_36709'; waited too long (yield), lane='642218149#0_0', time=29122.00.
# Warning: Vehicle 'h06_1of1_36709' ends teleporting on edge '642218149#1', time=29122.00.
# Warning: Teleporting vehicle 'h06_1of1_67027'; waited too long (yield), lane='642218147_0', time=29125.00.
# Warning: Vehicle 'h06_1of1_67027' ends teleporting on edge '3625548', time=29125.00.
# Warning: Teleporting vehicle 'h07_3of3_42992'; waited too long (jam), lane='91672829#1_0', time=29132.00.
# Warning: Teleporting vehicle 'h07_3of3_42470'; waited too long (jam), lane='91672829#0_0', time=29134.00.
# Warning: Vehicle 'h07_3of3_52773' ends teleporting on edge '91672829#0', time=29134.00.
# Warning: Teleporting vehicle 'h07_3of3_73894'; waited too long (yield), lane='-519356899_0', time=29137.00.
# Warning: Teleporting vehicle 'h07_3of3_52670'; waited too long (jam), lane='520265801_0', time=29142.00.
# Warning: Vehicle 'h07_3of3_52670' ends teleporting on edge '520265800#0', time=29142.00.
# Warning: Vehicle 'h06_1of1_68839' ends teleporting on edge '424764048#1', time=29144.00.
# Warning: Teleporting vehicle 'h07_3of3_27062'; waited too long (jam), lane='615610855_0', time=29146.00.
# Warning: Teleporting vehicle 'h07_3of3_73336'; waited too long (yield), lane='46961139_0', time=29146.00.
# Warning: Vehicle 'h08_1of3_85616' performs emergency braking on lane '393235681#0_0' with decel=9.00, wished=4.00, severity=1.00, time=29149.00.
# Warning: Vehicle 'h08_1of3_76297' performs emergency braking on lane '120929419#1_0' with decel=9.00, wished=4.00, severity=1.00, time=29149.00.
# Warning: Vehicle 'h07_3of3_26013' performs emergency braking on lane '-123313961#1_0' with decel=9.00, wished=4.00, severity=1.00, time=29149.00.
# Warning: Vehicle 'h06_1of1_126428' performs emergency braking on lane '436469868#0_0' with decel=9.00, wished=4.00, severity=1.00, time=29149.00.
# Warning: Vehicle 'h07_3of3_26399' performs emergency braking on lane '1306384915#1_0' with decel=9.00, wished=4.00, severity=1.00, time=29149.00.
# Warning: Vehicle 'h06_1of1_40414' performs emergency braking on lane '-1236005620_0' with decel=9.00, wished=4.00, severity=1.00, time=29154.00.
# Warning: Vehicle 'h07_1of3_66101' performs emergency braking on lane ':412440433_1_0' with decel=9.00, wished=4.00, severity=1.00, time=29154.00.
# Warning: Teleporting vehicle 'h07_3of3_25992'; waited too long (jam), lane='91672797#3_0', time=29156.00.
# Warning: Vehicle 'h07_3of3_25992' ends teleporting on edge '972630107', time=29159.00.
# Warning: Teleporting vehicle 'h08_1of3_84509'; waited too long (yield), lane='905807166_0', time=29160.00.
# Warning: Vehicle 'h07_3of3_42992' ends teleporting on edge '91672829#2', time=29160.00.
# Warning: Vehicle 'h08_1of3_84509' ends teleporting on edge '983279180', time=29160.00.
# Warning: Vehicle 'h07_1of3_38863' ends teleporting on edge '91672829#3', time=29161.00.
# Warning: Vehicle 'h07_3of3_42470' ends teleporting on edge '91672829#1', time=29162.00.
# Warning: Teleporting vehicle 'h06_1of1_125708'; waited too long (yield), lane='-60575790_0', time=29169.00.
# Warning: Teleporting vehicle 'h06_1of1_66460'; waited too long (jam), lane=':7371649061_2_0', time=29171.00.
# Warning: Vehicle 'h06_1of1_125708' ends teleporting on edge '-24428238#1', time=29171.00.
# Warning: Teleporting vehicle 'h06_1of1_68824'; waited too long (jam), lane='37791874#4_0', time=29172.00.
# Warning: Teleporting vehicle 'h06_1of1_68259'; waited too long (jam), lane='642215300#2_0', time=29173.00.
# Warning: Teleporting vehicle 'h07_3of3_25401'; waited too long (yield), lane='-685085522#0_0', time=29173.00.
# Warning: Vehicle 'h06_1of1_124693' ends teleporting on edge '642215300#2', time=29173.00.
# Warning: Vehicle 'h07_3of3_25401' ends teleporting on edge '983279179#0', time=29173.00.
# Warning: Vehicle 'h06_1of1_66460' ends teleporting on edge '-24428238#1', time=29174.00.
# Warning: Vehicle 'h06_1of1_114848' ends teleporting on edge '642215300#2', time=29175.00.
# Warning: Teleporting vehicle 'h06_1of1_39000'; waited too long (jam), lane='683571245#1_0', time=29178.00.
# Warning: Vehicle 'h07_3of3_73894' ends teleporting on edge '356962708#1', time=29194.00.
# Warning: Teleporting vehicle 'h07_3of3_74494'; waited too long (yield), lane='-286261133#0_0', time=29195.00.
# Warning: Teleporting vehicle 'h08_1of3_50683'; waited too long (yield), lane='342094982#0_0', time=29197.00.
# Warning: Teleporting vehicle 'h07_1of3_37485'; waited too long (jam), lane=':8411842025_3_0', time=29198.00.
# Warning: Teleporting vehicle 'h06_1of1_40008'; waited too long (jam), lane='642215300#1_0', time=29199.00.
# Warning: Teleporting vehicle 'h08_1of3_76026'; waited too long (yield), lane='-49040111#0_0', time=29199.00.
# Warning: Teleporting vehicle 'h07_3of3_26117'; waited too long (yield), lane='685426436#3_0', time=29200.00.
# Warning: Vehicle 'h07_1of3_37485' ends teleporting on edge '221864398#3', time=29200.00.
# Warning: Teleporting vehicle 'h07_3of3_41022'; waited too long (jam), lane='685426436#0_0', time=29203.00.
# Warning: Vehicle 'h07_3of3_41022' ends teleporting on edge '685426436#2', time=29205.00.
# Warning: Teleporting vehicle 'h07_3of3_73240'; waited too long (jam), lane=':33781620_0_1', time=29206.00.
# Warning: Vehicle 'h07_3of3_73240' ends teleporting on edge '-862077735#3', time=29208.00.
# Warning: Teleporting vehicle 'h07_3of3_41486'; waited too long (yield), lane=':2916142720_5_0', time=29213.00.
# Warning: Teleporting vehicle 'h07_3of3_26758'; waited too long (jam), lane=':270072049_0_0', time=29214.00.
# Warning: Vehicle 'h07_3of3_26758' ends teleporting on edge '862077740#0', time=29214.00.
# Warning: Teleporting vehicle 'h07_3of3_43062'; waited too long (yield), lane='862077721_0', time=29215.00.
# Warning: Teleporting vehicle 'h07_3of3_25416'; waited too long (yield), lane='862077738#3_0', time=29215.00.
# Warning: Vehicle 'h07_3of3_25416' ends teleporting on edge '24855726#0', time=29215.00.
# Warning: Vehicle 'h08_1of3_76026' ends teleporting on edge '-39791925#22', time=29215.00.
# Warning: Vehicle 'h07_3of3_52166' performs emergency braking on lane '157910466#1_0' with decel=9.00, wished=4.00, severity=1.00, time=29216.00.
# Warning: Vehicle 'h07_3of3_43062' ends teleporting on edge '862077740#0', time=29217.00.
# Warning: Teleporting vehicle 'h07_3of3_41217'; waited too long (jam), lane=':270072044_2_0', time=29218.00.
# Warning: Vehicle 'h07_3of3_41217' ends teleporting on edge '863798753#0', time=29218.00.
# Warning: Teleporting vehicle 'h06_1of1_98827'; waited too long (jam), lane='364298465_0', time=29219.00.
# Warning: Vehicle 'h06_1of1_98827' ends teleporting on edge '37791873#0', time=29221.00.
# Warning: Teleporting vehicle 'h06_1of1_98818'; waited too long (jam), lane='862077739_0', time=29222.00.
# Warning: Teleporting vehicle 'h07_3of3_67436'; waited too long (yield), lane='201275063#8_0', time=29223.00.
# Warning: Teleporting vehicle 'h07_3of3_43629'; waited too long (jam), lane='-827584042#0_0', time=29223.00.
# Warning: Teleporting vehicle 'h06_1of1_68882'; waited too long (jam), lane='-112781626#0_0', time=29225.00.
# Warning: Vehicle 'h06_1of1_98818' ends teleporting on edge '862077738#2', time=29225.00.
# Warning: Vehicle 'h06_1of1_68882' ends teleporting on edge '364298465', time=29225.00.
# Warning: Teleporting vehicle 'h07_3of3_52722'; waited too long (jam), lane='-866024664_0', time=29226.00.
# Warning: Vehicle 'h07_3of3_43629' ends teleporting on edge '-866024664', time=29226.00.
# Warning: Vehicle 'h07_3of3_74338' ends teleporting on edge '-717578058#0', time=29229.00.
# Warning: Teleporting vehicle 'h07_3of3_58804'; waited too long (jam), lane='159307616#1_0', time=29230.00.
# Warning: Vehicle 'h07_3of3_58804' ends teleporting on edge '-194293402', time=29235.00.
# Warning: Vehicle 'h06_1of1_126601' performs emergency braking on lane '707379108#0_0' with decel=9.00, wished=4.00, severity=1.00, time=29239.00.
# Warning: Vehicle 'h06_1of1_36996' ends teleporting on edge '642218149#1', time=29240.00.
# Warning: Teleporting vehicle 'h07_3of3_74346'; waited too long (yield), lane='46961134_0', time=29245.00.
# Warning: Teleporting vehicle 'h07_3of3_24847'; waited too long (jam), lane='-112781626#1_0', time=29246.00.
# Warning: Vehicle 'h07_3of3_24847' ends teleporting on edge '-112781626#0', time=29246.00.
# Warning: Vehicle 'h08_1of3_50683' ends teleporting on edge '-342094982#0', time=29250.00.
# Warning: Vehicle 'h07_3of3_52722' ends teleporting on edge '862077739', time=29254.00.
# Warning: Teleporting vehicle 'h07_2of3_69838'; waited too long (yield), lane='629812482_0', time=29258.00.
# Warning: Teleporting vehicle 'h07_3of3_41816'; waited too long (yield), lane='53255190#0_0', time=29258.00.
# Warning: Vehicle 'h07_3of3_41816' ends teleporting on edge '53255190#1', time=29258.00.
# Warning: Vehicle 'h07_2of3_69838' ends teleporting on edge '37791875#0', time=29261.00.
# Warning: Vehicle 'h07_3of3_43090' ends teleporting on edge '183744261', time=29263.00.
# Warning: Vehicle 'h08_1of3_84492' performs emergency braking on lane '123313961#3_0' with decel=9.00, wished=4.00, severity=1.00, time=29276.00.
# Warning: Teleporting vehicle 'h08_1of3_28894'; waited too long (yield), lane='788479659_0', time=29279.00.
# Warning: Vehicle 'h08_1of3_28894' ends teleporting on edge '905807165', time=29279.00.
# Warning: Vehicle 'h07_3of3_52095' ends teleporting on edge '363325782#5', time=29288.00.
# Warning: Teleporting vehicle 'h08_1of3_65526'; waited too long (yield), lane='161031266#0_0', time=29300.00.
# Warning: Vehicle 'h06_1of1_68034' ends teleporting on edge '3625548', time=29303.00.
# Warning: Teleporting vehicle 'h08_1of3_75528'; waited too long (jam), lane=':3683436349_1_0', time=29307.00.
# Warning: Vehicle 'h08_1of3_75528' ends teleporting on edge '436469889', time=29307.00.
# Warning: Vehicle 'h06_1of1_69093' ends teleporting on edge '424764048#0', time=29308.00.
# Warning: Teleporting vehicle 'h06_1of1_40178'; waited too long (jam), lane='642215300#0_0', time=29311.00.
# Warning: Vehicle 'h06_1of1_68242' performs emergency braking on lane '342847333#1_0' with decel=9.00, wished=4.00, severity=1.00, time=29323.00.
# Warning: Vehicle 'h07_3of3_26117' ends teleporting on edge '660277188', time=29325.00.
# Warning: Teleporting vehicle 'h06_1of1_85346'; waited too long (yield), lane='156711713_0', time=29328.00.
# Warning: Vehicle 'h07_3of3_42032' performs emergency braking on lane '34960794#0_0' with decel=9.00, wished=4.00, severity=1.00, time=29329.00.
# Warning: Vehicle 'h07_3of3_52314' performs emergency braking on lane '140499113#0_0' with decel=9.00, wished=4.00, severity=1.00, time=29330.00.
# Warning: Vehicle 'h08_1of3_61438' performs emergency braking on lane ':1692421530_0_0' with decel=9.00, wished=4.00, severity=1.00, time=29330.00.
# Warning: Teleporting vehicle 'h06_1of1_67130'; waited too long (jam), lane='384429702#2_0', time=29332.00.
# Warning: Vehicle 'h07_1of3_24197' performs emergency braking on lane '-326356012#2_0' with decel=9.00, wished=4.00, severity=1.00, time=29332.00.
# Warning: Vehicle 'h06_1of1_67130' ends teleporting on edge '156711713', time=29332.00.
# Warning: Teleporting vehicle 'h08_1of3_84513'; waited too long (yield), lane='202809484#1_0', time=29334.00.
# Warning: Vehicle 'h07_3of3_52745' ends teleporting on edge '-53792070#3', time=29342.00.
# Warning: Teleporting vehicle 'h07_3of3_67609'; waited too long (yield), lane='-53189547#0_0', time=29344.00.
# Warning: Teleporting vehicle 'h07_3of3_58858'; waited too long (yield), lane='517960552_0', time=29346.00.
# Warning: Teleporting vehicle 'h06_1of1_114842'; waited too long (jam), lane='384429702#1_0', time=29348.00.
# Warning: Vehicle 'h06_1of1_114842' ends teleporting on edge '384429702#2', time=29351.00.
# Warning: Vehicle 'h07_3of3_67436' ends teleporting on edge '24855726#0', time=29353.00.
# Warning: Teleporting vehicle 'h06_1of1_68981'; waited too long (jam), lane='442216986#1_1', time=29354.00.
# Warning: Vehicle 'h06_1of1_68981' ends teleporting on edge '442216986#2', time=29354.00.
# Warning: Vehicle 'h07_3of3_73336' ends teleporting on edge '356962706#0', time=29358.00.
# Warning: Teleporting vehicle 'h08_1of3_66315'; waited too long (yield), lane=':1999988547_5_0', time=29369.00.
# Warning: Teleporting vehicle 'h07_3of3_41256'; waited too long (jam), lane='-52505112#0_0', time=29373.00.
# Warning: Vehicle 'h07_3of3_41256' ends teleporting on edge '331884239#0', time=29373.00.
# Warning: Teleporting vehicle 'h07_3of3_74114'; waited too long (yield), lane='331884239#2_0', time=29377.00.
# Warning: Vehicle 'h07_3of3_74114' ends teleporting on edge '363325770#1', time=29377.00.
# Warning: Teleporting vehicle 'h07_3of3_43312'; waited too long (yield), lane='189359622#1_0', time=29378.00.
# Warning: Teleporting vehicle 'h06_1of1_114901'; waited too long (jam), lane='384429687#6_0', time=29389.00.
# Warning: Vehicle 'h07_3of3_43312' ends teleporting on edge '342760954', time=29390.00.
# Warning: Vehicle 'h07_3of3_67609' ends teleporting on edge '-39791925#3', time=29392.00.
# Warning: Teleporting vehicle 'h06_1of1_116437'; waited too long (jam), lane=':773179301_1_2', time=29393.00.
# Warning: Teleporting vehicle 'h08_1of3_51434'; waited too long (yield), lane='-1341099313#0_0', time=29393.00.
# Warning: Vehicle 'h06_1of1_116437' ends teleporting on edge '436469878#0', time=29393.00.
# Warning: Vehicle 'h07_3of3_58858' ends teleporting on edge '-356962706#6', time=29393.00.
# Warning: Vehicle 'h08_1of3_84513' ends teleporting on edge '168678834#0', time=29394.00.
# Warning: Teleporting vehicle 'h07_3of3_73809'; waited too long (jam), lane=':1424936979_1_2', time=29402.00.
# Warning: Vehicle 'h07_3of3_73809' ends teleporting on edge '436469878#1', time=29402.00.
# Warning: Vehicle 'h08_1of3_65526' ends teleporting on edge '424764044#2', time=29403.00.
# Warning: Teleporting vehicle 'h08_1of3_28977'; waited too long (yield), lane='-1341099313#1_0', time=29407.00.
# Warning: Vehicle 'h08_1of3_28977' ends teleporting on edge '-1341099313#0', time=29407.00.
# Warning: Teleporting vehicle 'h07_1of3_66000'; waited too long (yield), lane='37788760_0', time=29412.00.
# Warning: Teleporting vehicle 'h07_1of3_66278'; waited too long (jam), lane='27775466#2_1', time=29423.00.
# Warning: Vehicle 'h07_1of3_66278' ends teleporting on edge '508861272', time=29423.00.
# Warning: Vehicle 'h06_1of1_68259' ends teleporting on edge '3625548', time=29424.00.
# Warning: Teleporting vehicle 'h07_3of3_25449'; waited too long (jam), lane='366469494#2_1', time=29430.00.
# Warning: Teleporting vehicle 'h06_1of1_36842'; waited too long (yield), lane='642218149#0_0', time=29430.00.
# Warning: Vehicle 'h06_1of1_36842' ends teleporting on edge '642218149#1', time=29430.00.
# Warning: Vehicle 'h07_3of3_25449' ends teleporting on edge '27775466#0', time=29430.00.
# Warning: Vehicle 'h07_3of3_27062' ends teleporting on edge '342738939', time=29434.00.
