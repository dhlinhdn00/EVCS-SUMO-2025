# %%
from __future__ import annotations

import os
import sys
import subprocess
import time
from pathlib import Path
from typing import Optional, Dict
import xml.etree.ElementTree as ET

# Bổ sung import TraCI
import traci

# ---------------------------------------------------------------------------
#  Project helpers và cấu hình
# ---------------------------------------------------------------------------

sys.path.append("/home/hoai-linh.dao/Works/EVCS/CEREMA-Mini/src")

from simulationHelpers import od2tripsForSubs  # noqa: E402
from config import TLSCYCLEADAPTATION_PY, TLSCOORDINATOR_PY  # noqa: E402

# ---------------------------------------------------------------------------
#  Constants
# ---------------------------------------------------------------------------

THREADS = min(1, os.cpu_count() or 1)
os.environ["OMP_NUM_THREADS"] = str(THREADS)

NET_XML = "/home/hoai-linh.dao/Works/EVCS/CEREMA-Mini/result/net-creation/310525-AMP-test-func/connected-network.net.xml"
TAZ_XML = "/home/hoai-linh.dao/Works/EVCS/CEREMA-Mini/result/net-creation/310525-AMP-test-func/taz.xml"
VTYPES_XML = "/home/hoai-linh.dao/Works/EVCS/CEREMA-Mini/data/additional-files/vtypes/eidm-1.xml"
ODS_DIR = "/home/hoai-linh.dao/Works/EVCS/CEREMA-Mini/data/processed-data/total_scenario/smooth-old-form-all"
TRIPS_DIR = "/home/hoai-linh.dao/Works/EVCS/CEREMA-Mini/data/processed-data/total_scenario/smooth-trips"
ROUTES_DIR = "home/hoai-linh.dao/Works/EVCS/CEREMA-Mini/data/processed-data/total_scenario/smooth-routes"

SIM_DIR = Path("/home/hoai-linh.dao/Works/EVCS/CEREMA-Mini/result/04-06-test-subs-strategy")
# TRIPS_DIR = SIM_DIR / "trips"
# ROUTES_DIR = SIM_DIR / "routes"
TLS_DIR = SIM_DIR / "tls"
OUTPUTS_DIR = SIM_DIR / "outputs"
STATES_DIR = SIM_DIR / "states"
LOGS_DIR = SIM_DIR / "logs"

trips = od2tripsForSubs(
    taz_file=TAZ_XML,
    trips_dir=TRIPS_DIR,
    od_dir=ODS_DIR,
    dist_id="car_eidm"
)
print("All generated trip files:")
for t in trips:
    print("  ", t)

# %%
#!/usr/bin/env python3
from __future__ import annotations

import os
import sys
import subprocess
from pathlib import Path
from typing import Optional, Dict
import xml.etree.ElementTree as ET
from collections import defaultdict

# ---------------------------------------------------------------------------
#  Project helpers và cấu hình
# ---------------------------------------------------------------------------
sys.path.append("/home/hoai-linh.dao/Works/EVCS/CEREMA-Mini/src")
from simulationHelpers import od2tripsForSubs  # noqa: E402

# ---------------------------------------------------------------------------
#  Constants (đã có trips)
# ---------------------------------------------------------------------------
NET_XML     = "/home/hoai-linh.dao/Works/EVCS/CEREMA-Mini/result/net-creation/310525-AMP-test-func/connected-network.net.xml"
TAZ_XML     = "/home/hoai-linh.dao/Works/EVCS/CEREMA-Mini/result/net-creation/310525-AMP-test-func/taz.xml"
VTYPES_XML  = "/home/hoai-linh.dao/Works/EVCS/CEREMA-Mini/data/additional-files/vtypes/eidm-1.xml"

ODS_DIR     = "/home/hoai-linh.dao/Works/EVCS/CEREMA-Mini/data/processed-data/total_scenario/smooth-old-form-all"
TRIPS_DIR   = "/home/hoai-linh.dao/Works/EVCS/CEREMA-Mini/data/processed-data/total_scenario/smooth-trips"
ROUTES_DIR  = "/home/hoai-linh.dao/Works/EVCS/CEREMA-Mini/data/processed-data/total_scenario/smooth-routes"
SPLIT_DIR   = "/home/hoai-linh.dao/Works/EVCS/CEREMA-Mini/data/processed-data/total_scenario/split-routes"

# Số threads cho duarouter
DUAROUTER_THREADS = "64"
# Seed (tuỳ ý)
SEED = 42

print("=== Step 1: Generating routes from each trip file ===")
os.makedirs(ROUTES_DIR, exist_ok=True)
routes_paths: list[str] = []

for trips_xml in sorted(Path(TRIPS_DIR).glob("trips_*.xml")):
    # Tạo tên file route tương ứng
    fname = trips_xml.name.replace("trips_", "routes_")
    route_xml = os.path.join(ROUTES_DIR, fname)
    duarouter_log = route_xml.replace(".xml", ".log")

    cmd = [
        "duarouter",
        "-n", NET_XML,
        "-r", str(trips_xml),
        "-a", VTYPES_XML,
        "-o", str(route_xml),
        "--log", str(duarouter_log),
        "--exit-times",
        "--named-routes",
        "--route-length",
        "--write-costs",
        "--routing-threads", DUAROUTER_THREADS,
        "--ignore-errors",
        "--seed", str(SEED),
    ]
    print(f"[RUN ] {' '.join(cmd)}")
    subprocess.run(cmd, check=True)
    routes_paths.append(route_xml)
    print(f"[INFO] Generated {route_xml}")
print()

# %%
#!/usr/bin/env python3
"""
count_trips_per_hour.py
-----------------------
Đọc tất cả các file XML trong thư mục “smooth-routes” gốc (bỏ qua các file *.alt.xml),
đếm số <vehicle> trong mỗi file, rồi tổng hợp theo giờ (XX). Kết quả in ra console.

Cách hoạt động:
1. Quét folder SMOOTH_ROUTES_DIR, tìm các file “routes_XX_YofZ.xml” (không tính *.alt.xml).
2. Với mỗi file, parse XML và đếm số thẻ <vehicle>.
3. Lấy chỉ số giờ XX từ tên file, cộng dồn vào dict hour_to_count.
4. Cuối cùng in số chuyến (vehicles) theo từng giờ.

Cách chạy:
    chmod +x count_trips_per_hour.py
    ./count_trips_per_hour.py
"""

import sys
import re
import xml.etree.ElementTree as ET
from pathlib import Path
from collections import defaultdict

# ===================================================================
# Cấu hình: đường dẫn tới thư mục chứa các file route gốc (smooth-routes)
# ===================================================================
SMOOTH_ROUTES_DIR = Path(
    "/home/hoai-linh.dao/Works/EVCS/CEREMA-Mini/"
    "data/processed-data/total_scenario/smooth-routes"
)

# ===================================================================
# Regex để bắt tên file: routes_XX_YofZ.xml (ví dụ "routes_07_2of3.xml")
# Bỏ qua mọi file chứa ".alt.xml" tự động
# ===================================================================
pattern = re.compile(r"^routes_(\d{2})_\d+of\d+\.xml$")

def count_trips_per_hour(routes_dir: Path) -> dict[str, int]:
    """
    Quét hết các file *.xml trong routes_dir (bỏ qua *.alt.xml),
    parse và đếm vehicle, rồi tổng hợp theo giờ.

    Trả về dict: key = "XX" (chuỗi 2 chữ số giờ), value = tổng số xe (int).
    """
    hour_to_count: dict[str, int] = defaultdict(int)

    for f in routes_dir.glob("*.xml"):
        if ".alt.xml" in f.name:
            continue
        m = pattern.match(f.name)
        if not m:
            continue

        hour = m.group(1)  # "07", "15", v.v.
        try:
            tree = ET.parse(f)
            root = tree.getroot()
        except ET.ParseError as e:
            print(f"[WARNING] Không parse được {f.name}: {e}", file=sys.stderr)
            continue

        # Đếm tất cả thẻ <vehicle> trực tiếp con của <routes>
        # Nếu có namespace, dùng .//vehicle để bắt mọi vehicle
        vehicles = root.findall(".//vehicle")
        count = len(vehicles)
        hour_to_count[hour] += count

    return dict(sorted(hour_to_count.items()))


def main():
    if not SMOOTH_ROUTES_DIR.is_dir():
        print(f"[ERROR] Thư mục không tồn tại: {SMOOTH_ROUTES_DIR}", file=sys.stderr)
        sys.exit(1)

    counts = count_trips_per_hour(SMOOTH_ROUTES_DIR)
    if not counts:
        print("[INFO] Không tìm thấy file hợp lệ hoặc không có vehicle nào.", file=sys.stderr)
        return

    print("Số chuyến (vehicles) theo từng giờ trong thư mục smooth-routes:")
    print("Hour\tCount")
    for hour, cnt in counts.items():
        print(f"{hour}\t{cnt}")


if __name__ == "__main__":
    main()

# %%
#!/usr/bin/env python3
"""
merge_vehicle_routes.py
-----------------------
Merge tất cả các file routes_XX_YofZ.xml (liệt kê <vehicle> chi tiết)
thuộc cùng một giờ XX thành một file routes_XX_merged.xml có period=3600s.

Cách chạy:
    python3 merge_vehicle_routes.py

Sau khi chạy xong, bạn sẽ có thư mục:
    smooth-routes-merged/
        routes_00_merged.xml
        routes_01_merged.xml
        ...
        routes_23_merged.xml
(chỉ tạo các giờ thực sự có file con).
"""

import sys
import re
import xml.etree.ElementTree as ET
from pathlib import Path
from collections import defaultdict

# ---------------------------------------------------------------------------
# Thay đổi nếu cần:
INPUT_DIR = Path(
    "/home/hoai-linh.dao/Works/EVCS/CEREMA-Mini/"
    "data/processed-data/total_scenario/smooth-routes"
)
OUTPUT_DIR = Path(
    "/home/hoai-linh.dao/Works/EVCS/CEREMA-Mini/"
    "data/processed-data/total_scenario/smooth-routes-merged"
)
# Mỗi giờ = 3600s
HOUR = 3600

# Regex để bắt tên file: routes_XX_YofZ.xml (vd. routes_07_2of3.xml)
pattern = re.compile(r"^routes_(\d{2})_(\d+)of(\d+)\.xml$")

# Tạo thư mục output nếu chưa có
OUTPUT_DIR.mkdir(parents=True, exist_ok=True)

# ---------------------------------------------------------------------------
# Bước 1: Quét tất cả file *.xml trong INPUT_DIR, group theo giờ
# ---------------------------------------------------------------------------
hour_to_entries = defaultdict(list)
for f in INPUT_DIR.glob("*.xml"):
    if ".alt.xml" in f.name:
        continue
    m = pattern.match(f.name)
    if not m:
        continue
    hh = int(m.group(1))      # ví dụ "07" → 7
    i = int(m.group(2))       # ví dụ "2" (trong "2of3")
    m_val = int(m.group(3))   # ví dụ "3" (trong "2of3")
    hour_to_entries[hh].append((f, i, m_val))

if not hour_to_entries:
    print(f"[ERROR] Không tìm thấy file routes_XX_YofZ.xml trong {INPUT_DIR}")
    sys.exit(1)

# ---------------------------------------------------------------------------
# Bước 2: Với mỗi giờ, merge thành routes_XX_merged.xml
# ---------------------------------------------------------------------------
for hh in sorted(hour_to_entries):
    entries = hour_to_entries[hh]
    # Giả định mọi entry của cùng giờ đều có cùng "m" (of m)
    m_values = set(mv for (_, _, mv) in entries)
    if len(m_values) != 1:
        print(f"[WARNING] Giờ {hh:02d} có nhiều giá trị m khác nhau: {m_values}")
    m_of = sorted(m_values)[0]
    period_sub = HOUR // m_of  # 3600/m

    print(f"[INFO] Giờ {hh:02d}: có {len(entries)} file (of{m_of}), period_sub={period_sub}s.")

    # Tạo tree mới (root=<routes>)
    merged_root = ET.Element("routes")

    # 2.1. Duyệt một vòng để thu thập vType và route định nghĩa chung
    vtype_dict = {}
    route_dict = {}
    for (route_file, _, _) in sorted(entries, key=lambda x: x[1]):
        tree = ET.parse(route_file)
        root = tree.getroot()
        # vType
        for v in root.findall("vType"):
            vid = v.attrib.get("id")
            if vid and vid not in vtype_dict:
                vtype_dict[vid] = ET.fromstring(ET.tostring(v))
        # route
        for r in root.findall("route"):
            rid = r.attrib.get("id")
            if rid and rid not in route_dict:
                route_dict[rid] = ET.fromstring(ET.tostring(r))

    # Append vType và route vào merged_root
    for v in vtype_dict.values():
        merged_root.append(v)
    for r in route_dict.values():
        merged_root.append(r)

    # 2.2. Duyệt lại từng file con, adjust depart của vehicle, append vào merged_root
    for (route_file, idx, _) in sorted(entries, key=lambda x: x[1]):
        offset = (idx - 1) * period_sub
        tree = ET.parse(route_file)
        root = tree.getroot()
        for veh in root.findall("vehicle"):
            veh_copy = ET.fromstring(ET.tostring(veh))
            depart_old = float(veh_copy.attrib.get("depart", "0"))
            depart_new = depart_old + offset
            veh_copy.set("depart", f"{depart_new:.2f}")
            merged_root.append(veh_copy)

    # 2.3. Ghi ra file merged
    merged_tree = ET.ElementTree(merged_root)
    merged_name = f"routes_{hh:02d}_merged.xml"
    merged_path = OUTPUT_DIR / merged_name
    merged_tree.write(merged_path, encoding="utf-8", xml_declaration=True)
    print(f"    → Đã tạo {merged_name} chứa {len(merged_root.findall('vehicle'))} vehicles.")

print("=== Hoàn thành merge cho tất cả các giờ! ===")

# %%
#!/usr/bin/env python3
"""
create_tls_for_merged.py
------------------------
Sau khi đã merge routes vào folder "smooth-routes-merged", dùng script này
để:
 1. Với mỗi file routes_XX_merged.xml, sinh:
       - tls_cycle_XX.add.xml
       - tls_coord_XX.add.xml
    → Lưu ở thư mục "smooth-tls/base/".
 2. Sau đó, copy hai file base đó thành N cặp file tương ứng với of N.
    Ví dụ giờ 07 có of3, sẽ tạo:
       - tls_cycle_07_1of3.add.xml
       - tls_coord_07_1of3.add.xml
       - tls_cycle_07_2of3.add.xml
       - tls_coord_07_2of3.add.xml
       - tls_cycle_07_3of3.add.xml
       - tls_coord_07_3of3.add.xml
"""

import sys
import subprocess
from pathlib import Path
import re
import shutil

# ---------------------------------------------------------------------------
# Thay đổi đường dẫn nếu cần:
# ---------------------------------------------------------------------------
# Đường dẫn file mạng lưới SUMO
NET_XML = (
    "/home/hoai-linh.dao/Works/EVCS/CEREMA-Mini/"
    "result/net-creation/310525-AMP-test-func/connected-network.net.xml"
)
# Đường dẫn tới tlsCycleAdaptation.py và tlsCoordinator.py
sys.path.append("/home/hoai-linh.dao/Works/EVCS/CEREMA-Mini/src")
try:
    from config import TLSCYCLEADAPTATION_PY, TLSCOORDINATOR_PY  # noqa: E402
except ImportError:
    print("[ERROR] Không tìm thấy config.py hoặc TLSCYCLEADAPTATION_PY/TLSCOORDINATOR_PY chưa khai báo.")
    sys.exit(1)

# Folder chứa routes đã merge (period=3600)
MERGED_DIR = Path(
    "/home/hoai-linh.dao/Works/EVCS/CEREMA-Mini/"
    "data/processed-data/total_scenario/smooth-routes-merged"
)

# Root folder chứa toàn bộ smooth-routes (để quét sub-of)
ORIG_ROUTES_DIR = MERGED_DIR.parent  # ví dụ: smooth-routes

# Folder đích lưu TLS (cuối cùng)
TLS_DIR = Path(
    "/home/hoai-linh.dao/Works/EVCS/CEREMA-Mini/"
    "data/processed-data/total_scenario/smooth-tls"
)

# Folder tạm để lưu file base (chưa phân of N)
BASE_TLS_DIR = TLS_DIR / "base"
BASE_TLS_DIR.mkdir(parents=True, exist_ok=True)
TLS_DIR.mkdir(parents=True, exist_ok=True)

# Regex để bắt tên file merged: routes_XX_merged.xml
merged_pattern = re.compile(r"^routes_(\d{2})_merged\.xml$")

# ---------------------------------------------------------------------------
# Bước 1: Với mỗi routes_XX_merged.xml, chạy tlsCycleAdaptation + tlsCoordinator
# ---------------------------------------------------------------------------
for merged_file in sorted(MERGED_DIR.glob("routes_*_merged.xml")):
    m = merged_pattern.match(merged_file.name)
    if not m:
        continue
    hh = int(m.group(1))
    tag = f"{hh:02d}"
    begin_time = hh * 3600

    # Tên file base (chưa phân of)
    tls_cycle_base = BASE_TLS_DIR / f"tls_cycle_{tag}.add.xml"
    tls_coord_base = BASE_TLS_DIR / f"tls_coord_{tag}.add.xml"

    # 1. Tạo tls_cycle_base nếu chưa có hoặc file rỗng
    if not tls_cycle_base.exists() or tls_cycle_base.stat().st_size == 0:
        print(f"[{tag}] Tạo tls_cycle_base từ {merged_file.name} … (period=3600)")
        cmd_cycle = [
            "python3",
            TLSCYCLEADAPTATION_PY,
            "-n", NET_XML,
            "-r", str(merged_file),
            "-b", str(begin_time),
            "-o", str(tls_cycle_base),
            "--min-cycle", "40",
            "--max-cycle", "120",
            "--yellow-time", "3",
            "-p", "a",
            "--verbose",
        ]
        try:
            subprocess.run(cmd_cycle, check=True)
        except subprocess.CalledProcessError as e:
            print(f"[ERROR] tlsCycleAdaptation thất bại cho giờ {tag}: {e}")
            continue
    else:
        print(f"[{tag}] tls_cycle_base đã tồn tại, bỏ qua.")

    # 2. Tạo tls_coord_base nếu chưa có hoặc file rỗng
    if not tls_coord_base.exists() or tls_coord_base.stat().st_size == 0:
        print(f"[{tag}] Tạo tls_coord_base từ {merged_file.name} …")
        cmd_coord = [
            "python3",
            TLSCOORDINATOR_PY,
            "-n", NET_XML,
            "-r", str(merged_file),
            "-a", str(tls_cycle_base),
            "-o", str(tls_coord_base),
        ]
        try:
            subprocess.run(cmd_coord, check=True)
        except subprocess.CalledProcessError as e:
            print(f"[ERROR] tlsCoordinator thất bại cho giờ {tag}: {e}")
            continue
    else:
        print(f"[{tag}] tls_coord_base đã tồn tại, bỏ qua.")

print("=== Hoàn thành tạo base TLS cho mọi giờ! ===\n")

# ---------------------------------------------------------------------------
# Bước 2: Lấy thông tin số phần of N và copy base → of N
# ---------------------------------------------------------------------------

# Regex để bắt tên file gốc: routes_XX_partofM.xml
orig_pattern = re.compile(r"^routes_(\d{2})_(\d+)of(\d+)\.xml$")

# Tạo map: hour → max_m (giả sử mọi file cùng giờ có cùng M)
hour_to_m: dict[int, int] = {}
for f in sorted(ORIG_ROUTES_DIR.glob("routes_*.xml")):
    m = orig_pattern.match(f.name)
    if not m:
        continue
    hh = int(m.group(1))
    m_of = int(m.group(3))
    # Lấy max của m_of
    if hh not in hour_to_m or hour_to_m[hh] < m_of:
        hour_to_m[hh] = m_of

if not hour_to_m:
    print("[WARNING] Không tìm thấy bất kỳ file sub-of trong thư mục gốc routes.")
else:
    print(f"[INFO] Phát hiện cấu hình of M như sau: {hour_to_m}\n")

# Với mỗi giờ, copy base thành các ofN
for hh, m_of in sorted(hour_to_m.items()):
    tag = f"{hh:02d}"
    base_cycle = BASE_TLS_DIR / f"tls_cycle_{tag}.add.xml"
    base_coord = BASE_TLS_DIR / f"tls_coord_{tag}.add.xml"

    if not base_cycle.exists() or not base_coord.exists():
        print(f"[WARNING] Bỏ qua giờ {tag}, không có base TLS trong {BASE_TLS_DIR}.")
        continue

    print(f"[{tag}] Phân ra {m_of} file TLS tương ứng of{m_of}:")

    for part in range(1, m_of + 1):
        new_cycle = TLS_DIR / f"tls_cycle_{tag}_{part}of{m_of}.add.xml"
        new_coord = TLS_DIR / f"tls_coord_{tag}_{part}of{m_of}.add.xml"

        # Copy nếu chưa tồn tại hoặc muốn ghi đè thì remove rồi copy
        if new_cycle.exists():
            new_cycle.unlink()
        shutil.copy(base_cycle, new_cycle)
        print(f"  - Tạo {new_cycle.name}")

        if new_coord.exists():
            new_coord.unlink()
        shutil.copy(base_coord, new_coord)
        print(f"  - Tạo {new_coord.name}")

    print("")  # dòng trống giữa các giờ

print("=== Hoàn thành split base TLS thành các ofN! ===")
# Out:
# [00] tls_cycle_base đã tồn tại, bỏ qua.
# [00] tls_coord_base đã tồn tại, bỏ qua.
# [01] Tạo tls_cycle_base từ routes_01_merged.xml … (period=3600)
# Warning: The period is less than 1 hour. The flows will be proportionally scaled up to 1-hour flow with the scaling factor 1.000161111111111.
# the total number of tls: 5960
# Begin time:3600.0
# parsing route file: /home/hoai-linh.dao/Works/EVCS/CEREMA-Mini/data/processed-data/total_scenario/smooth-routes-merged/routes_01_merged.xml
# Parsed 158619 vehicles passing traffic lights from /home/hoai-linh.dao/Works/EVCS/CEREMA-Mini/data/processed-data/total_scenario/smooth-routes-merged/routes_01_merged.xml.
# tl-logic ID: 10004336247
# phase: 0
# group flows: [79, 17.00273888888889, 7.001127777777778]
# The used lanes: [[0], [0]]
# the current cycle length:90 sec
# Green time for phase 0: 37
# The optimal cycle length:40
#
# Duration for Phase 1 is from the input file.
# Duration for Phase 2 is from the input file.
# tl-logic ID: 10004336274
# phase: 0
# group flows: [79, 17.00273888888889, 7.001127777777778]
# The used lanes: [[0], [0]]
# the current cycle length:90 sec
# Green time for phase 0: 37
# The optimal cycle length:40
#
# Duration for Phase 1 is from the input file.
# Duration for Phase 2 is from the input file.
# tl-logic ID: 1004063595
# phase: 0
# group flows: [82, 9.00145]
# The used lanes: [[0]]
# the current cycle length:90 sec
# Green time for phase 0: 37
# The optimal cycle length:40
#
# Duration for Phase 1 is from the input file.
# Duration for Phase 2 is from the input file.
# tl-logic ID: 10044973712
# phase: 0
# group flows: [79, 4.000644444444444]
# The used lanes: [[0]]
# the current cycle length:90 sec
# Green time for phase 0: 37
# The optimal cycle length:40
#
# Duration for Phase 1 is from the input file.
# Duration for Phase 2 is from the input file.
# tl-logic ID: 10045462117
# phase: 0
# group flows: [79, 15.002416666666665]
# The used lanes: [[0, 1]]
# the current cycle length:90 sec
# Green time for phase 0: 37
# The optimal cycle length:40
#
# Duration for Phase 1 is from the input file.
# Duration for Phase 2 is from the input file.
# tl-logic ID: 10045745783
# phase: 0
# group flows: [79, 31.004994444444442, 23.003705555555555]
# The used lanes: [[0, 1], [0, 1]]
# the current cycle length:90 sec
# Green time for phase 0: 37
# The optimal cycle length:40
#
# Duration for Phase 1 is from the input file.
# Duration for Phase 2 is from the input file.
# tl-logic ID: 10045745784
# phase: 0
# group flows: [82, 0, 1.000161111111111]
# The used lanes: [[0], [0]]
# the current cycle length:90 sec
# Green time for phase 0: 37
# The optimal cycle length:40
#
# Duration for Phase 1 is from the input file.
# Duration for Phase 2 is from the input file.
# tl-logic ID: 10045858637
# phase: 0
# group flows: [82, 38.00612222222222]
# The used lanes: [[0, 1, 2, 3]]
# the current cycle length:90 sec
# Green time for phase 0: 37
# The optimal cycle length:40
#
# Duration for Phase 1 is from the input file.
# Duration for Phase 2 is from the input file.
# tl-logic ID: 10045858640
# phase: 0
# group flows: [79, 40.00644444444444]
# The used lanes: [[0, 1]]
# the current cycle length:90 sec
# Green time for phase 0: 37
# The optimal cycle length:40
#
# Duration for Phase 1 is from the input file.
# Duration for Phase 2 is from the input file.
# tl-logic ID: 10045858643
# phase: 0
# group flows: [82, 81.01304999999999, 62.009988888888884]
# The used lanes: [[0], [0]]
# the current cycle length:90 sec
# Green time for phase 0: 37
# The optimal cycle length:40
#
# Duration for Phase 1 is from the input file.
# Duration for Phase 2 is from the input file.
# tl-logic ID: 10045858644
# phase: 0
# group flows: [79, 15.002416666666665, 4.000644444444444]
# The used lanes: [[0, 1], [0, 1]]
# the current cycle length:90 sec
# Green time for phase 0: 37
# The optimal cycle length:40
#
# Duration for Phase 1 is from the input file.
# Duration for Phase 2 is from the input file.
# tl-logic ID: 10045858646
# phase: 0
# group flows: [79, 15.002416666666665, 4.000644444444444]
# The used lanes: [[0, 1], [0, 1]]
# the current cycle length:90 sec
# Green time for phase 0: 37
# The optimal cycle length:40
#
# Duration for Phase 1 is from the input file.
# Duration for Phase 2 is from the input file.
# tl-logic ID: 10045858650
# phase: 0
# group flows: [79, 19.00306111111111, 9.00145]
# The used lanes: [[0], [0]]
# the current cycle length:90 sec
# Green time for phase 0: 37
# The optimal cycle length:40
#
# Duration for Phase 1 is from the input file.
# Duration for Phase 2 is from the input file.
# tl-logic ID: 10045933297
# phase: 0
# group flows: [82, 3.0004833333333334, 8.001288888888888]
# The used lanes: [[0, 1], [0, 1]]
# the current cycle length:90 sec
# Green time for phase 0: 37
# The optimal cycle length:40
#
# Duration for Phase 1 is from the input file.
# Duration for Phase 2 is from the input file.
# tl-logic ID: 10046280741
# phase: 0
# group flows: [82, 8.001288888888888, 10.00161111111111]
# The used lanes: [[0], [0]]
# the current cycle length:90 sec
# Green time for phase 0: 37
# The optimal cycle length:40
#
# Duration for Phase 1 is from the input file.
# Duration for Phase 2 is from the input file.
# tl-logic ID: 10050839708
# phase: 0
# group flows: [82, 16.002577777777777, 13.002094444444444]
# The used lanes: [[0], [0]]
# the current cycle length:90 sec
# Green time for phase 0: 37
# The optimal cycle length:40
#
# Duration for Phase 1 is from the input file.
# Duration for Phase 2 is from the input file.
# tl-logic ID: 10050839709
# phase: 0
# group flows: [82, 16.002577777777777, 13.002094444444444]
# The used lanes: [[0], [0]]
# the current cycle length:90 sec
# Green time for phase 0: 37
# The optimal cycle length:40
#
# Duration for Phase 1 is from the input file.
# Duration for Phase 2 is from the input file.
# tl-logic ID: 10050839710
# phase: 0
# group flows: [82, 16.002577777777777, 13.002094444444444]
# The used lanes: [[0], [0]]
# the current cycle length:90 sec
# Green time for phase 0: 37
# The optimal cycle length:40
#
# Duration for Phase 1 is from the input file.
# Duration for Phase 2 is from the input file.
# tl-logic ID: 10069024725
# phase: 0
# group flows: [82, 1.000161111111111]
# The used lanes: [[0]]
# the current cycle length:90 sec
# Green time for phase 0: 37
# The optimal cycle length:40
#
# Duration for Phase 1 is from the input file.
# Duration for Phase 2 is from the input file.
# tl-logic ID: 10069024726
# phase: 0
# group flows: [82, 1.000161111111111]
# The used lanes: [[0]]
# the current cycle length:90 sec
# Green time for phase 0: 37
# The optimal cycle length:40
#
# Duration for Phase 1 is from the input file.
# Duration for Phase 2 is from the input file.
# tl-logic ID: 10069024728
# phase: 0
# group flows: [80, 13.002094444444444, 11.001772222222222]
# The used lanes: [[0], [0]]
# the current cycle length:90 sec
# Green time for phase 0: 37
# The optimal cycle length:40
#
# Duration for Phase 1 is from the input file.
# Duration for Phase 2 is from the input file.
# tl-logic ID: 10069024729
# phase: 0
# group flows: [80, 14.002255555555555, 11.001772222222222]
# The used lanes: [[0], [0]]
# the current cycle length:90 sec
# Green time for phase 0: 37
# The optimal cycle length:40
#
# Duration for Phase 1 is from the input file.
# Duration for Phase 2 is from the input file.
# tl-logic ID: 10073622362
# phase: 0
# group flows: [82, 1.000161111111111]
# The used lanes: [[0]]
# the current cycle length:90 sec
# Green time for phase 0: 37
# The optimal cycle length:40
#
# Duration for Phase 1 is from the input file.
# Duration for Phase 2 is from the input file.
# tl-logic ID: 10073622364
# phase: 0
# group flows: [82, 1.000161111111111]
# The used lanes: [[0]]
# the current cycle length:90 sec
# Green time for phase 0: 37
# The optimal cycle length:40
#
# Duration for Phase 1 is from the input file.
# Duration for Phase 2 is from the input file.
# tl-logic ID: 10073622366
# phase: 0
# group flows: [82, 1.000161111111111]
# The used lanes: [[0]]
# the current cycle length:90 sec
# Green time for phase 0: 37
# The optimal cycle length:40
#
# Duration for Phase 1 is from the input file.
# Duration for Phase 2 is from the input file.
# tl-logic ID: 10073622368
# phase: 0
# group flows: [82, 1.000161111111111]
# The used lanes: [[0]]
# the current cycle length:90 sec
# Green time for phase 0: 37
# The optimal cycle length:40
#
# Duration for Phase 1 is from the input file.
# Duration for Phase 2 is from the input file.
# tl-logic ID: 10076831966
# phase: 0
# group flows: [82, 33.005316666666666, 33.005316666666666]
# The used lanes: [[0], [0]]
# the current cycle length:90 sec
# Green time for phase 0: 37
# The optimal cycle length:40
#
# Duration for Phase 1 is from the input file.
# Duration for Phase 2 is from the input file.
# tl-logic ID: 1008636727
# TLS: 1008636727 --> the tl-indices with more than one major-green:[6, 6, 6]
# phase: 0
# group flows: [42, 0, 9.501530555555554]
# The used lanes: [[0], [0]]
# phase: 2
# group flows: [42, 4.000644444444444, 9.501530555555554]
# The used lanes: [[0], [0]]
# the current cycle length:90 sec
# Green time for phase 0: 17
# Green time for phase 2: 17
# The optimal cycle length:40
#
# tl-logic ID: 10087590060
# phase: 0
# group flows: [82, 1.000161111111111, 0]
# The used lanes: [[0], [0]]
# the current cycle length:90 sec
# Green time for phase 0: 37
# The optimal cycle length:40
#
# Duration for Phase 1 is from the input file.
# Duration for Phase 2 is from the input file.
# tl-logic ID: 10126593805
# phase: 0
# group flows: [82, 1.000161111111111, 0]
# The used lanes: [[0], [0]]
# the current cycle length:90 sec
# Green time for phase 0: 37
# The optimal cycle length:40
#
# Duration for Phase 1 is from the input file.
# Duration for Phase 2 is from the input file.
# tl-logic ID: 10126593806
# phase: 0
# group flows: [82, 1.000161111111111]
# The used lanes: [[0, 1]]
# the current cycle length:90 sec
# Green time for phase 0: 37
# The optimal cycle length:40
#
# Duration for Phase 1 is from the input file.
# Duration for Phase 2 is from the input file.
# tl-logic ID: 10140298854
# phase: 0
# group flows: [82, 1.000161111111111]
# The used lanes: [[0]]
# the current cycle length:90 sec
# Green time for phase 0: 37
# The optimal cycle length:40
#
# Duration for Phase 1 is from the input file.
# Duration for Phase 2 is from the input file.
# tl-logic ID: 10195151079
# phase: 0
# group flows: [82, 19.00306111111111, 33.005316666666666]
# The used lanes: [[0, 1], [0]]
# the current cycle length:90 sec
# Green time for phase 0: 37
# The optimal cycle length:40
#
# Duration for Phase 1 is from the input file.
# Duration for Phase 2 is from the input file.
# tl-logic ID: 10195155520
# phase: 0
# group flows: [80, 13.002094444444444]
# The used lanes: [[0, 1]]
# the current cycle length:90 sec
# Green time for phase 0: 37
# The optimal cycle length:40
#
# Duration for Phase 1 is from the input file.
# Duration for Phase 2 is from the input file.
# tl-logic ID: 10195155521
# phase: 0
# group flows: [80, 14.002255555555555]
# The used lanes: [[0, 1]]
# the current cycle length:90 sec
# Green time for phase 0: 37
# The optimal cycle length:40
#
# Duration for Phase 1 is from the input file.
# Duration for Phase 2 is from the input file.
# tl-logic ID: 10197514782
# phase: 0
# group flows: [80, 5.000805555555555, 9.00145]
# The used lanes: [[0], [0]]
# the current cycle length:90 sec
# Green time for phase 0: 37
# The optimal cycle length:40
#
# Duration for Phase 1 is from the input file.
# Duration for Phase 2 is from the input file.
# tl-logic ID: 10197514783
# phase: 0
# group flows: [80, 5.000805555555555, 9.00145]
# The used lanes: [[0], [0]]
# the current cycle length:90 sec
# Green time for phase 0: 37
# The optimal cycle length:40
#
# Duration for Phase 1 is from the input file.
# Duration for Phase 2 is from the input file.
# tl-logic ID: 10219792021
# phase: 0
# group flows: [80, 16.002577777777777, 17.00273888888889]
# The used lanes: [[0], [0]]
# the current cycle length:90 sec
# Green time for phase 0: 37
# The optimal cycle length:40
#
# Duration for Phase 1 is from the input file.
# Duration for Phase 2 is from the input file.
# tl-logic ID: 10224062427
# phase: 0
# group flows: [82, 10.00161111111111, 4.000644444444444]
# The used lanes: [[0], [0]]
# the current cycle length:90 sec
# Green time for phase 0: 37
# The optimal cycle length:40
#
# Duration for Phase 1 is from the input file.
# Duration for Phase 2 is from the input file.
# tl-logic ID: 10224941883
# phase: 0
# group flows: [82, 12.001933333333334, 2.000322222222222]
# The used lanes: [[0], [0]]
# the current cycle length:90 sec
# Green time for phase 0: 37
# The optimal cycle length:40
#
# Duration for Phase 1 is from the input file.
# Duration for Phase 2 is from the input file.
# tl-logic ID: 10224941888
# phase: 0
# group flows: [82, 11.001772222222222, 5.000805555555555]
# The used lanes: [[0], [0]]
# the current cycle length:90 sec
# Green time for phase 0: 37
# The optimal cycle length:40
#
# Duration for Phase 1 is from the input file.
# Duration for Phase 2 is from the input file.
# tl-logic ID: 1024070777
# phase: 0
# group flows: [82, 3.0004833333333334, 6.000966666666667]
# The used lanes: [[0], [0]]
# the current cycle length:90 sec
# Green time for phase 0: 37
# The optimal cycle length:40
#
# Duration for Phase 1 is from the input file.
# Duration for Phase 2 is from the input file.
# tl-logic ID: 10250714126
# phase: 0
# group flows: [80, 19.00306111111111, 11.001772222222222]
# The used lanes: [[0], [0]]
# the current cycle length:90 sec
# Green time for phase 0: 37
# The optimal cycle length:40
#
# Duration for Phase 1 is from the input file.
# Duration for Phase 2 is from the input file.
# tl-logic ID: 10250714127
# phase: 0
# group flows: [80, 19.00306111111111, 11.001772222222222]
# The used lanes: [[0], [0]]
# the current cycle length:90 sec
# Green time for phase 0: 37
# The optimal cycle length:40
#
# Duration for Phase 1 is from the input file.
# Duration for Phase 2 is from the input file.
# tl-logic ID: 10250714152
# phase: 0
# group flows: [82, 3.0004833333333334, 7.001127777777778]
# The used lanes: [[0], [0]]
# the current cycle length:90 sec
# Green time for phase 0: 37
# The optimal cycle length:40
#
# Duration for Phase 1 is from the input file.
# Duration for Phase 2 is from the input file.
# tl-logic ID: 10273676480
# phase: 0
# group flows: [82, 36.0058, 34.00547777777778]
# The used lanes: [[0], [0]]
# the current cycle length:90 sec
# Green time for phase 0: 37
# The optimal cycle length:40
#
# Duration for Phase 1 is from the input file.
# Duration for Phase 2 is from the input file.
# tl-logic ID: 10273676481
# phase: 0
# group flows: [82, 36.0058, 35.00563888888889]
# The used lanes: [[0], [0]]
# the current cycle length:90 sec
# Green time for phase 0: 37
# The optimal cycle length:40
#
# Duration for Phase 1 is from the input file.
# Duration for Phase 2 is from the input file.
# tl-logic ID: 10273676482
# phase: 0
# group flows: [82, 36.0058, 34.00547777777778]
# The used lanes: [[0], [0]]
# the current cycle length:90 sec
# Green time for phase 0: 37
# The optimal cycle length:40
#
# Duration for Phase 1 is from the input file.
# Duration for Phase 2 is from the input file.
# tl-logic ID: 1028650428
# phase: 0
# group flows: [80, 18.0029, 13.002094444444444]
# The used lanes: [[0], [0]]
# the current cycle length:90 sec
# Green time for phase 0: 37
# The optimal cycle length:40
#
# Duration for Phase 1 is from the input file.
# Duration for Phase 2 is from the input file.
# tl-logic ID: 1028650431
# phase: 0
# group flows: [80, 4.000644444444444, 9.00145]
# The used lanes: [[0], [0]]
# the current cycle length:90 sec
# Green time for phase 0: 37
# The optimal cycle length:40
#
# Duration for Phase 1 is from the input file.
# Duration for Phase 2 is from the input file.
# tl-logic ID: 10287682181
# phase: 0
# group flows: [82, 3.0004833333333334, 43.006927777777776]
# The used lanes: [[0], [0]]
# the current cycle length:90 sec
# Green time for phase 0: 37
# The optimal cycle length:40
#
# Duration for Phase 1 is from the input file.
# Duration for Phase 2 is from the input file.
# tl-logic ID: 10287682317
# phase: 0
# group flows: [80, 16.002577777777777, 15.002416666666665]
# The used lanes: [[0], [0]]
# the current cycle length:90 sec
# Green time for phase 0: 37
# The optimal cycle length:40
#
# Duration for Phase 1 is from the input file.
# Duration for Phase 2 is from the input file.
# tl-logic ID: 10287682318
# phase: 0
# group flows: [80, 16.002577777777777, 15.002416666666665]
# The used lanes: [[0], [0]]
# the current cycle length:90 sec
# Green time for phase 0: 37
# The optimal cycle length:40
#
# Duration for Phase 1 is from the input file.
# Duration for Phase 2 is from the input file.
# tl-logic ID: 10287682319
# phase: 0
# group flows: [80, 16.002577777777777, 15.002416666666665]
# The used lanes: [[0], [0]]
# the current cycle length:90 sec
# Green time for phase 0: 37
# The optimal cycle length:40
#
# Duration for Phase 1 is from the input file.
# Duration for Phase 2 is from the input file.
# tl-logic ID: 10287682327
# phase: 0
# group flows: [80, 17.00273888888889, 18.0029]
# The used lanes: [[0], [0]]
# the current cycle length:90 sec
# Green time for phase 0: 37
# The optimal cycle length:40
#
# Duration for Phase 1 is from the input file.
# Duration for Phase 2 is from the input file.
# tl-logic ID: 10287682328
# phase: 0
# group flows: [80, 17.00273888888889, 17.00273888888889]
# The used lanes: [[0], [0]]
# the current cycle length:90 sec
# Green time for phase 0: 37
# The optimal cycle length:40
#
# Duration for Phase 1 is from the input file.
# Duration for Phase 2 is from the input file.
# tl-logic ID: 10287682329
# phase: 0
# group flows: [80, 17.00273888888889, 17.00273888888889]
# The used lanes: [[0], [0]]
# the current cycle length:90 sec
# Green time for phase 0: 37
# The optimal cycle length:40
#
# Duration for Phase 1 is from the input file.
# Duration for Phase 2 is from the input file.
# tl-logic ID: 10287682387
# phase: 0
# group flows: [80, 15.002416666666665, 15.002416666666665]
# The used lanes: [[0], [0]]
# the current cycle length:90 sec
# Green time for phase 0: 37
# The optimal cycle length:40
#
# Duration for Phase 1 is from the input file.
# Duration for Phase 2 is from the input file.
# tl-logic ID: 10287682389
# phase: 0
# group flows: [82, 1.000161111111111]
# The used lanes: [[0]]
# the current cycle length:90 sec
# Green time for phase 0: 37
# The optimal cycle length:40
#
# Duration for Phase 1 is from the input file.
# Duration for Phase 2 is from the input file.
# tl-logic ID: 10287682390
# phase: 0
# group flows: [82, 0, 1.000161111111111]
# The used lanes: [[0], [0]]
# the current cycle length:90 sec
# Green time for phase 0: 37
# The optimal cycle length:40
#
# Duration for Phase 1 is from the input file.
# Duration for Phase 2 is from the input file.
# tl-logic ID: 1028829867
# phase: 0
# group flows: [82, 1.000161111111111, 46.00741111111111]
# The used lanes: [[0], [0]]
# the current cycle length:90 sec
# Green time for phase 0: 37
# The optimal cycle length:40
#
# Duration for Phase 1 is from the input file.
# Duration for Phase 2 is from the input file.
# tl-logic ID: 1030147252
# phase: 0
# group flows: [82, 4.000644444444444, 8.001288888888888]
# The used lanes: [[0], [0]]
# the current cycle length:90 sec
# Green time for phase 0: 37
# The optimal cycle length:40
#
# Duration for Phase 1 is from the input file.
# Duration for Phase 2 is from the input file.
# tl-logic ID: 1035263389
# phase: 0
# group flows: [79, 8.001288888888888]
# The used lanes: [[0, 1, 2]]
# the current cycle length:90 sec
# Green time for phase 0: 37
# The optimal cycle length:40
#
# Duration for Phase 1 is from the input file.
# Duration for Phase 2 is from the input file.
# tl-logic ID: 1035605826
# phase: 0
# group flows: [82, 11.001772222222222, 15.002416666666665]
# The used lanes: [[0], [0]]
# the current cycle length:90 sec
# Green time for phase 0: 37
# The optimal cycle length:40
#
# Duration for Phase 1 is from the input file.
# Duration for Phase 2 is from the input file.
# tl-logic ID: 1035605892
# phase: 0
# group flows: [80, 5.000805555555555, 0]
# The used lanes: [[0], [0]]
# the current cycle length:90 sec
# Green time for phase 0: 37
# The optimal cycle length:40
#
# Duration for Phase 1 is from the input file.
# Duration for Phase 2 is from the input file.
# tl-logic ID: 1037207640
# phase: 0
# group flows: [80, 3.0004833333333334, 4.000644444444444]
# The used lanes: [[0], [0]]
# the current cycle length:90 sec
# Green time for phase 0: 37
# The optimal cycle length:40
#
# Duration for Phase 1 is from the input file.
# Duration for Phase 2 is from the input file.
# tl-logic ID: 1037207719
# phase: 0
# group flows: [80, 4.000644444444444]
# The used lanes: [[0, 1, 2]]
# the current cycle length:90 sec
# Green time for phase 0: 37
# The optimal cycle length:40
#
# Duration for Phase 1 is from the input file.
# Duration for Phase 2 is from the input file.
# tl-logic ID: 1049052343
# phase: 0
# group flows: [80, 22.003544444444444]
# The used lanes: [[0]]
# the current cycle length:90 sec
# Green time for phase 0: 37
# The optimal cycle length:40
#
# Duration for Phase 1 is from the input file.
# Duration for Phase 2 is from the input file.
# tl-logic ID: 1052989453
# phase: 0
# group flows: [82, 24.003866666666667, 30.00483333333333]
# The used lanes: [[0], [0]]
# the current cycle length:90 sec
# Green time for phase 0: 37
# The optimal cycle length:40
#
# Duration for Phase 1 is from the input file.
# Duration for Phase 2 is from the input file.
# tl-logic ID: 1052989587
# phase: 0
# group flows: [82, 24.003866666666667, 30.00483333333333]
# The used lanes: [[0], [0]]
# the current cycle length:90 sec
# Green time for phase 0: 37
# The optimal cycle length:40
#
# Duration for Phase 1 is from the input file.
# Duration for Phase 2 is from the input file.
# tl-logic ID: 1053203245
# phase: 0
# group flows: [79, 54.0087]
# The used lanes: [[0, 1]]
# the current cycle length:90 sec
# Green time for phase 0: 37
# The optimal cycle length:40
#
# Duration for Phase 1 is from the input file.
# Duration for Phase 2 is from the input file.
# tl-logic ID: 1053203865
# phase: 0
# group flows: [82, 39.00628333333333]
# The used lanes: [[0, 1]]
# the current cycle length:90 sec
# Green time for phase 0: 37
# The optimal cycle length:40
#
# Duration for Phase 1 is from the input file.
# Duration for Phase 2 is from the input file.
# tl-logic ID: 1053204246
# phase: 0
# group flows: [80, 18.0029]
# The used lanes: [[0]]
# the current cycle length:90 sec
# Green time for phase 0: 37
# The optimal cycle length:40
#
# Duration for Phase 1 is from the input file.
# Duration for Phase 2 is from the input file.
# tl-logic ID: 1053204391
# phase: 0
# group flows: [82, 35.00563888888889]
# The used lanes: [[0]]
# the current cycle length:90 sec
# Green time for phase 0: 37
# The optimal cycle length:40
#
# Duration for Phase 1 is from the input file.
# Duration for Phase 2 is from the input file.
# tl-logic ID: 1053205954
# phase: 0
# group flows: [79, 54.0087]
# The used lanes: [[0, 1]]
# the current cycle length:90 sec
# Green time for phase 0: 37
# The optimal cycle length:40
#
# Duration for Phase 1 is from the input file.
# Duration for Phase 2 is from the input file.
# tl-logic ID: 1053207349
# phase: 0
# group flows: [80, 24.003866666666667]
# The used lanes: [[0]]
# the current cycle length:90 sec
# Green time for phase 0: 37
# The optimal cycle length:40
#
# Duration for Phase 1 is from the input file.
# Duration for Phase 2 is from the input file.
# tl-logic ID: 10537419408
# phase: 0
# group flows: [79, 55.00886111111111, 57.00918333333333]
# The used lanes: [[0], [0]]
# the current cycle length:90 sec
# Green time for phase 0: 37
# The optimal cycle length:40
#
# Duration for Phase 1 is from the input file.
# Duration for Phase 2 is from the input file.
# tl-logic ID: 10554193373
# phase: 0
# group flows: [79, 53.008538888888886]
# The used lanes: [[0, 1]]
# the current cycle length:90 sec
# Green time for phase 0: 37
# The optimal cycle length:40
#
# Duration for Phase 1 is from the input file.
# Duration for Phase 2 is from the input file.
# tl-logic ID: 10554193374
# phase: 0
# group flows: [82, 86.01385555555555, 79.01272777777777]
# The used lanes: [[0], [0]]
# the current cycle length:90 sec
# Green time for phase 0: 37
# The optimal cycle length:40
#
# Duration for Phase 1 is from the input file.
# Duration for Phase 2 is from the input file.
# tl-logic ID: 10575044249
# phase: 0
# group flows: [82, 1.000161111111111]
# The used lanes: [[0]]
# the current cycle length:90 sec
# Green time for phase 0: 37
# The optimal cycle length:40
#
# Duration for Phase 1 is from the input file.
# Duration for Phase 2 is from the input file.
# tl-logic ID: 10576694049
# phase: 0
# group flows: [80, 6.000966666666667, 1.000161111111111]
# The used lanes: [[0], [0]]
# the current cycle length:90 sec
# Green time for phase 0: 37
# The optimal cycle length:40
#
# Duration for Phase 1 is from the input file.
# Duration for Phase 2 is from the input file.
# tl-logic ID: 10579681584
# phase: 0
# group flows: [82, 21.003383333333332]
# The used lanes: [[0]]
# the current cycle length:90 sec
# Green time for phase 0: 37
# The optimal cycle length:40
#
# Duration for Phase 1 is from the input file.
# Duration for Phase 2 is from the input file.
# tl-logic ID: 10579681586
# phase: 0
# group flows: [82, 9.00145]
# The used lanes: [[0]]
# the current cycle length:90 sec
# Green time for phase 0: 37
# The optimal cycle length:40
#
# Duration for Phase 1 is from the input file.
# Duration for Phase 2 is from the input file.
# tl-logic ID: 10591372330
# phase: 0
# group flows: [82, 68.01095555555555, 40.00644444444444]
# The used lanes: [[0], [0]]
# the current cycle length:90 sec
# Green time for phase 0: 37
# The optimal cycle length:40
#
# Duration for Phase 1 is from the input file.
# Duration for Phase 2 is from the input file.
# tl-logic ID: 10591372332
# phase: 0
# group flows: [82, 74.01192222222222, 83.01337222222222]
# The used lanes: [[0], [0]]
# the current cycle length:90 sec
# Green time for phase 0: 37
# The optimal cycle length:40
#
# Duration for Phase 1 is from the input file.
# Duration for Phase 2 is from the input file.
# tl-logic ID: 10591372334
# phase: 0
# group flows: [82, 3.0004833333333334, 1.000161111111111]
# The used lanes: [[0], [0]]
# the current cycle length:90 sec
# Green time for phase 0: 37
# The optimal cycle length:40
#
# Duration for Phase 1 is from the input file.
# Duration for Phase 2 is from the input file.
# tl-logic ID: 10591372336
# phase: 0
# group flows: [82, 3.0004833333333334, 1.000161111111111]
# The used lanes: [[0], [0]]
# the current cycle length:90 sec
# Green time for phase 0: 37
# The optimal cycle length:40
#
# Duration for Phase 1 is from the input file.
# Duration for Phase 2 is from the input file.
# tl-logic ID: 10591372337
# phase: 0
# group flows: [82, 0, 1.000161111111111]
# The used lanes: [[0], [0]]
# the current cycle length:90 sec
# Green time for phase 0: 37
# The optimal cycle length:40
#
# Duration for Phase 1 is from the input file.
# Duration for Phase 2 is from the input file.
# tl-logic ID: 10591372338
# phase: 0
# group flows: [82, 3.0004833333333334, 1.000161111111111]
# The used lanes: [[0], [0]]
# the current cycle length:90 sec
# Green time for phase 0: 37
# The optimal cycle length:40
#
# Duration for Phase 1 is from the input file.
# Duration for Phase 2 is from the input file.
# tl-logic ID: 10591372358
# phase: 0
# group flows: [82, 81.01304999999999]
# The used lanes: [[0, 1, 2]]
# the current cycle length:90 sec
# Green time for phase 0: 37
# The optimal cycle length:40
#
# Duration for Phase 1 is from the input file.
# Duration for Phase 2 is from the input file.
# tl-logic ID: 10591372360
# phase: 0
# group flows: [82, 81.01304999999999]
# The used lanes: [[0, 1, 2]]
# the current cycle length:90 sec
# Green time for phase 0: 37
# The optimal cycle length:40
#
# Duration for Phase 1 is from the input file.
# Duration for Phase 2 is from the input file.
# tl-logic ID: 10591372362
# phase: 0
# group flows: [82, 77.01240555555555]
# The used lanes: [[0, 1, 2]]
# the current cycle length:90 sec
# Green time for phase 0: 37
# The optimal cycle length:40
#
# Duration for Phase 1 is from the input file.
# Duration for Phase 2 is from the input file.
# tl-logic ID: 10591372364
# phase: 0
# group flows: [82, 77.01240555555555]
# The used lanes: [[0, 1, 2]]
# the current cycle length:90 sec
# Green time for phase 0: 37
# The optimal cycle length:40
#
# Duration for Phase 1 is from the input file.
# Duration for Phase 2 is from the input file.
# tl-logic ID: 10591372366
# phase: 0
# group flows: [82, 77.01240555555555]
# The used lanes: [[0, 1, 2]]
# the current cycle length:90 sec
# Green time for phase 0: 37
# The optimal cycle length:40
#
# Duration for Phase 1 is from the input file.
# Duration for Phase 2 is from the input file.
# tl-logic ID: 10591372368
# phase: 0
# group flows: [82, 77.01240555555555]
# The used lanes: [[0, 1, 2]]
# the current cycle length:90 sec
# Green time for phase 0: 37
# The optimal cycle length:40
#
# Duration for Phase 1 is from the input file.
# Duration for Phase 2 is from the input file.
# tl-logic ID: 105958580
# phase: 0
# group flows: [79, 14.002255555555555]
# The used lanes: [[0]]
# the current cycle length:90 sec
# Green time for phase 0: 37
# The optimal cycle length:40
#
# Duration for Phase 1 is from the input file.
# Duration for Phase 2 is from the input file.
# tl-logic ID: 10608429396
# phase: 0
# group flows: [82, 1.000161111111111, 3.0004833333333334]
# The used lanes: [[0], [0]]
# the current cycle length:90 sec
# Green time for phase 0: 37
# The optimal cycle length:40
#
# Duration for Phase 1 is from the input file.
# Duration for Phase 2 is from the input file.
# tl-logic ID: 10608429399
# phase: 0
# group flows: [82, 4.000644444444444, 1.000161111111111]
# The used lanes: [[0], [0]]
# the current cycle length:90 sec
# Green time for phase 0: 37
# The optimal cycle length:40
#
# Duration for Phase 1 is from the input file.
# Duration for Phase 2 is from the input file.
# tl-logic ID: 10608448605
# phase: 0
# group flows: [82, 1.000161111111111, 5.000805555555555]
# The used lanes: [[0], [0]]
# the current cycle length:90 sec
# Green time for phase 0: 37
# The optimal cycle length:40
#
# Duration for Phase 1 is from the input file.
# Duration for Phase 2 is from the input file.
# tl-logic ID: 106207955
# phase: 0
# group flows: [82, 16.002577777777777]
# The used lanes: [[0]]
# the current cycle length:90 sec
# Green time for phase 0: 37
# The optimal cycle length:40
#
# Duration for Phase 1 is from the input file.
# Duration for Phase 2 is from the input file.
# tl-logic ID: 106207963
# phase: 0
# group flows: [82, 16.002577777777777]
# The used lanes: [[0]]
# the current cycle length:90 sec
# Green time for phase 0: 37
# The optimal cycle length:40
#
# Duration for Phase 1 is from the input file.
# Duration for Phase 2 is from the input file.
# tl-logic ID: 106207989
# phase: 0
# group flows: [82, 17.00273888888889, 14.002255555555555]
# The used lanes: [[0], [0]]
# the current cycle length:90 sec
# Green time for phase 0: 37
# The optimal cycle length:40
#
# Duration for Phase 1 is from the input file.
# Duration for Phase 2 is from the input file.
# tl-logic ID: 10632678700
# phase: 0
# group flows: [79, 106.01707777777777, 106.01707777777777]
# The used lanes: [[0], [0]]
# the current cycle length:90 sec
# Green time for phase 0: 37
# The optimal cycle length:40
#
# Duration for Phase 1 is from the input file.
# Duration for Phase 2 is from the input file.
# tl-logic ID: 10632678701
# phase: 0
# group flows: [79, 106.01707777777777, 106.01707777777777]
# The used lanes: [[0], [0]]
# the current cycle length:90 sec
# Green time for phase 0: 37
# The optimal cycle length:40
#
# Duration for Phase 1 is from the input file.
# Duration for Phase 2 is from the input file.
# tl-logic ID: 10632678702
# phase: 0
# group flows: [79, 106.01707777777777, 106.01707777777777]
# The used lanes: [[0], [0]]
# the current cycle length:90 sec
# Green time for phase 0: 37
# The optimal cycle length:40
#
# Duration for Phase 1 is from the input file.
# Duration for Phase 2 is from the input file.
# tl-logic ID: 10665012694
# phase: 0
# group flows: [82, 1.000161111111111, 19.00306111111111]
# The used lanes: [[0], [0]]
# the current cycle length:90 sec
# Green time for phase 0: 37
# The optimal cycle length:40
#
# Duration for Phase 1 is from the input file.
# Duration for Phase 2 is from the input file.
# tl-logic ID: 10665012699
# phase: 0
# group flows: [82, 2.000322222222222, 20.00322222222222]
# The used lanes: [[0], [0]]
# the current cycle length:90 sec
# Green time for phase 0: 37
# The optimal cycle length:40
#
# Duration for Phase 1 is from the input file.
# Duration for Phase 2 is from the input file.
# tl-logic ID: 10665012700
# phase: 0
# group flows: [82, 2.000322222222222, 20.00322222222222]
# The used lanes: [[0], [0]]
# the current cycle length:90 sec
# Green time for phase 0: 37
# The optimal cycle length:40
#
# Duration for Phase 1 is from the input file.
# Duration for Phase 2 is from the input file.
# tl-logic ID: 10665012701
# phase: 0
# group flows: [82, 2.000322222222222, 21.003383333333332]
# The used lanes: [[0], [0]]
# the current cycle length:90 sec
# Green time for phase 0: 37
# The optimal cycle length:40
#
# Duration for Phase 1 is from the input file.
# Duration for Phase 2 is from the input file.
# tl-logic ID: 10665012702
# phase: 0
# group flows: [82, 2.000322222222222, 20.00322222222222]
# The used lanes: [[0], [0]]
# the current cycle length:90 sec
# Green time for phase 0: 37
# The optimal cycle length:40
#
# Duration for Phase 1 is from the input file.
# Duration for Phase 2 is from the input file.
# tl-logic ID: 10665020497
# phase: 0
# group flows: [82, 1.000161111111111, 19.00306111111111]
# The used lanes: [[0], [0]]
# the current cycle length:90 sec
# Green time for phase 0: 37
# The optimal cycle length:40
#
# Duration for Phase 1 is from the input file.
# Duration for Phase 2 is from the input file.
# tl-logic ID: 10665020538
# phase: 0
# group flows: [82, 1.000161111111111, 20.00322222222222]
# The used lanes: [[0], [0]]
# the current cycle length:90 sec
# Green time for phase 0: 37
# The optimal cycle length:40
#
# Duration for Phase 1 is from the input file.
# Duration for Phase 2 is from the input file.
# tl-logic ID: 10665020542
# phase: 0
# group flows: [82, 6.000966666666667]
# The used lanes: [[0, 1, 2]]
# the current cycle length:90 sec
# Green time for phase 0: 37
# The optimal cycle length:40
#
# Duration for Phase 1 is from the input file.
# Duration for Phase 2 is from the input file.
# tl-logic ID: 10665020556
# phase: 0
# group flows: [82, 1.000161111111111, 0]
# The used lanes: [[0], [0]]
# the current cycle length:90 sec
# Green time for phase 0: 37
# The optimal cycle length:40
#
# Duration for Phase 1 is from the input file.
# Duration for Phase 2 is from the input file.
# tl-logic ID: 10683668334
# phase: 0
# group flows: [82, 6.000966666666667, 6.000966666666667]
# The used lanes: [[0], [0]]
# the current cycle length:90 sec
# Green time for phase 0: 37
# The optimal cycle length:40
#
# Duration for Phase 1 is from the input file.
# Duration for Phase 2 is from the input file.
# tl-logic ID: 10683668335
# phase: 0
# group flows: [82, 6.000966666666667, 6.000966666666667]
# The used lanes: [[0], [0]]
# the current cycle length:90 sec
# Green time for phase 0: 37
# The optimal cycle length:40
#
# Duration for Phase 1 is from the input file.
# Duration for Phase 2 is from the input file.
# tl-logic ID: 10683668370
# phase: 0
# group flows: [82, 35.00563888888889]
# The used lanes: [[0, 1]]
# the current cycle length:90 sec
# Green time for phase 0: 37
# The optimal cycle length:40
#
# Duration for Phase 1 is from the input file.
# Duration for Phase 2 is from the input file.
# tl-logic ID: 10702112573
# phase: 0
# group flows: [79, 108.0174, 107.01723888888888]
# The used lanes: [[0], [0]]
# the current cycle length:90 sec
# Green time for phase 0: 37
# The optimal cycle length:40
#
# Duration for Phase 1 is from the input file.
# Duration for Phase 2 is from the input file.
# tl-logic ID: 10702112574
# phase: 0
# group flows: [79, 107.01723888888888, 107.01723888888888]
# The used lanes: [[0], [0]]
# the current cycle length:90 sec
# Green time for phase 0: 37
# The optimal cycle length:40
#
# Duration for Phase 1 is from the input file.
# Duration for Phase 2 is from the input file.
# tl-logic ID: 10717790697
# phase: 0
# group flows: [82, 3.0004833333333334, 5.000805555555555]
# The used lanes: [[0], [0]]
# the current cycle length:90 sec
# Green time for phase 0: 37
# The optimal cycle length:40
#
# Duration for Phase 1 is from the input file.
# Duration for Phase 2 is from the input file.
# tl-logic ID: 10717790698
# phase: 0
# group flows: [82, 3.0004833333333334, 5.000805555555555]
# The used lanes: [[0], [0]]
# the current cycle length:90 sec
# Green time for phase 0: 37
# The optimal cycle length:40
#
# Duration for Phase 1 is from the input file.
# Duration for Phase 2 is from the input file.
# tl-logic ID: 10717790699
# phase: 0
# group flows: [82, 0, 1.000161111111111]
# The used lanes: [[0], [0]]
# the current cycle length:90 sec
# Green time for phase 0: 37
# The optimal cycle length:40
#
# Duration for Phase 1 is from the input file.
# Duration for Phase 2 is from the input file.
# tl-logic ID: 10717790700
# phase: 0
# group flows: [82, 4.000644444444444, 5.000805555555555]
# The used lanes: [[0], [0]]
# the current cycle length:90 sec
# Green time for phase 0: 37
# The optimal cycle length:40
#
# Duration for Phase 1 is from the input file.
# Duration for Phase 2 is from the input file.
# tl-logic ID: 10717790703
# phase: 0
# group flows: [82, 4.000644444444444, 5.000805555555555]
# The used lanes: [[0], [0]]
# the current cycle length:90 sec
# Green time for phase 0: 37
# The optimal cycle length:40
#
# Duration for Phase 1 is from the input file.
# Duration for Phase 2 is from the input file.
# tl-logic ID: 10717790704
# phase: 0
# group flows: [82, 0, 1.000161111111111]
# The used lanes: [[0], [0]]
# the current cycle length:90 sec
# Green time for phase 0: 37
# The optimal cycle length:40
#
# Duration for Phase 1 is from the input file.
# Duration for Phase 2 is from the input file.
# tl-logic ID: 10721187365
# phase: 0
# group flows: [82, 123.01981666666666, 102.01643333333332]
# The used lanes: [[0, 1], [0, 1]]
# the current cycle length:90 sec
# Green time for phase 0: 37
# The optimal cycle length:40
#
# Duration for Phase 1 is from the input file.
# Duration for Phase 2 is from the input file.
# tl-logic ID: 10721187366
# phase: 0
# group flows: [82, 102.01643333333332]
# The used lanes: [[0, 1]]
# the current cycle length:90 sec
# Green time for phase 0: 37
# The optimal cycle length:40
#
# Duration for Phase 1 is from the input file.
# Duration for Phase 2 is from the input file.
# tl-logic ID: 10732774383
# phase: 0
# group flows: [80, 18.0029, 19.00306111111111]
# The used lanes: [[0], [0]]
# the current cycle length:90 sec
# Green time for phase 0: 37
# The optimal cycle length:40
#
# Duration for Phase 1 is from the input file.
# Duration for Phase 2 is from the input file.
# tl-logic ID: 10732774384
# phase: 0
# group flows: [80, 20.00322222222222, 19.00306111111111]
# The used lanes: [[0], [0]]
# the current cycle length:90 sec
# Green time for phase 0: 37
# The optimal cycle length:40
#
# Duration for Phase 1 is from the input file.
# Duration for Phase 2 is from the input file.
# tl-logic ID: 10732774385
# phase: 0
# group flows: [82, 1.000161111111111, 0]
# The used lanes: [[0], [0]]
# the current cycle length:90 sec
# Green time for phase 0: 37
# The optimal cycle length:40
#
# Duration for Phase 1 is from the input file.
# Duration for Phase 2 is from the input file.
# tl-logic ID: 10741691644
# phase: 0
# group flows: [82, 1.000161111111111, 0]
# The used lanes: [[0], [0]]
# the current cycle length:90 sec
# Green time for phase 0: 37
# The optimal cycle length:40
#
# Duration for Phase 1 is from the input file.
# Duration for Phase 2 is from the input file.
# tl-logic ID: 10741691645
# phase: 0
# group flows: [82, 1.000161111111111, 0]
# The used lanes: [[0], [0]]
# the current cycle length:90 sec
# Green time for phase 0: 37
# The optimal cycle length:40
#
# Duration for Phase 1 is from the input file.
# Duration for Phase 2 is from the input file.
# tl-logic ID: 10776051318
# phase: 0
# group flows: [79, 5.000805555555555]
# The used lanes: [[0, 1]]
# the current cycle length:90 sec
# Green time for phase 0: 37
# The optimal cycle length:40
#
# Duration for Phase 1 is from the input file.
# Duration for Phase 2 is from the input file.
# tl-logic ID: 10778137631
# phase: 0
# group flows: [80, 9.00145, 9.00145]
# The used lanes: [[0], [0]]
# the current cycle length:90 sec
# Green time for phase 0: 37
# The optimal cycle length:40
#
# Duration for Phase 1 is from the input file.
# Duration for Phase 2 is from the input file.
# tl-logic ID: 10779993991
# phase: 0
# group flows: [82, 17.00273888888889]
# The used lanes: [[0, 1, 2]]
# the current cycle length:90 sec
# Green time for phase 0: 37
# The optimal cycle length:40
#
# Duration for Phase 1 is from the input file.
# Duration for Phase 2 is from the input file.
# tl-logic ID: 10790493350
# phase: 0
# group flows: [80, 41.00660555555555]
# The used lanes: [[0, 1, 2]]
# the current cycle length:90 sec
# Green time for phase 0: 37
# The optimal cycle length:40
#
# Duration for Phase 1 is from the input file.
# Duration for Phase 2 is from the input file.
# tl-logic ID: 10790493352
# phase: 0
# group flows: [80, 41.00660555555555]
# The used lanes: [[0, 1, 2]]
# the current cycle length:90 sec
# Green time for phase 0: 37
# The optimal cycle length:40
#
# Duration for Phase 1 is from the input file.
# Duration for Phase 2 is from the input file.
# tl-logic ID: 10790493353
# phase: 0
# group flows: [80, 41.00660555555555]
# The used lanes: [[0, 1, 2]]
# the current cycle length:90 sec
# Green time for phase 0: 37
# The optimal cycle length:40
#
# Duration for Phase 1 is from the input file.
# Duration for Phase 2 is from the input file.
# tl-logic ID: 10792883970
# phase: 0
# group flows: [79, 4.000644444444444]
# The used lanes: [[0]]
# the current cycle length:90 sec
# Green time for phase 0: 37
# The optimal cycle length:40
#
# Duration for Phase 1 is from the input file.
# Duration for Phase 2 is from the input file.
# tl-logic ID: 10792883971
# phase: 0
# group flows: [79, 1.000161111111111, 4.000644444444444]
# The used lanes: [[0], [0]]
# the current cycle length:90 sec
# Green time for phase 0: 37
# The optimal cycle length:40
#
# Duration for Phase 1 is from the input file.
# Duration for Phase 2 is from the input file.
# tl-logic ID: 10792888290
# phase: 0
# group flows: [82, 6.000966666666667, 3.0004833333333334]
# The used lanes: [[0], [0]]
# the current cycle length:90 sec
# Green time for phase 0: 37
# The optimal cycle length:40
#
# Duration for Phase 1 is from the input file.
# Duration for Phase 2 is from the input file.
# tl-logic ID: 10792888291
# phase: 0
# group flows: [82, 6.000966666666667, 3.0004833333333334]
# The used lanes: [[0], [0]]
# the current cycle length:90 sec
# Green time for phase 0: 37
# The optimal cycle length:40
#
# Duration for Phase 1 is from the input file.
# Duration for Phase 2 is from the input file.
# tl-logic ID: 10792888292
# phase: 0
# group flows: [82, 2.000322222222222, 0]
# The used lanes: [[0], [0]]
# the current cycle length:90 sec
# Green time for phase 0: 37
# The optimal cycle length:40
#
# Duration for Phase 1 is from the input file.
# Duration for Phase 2 is from the input file.
# tl-logic ID: 10792888293
# phase: 0
# group flows: [82, 4.000644444444444, 4.000644444444444]
# The used lanes: [[0], [0]]
# the current cycle length:90 sec
# Green time for phase 0: 37
# The optimal cycle length:40
#
# Duration for Phase 1 is from the input file.
# Duration for Phase 2 is from the input file.
# tl-logic ID: 10792888294
# phase: 0
# group flows: [82, 6.000966666666667, 3.0004833333333334]
# The used lanes: [[0], [0]]
# the current cycle length:90 sec
# Green time for phase 0: 37
# The optimal cycle length:40
#
# Duration for Phase 1 is from the input file.
# Duration for Phase 2 is from the input file.
# tl-logic ID: 10792888295
# phase: 0
# group flows: [82, 3.0004833333333334]
# The used lanes: [[0, 1]]
# the current cycle length:90 sec
# Green time for phase 0: 37
# The optimal cycle length:40
#
# Duration for Phase 1 is from the input file.
# Duration for Phase 2 is from the input file.
# tl-logic ID: 10792888296
# phase: 0
# group flows: [82, 0, 2.000322222222222]
# The used lanes: [[0], [0]]
# the current cycle length:90 sec
# Green time for phase 0: 37
# The optimal cycle length:40
#
# Duration for Phase 1 is from the input file.
# Duration for Phase 2 is from the input file.
# tl-logic ID: 10792888298
# phase: 0
# group flows: [82, 2.000322222222222]
# The used lanes: [[0, 1, 2]]
# the current cycle length:90 sec
# Green time for phase 0: 37
# The optimal cycle length:40
#
# Duration for Phase 1 is from the input file.
# Duration for Phase 2 is from the input file.
# tl-logic ID: 10792891332
# phase: 0
# group flows: [82, 1.000161111111111, 0]
# The used lanes: [[0], [0]]
# the current cycle length:90 sec
# Green time for phase 0: 37
# The optimal cycle length:40
#
# Duration for Phase 1 is from the input file.
# Duration for Phase 2 is from the input file.
# tl-logic ID: 10802777754
# phase: 0
# group flows: [82, 5.000805555555555, 3.0004833333333334]
# The used lanes: [[0], [0]]
# the current cycle length:90 sec
# Green time for phase 0: 37
# The optimal cycle length:40
#
# Duration for Phase 1 is from the input file.
# Duration for Phase 2 is from the input file.
# tl-logic ID: 10802777755
# phase: 0
# group flows: [82, 6.000966666666667, 3.0004833333333334]
# The used lanes: [[0], [0]]
# the current cycle length:90 sec
# Green time for phase 0: 37
# The optimal cycle length:40
#
# Duration for Phase 1 is from the input file.
# Duration for Phase 2 is from the input file.
# tl-logic ID: 10812771756
# phase: 0
# group flows: [82, 3.0004833333333334, 5.000805555555555]
# The used lanes: [[0], [0]]
# the current cycle length:90 sec
# Green time for phase 0: 37
# The optimal cycle length:40
#
# Duration for Phase 1 is from the input file.
# Duration for Phase 2 is from the input file.
# tl-logic ID: 10814647247
# TLS: 10814647247 --> the tl-indices with more than one major-green:[6, 6, 6]
# phase: 0
# group flows: [40, 1.000161111111111, 5.000805555555555]
# The used lanes: [[0], [0]]
# phase: 2
# group flows: [40, 1.000161111111111, 0]
# The used lanes: [[0], [0]]
# the current cycle length:90 sec
# Green time for phase 0: 28
# Green time for phase 2: 6
# The optimal cycle length:40
#
# tl-logic ID: 10829095753
# phase: 0
# group flows: [82, 0, 13.002094444444444]
# The used lanes: [[0], [0]]
# the current cycle length:90 sec
# Green time for phase 0: 37
# The optimal cycle length:40
#
# Duration for Phase 1 is from the input file.
# Duration for Phase 2 is from the input file.
# tl-logic ID: 10829095784
# phase: 0
# group flows: [82, 0, 13.002094444444444]
# The used lanes: [[0], [0]]
# the current cycle length:90 sec
# Green time for phase 0: 37
# The optimal cycle length:40
#
# Duration for Phase 1 is from the input file.
# Duration for Phase 2 is from the input file.
# tl-logic ID: 10829095785
# phase: 0
# group flows: [82, 0, 13.002094444444444]
# The used lanes: [[0], [0]]
# the current cycle length:90 sec
# Green time for phase 0: 37
# The optimal cycle length:40
#
# Duration for Phase 1 is from the input file.
# Duration for Phase 2 is from the input file.
# tl-logic ID: 10846342340
# phase: 0
# group flows: [80, 19.00306111111111, 23.003705555555555]
# The used lanes: [[0], [0]]
# the current cycle length:90 sec
# Green time for phase 0: 37
# The optimal cycle length:40
#
# Duration for Phase 1 is from the input file.
# Duration for Phase 2 is from the input file.
# tl-logic ID: 10846342342
# phase: 0
# group flows: [82, 1.000161111111111]
# The used lanes: [[0]]
# the current cycle length:90 sec
# Green time for phase 0: 37
# The optimal cycle length:40
#
# Duration for Phase 1 is from the input file.
# Duration for Phase 2 is from the input file.
# tl-logic ID: 10846342387
# phase: 0
# group flows: [80, 19.00306111111111, 23.003705555555555]
# The used lanes: [[0], [0]]
# the current cycle length:90 sec
# Green time for phase 0: 37
# The optimal cycle length:40
#
# Duration for Phase 1 is from the input file.
# Duration for Phase 2 is from the input file.
# tl-logic ID: 10875857067
# phase: 0
# group flows: [82, 2.000322222222222]
# The used lanes: [[0]]
# the current cycle length:90 sec
# Green time for phase 0: 37
# The optimal cycle length:40
#
# Duration for Phase 1 is from the input file.
# Duration for Phase 2 is from the input file.
# tl-logic ID: 10875857068
# phase: 0
# group flows: [79, 108.0174]
# The used lanes: [[0, 1]]
# the current cycle length:90 sec
# Green time for phase 0: 37
# The optimal cycle length:40
#
# Duration for Phase 1 is from the input file.
# Duration for Phase 2 is from the input file.
# tl-logic ID: 10875857069
# phase: 0
# group flows: [79, 114.01836666666667]
# The used lanes: [[0, 1]]
# the current cycle length:90 sec
# Green time for phase 0: 37
# The optimal cycle length:40
#
# Duration for Phase 1 is from the input file.
# Duration for Phase 2 is from the input file.
# tl-logic ID: 10875857070
# phase: 0
# group flows: [79, 114.01836666666667]
# The used lanes: [[0, 1]]
# the current cycle length:90 sec
# Green time for phase 0: 37
# The optimal cycle length:40
#
# Duration for Phase 1 is from the input file.
# Duration for Phase 2 is from the input file.
# tl-logic ID: 10875857071
# phase: 0
# group flows: [79, 110.01772222222222]
# The used lanes: [[0, 1]]
# the current cycle length:90 sec
# Green time for phase 0: 37
# The optimal cycle length:40
#
# Duration for Phase 1 is from the input file.
# Duration for Phase 2 is from the input file.
# tl-logic ID: 10875857077
# phase: 0
# group flows: [82, 0, 1.000161111111111]
# The used lanes: [[0], [0]]
# the current cycle length:90 sec
# Green time for phase 0: 37
# The optimal cycle length:40
#
# Duration for Phase 1 is from the input file.
# Duration for Phase 2 is from the input file.
# tl-logic ID: 10875857078
# phase: 0
# group flows: [82, 2.000322222222222, 0]
# ...
# The optimal cycle length:40
#
# Duration for Phase 1 is from the input file.
# Duration for Phase 2 is from the input file.
# tl-logic ID: 9744954887
# phase: 0
# group flows: [80, 0, 2.000322222222222]
# The used lanes: [[0], [0]]
# the current cycle length:90 sec
# Green time for phase 0: 37
# The optimal cycle length:40
#
# Duration for Phase 1 is from the input file.
# Duration for Phase 2 is from the input file.
# tl-logic ID: 976665789
# phase: 0
# group flows: [82, 14.002255555555555, 38.00612222222222]
# The used lanes: [[0], [0]]
# the current cycle length:90 sec
# Green time for phase 0: 37
# The optimal cycle length:40
#
# Duration for Phase 1 is from the input file.
# Duration for Phase 2 is from the input file.
# tl-logic ID: 976665959
# phase: 0
# group flows: [82, 14.002255555555555, 38.00612222222222]
# The used lanes: [[0], [0]]
# the current cycle length:90 sec
# Green time for phase 0: 37
# The optimal cycle length:40
#
# Duration for Phase 1 is from the input file.
# Duration for Phase 2 is from the input file.
# tl-logic ID: 976666186
# phase: 0
# group flows: [82, 10.00161111111111]
# The used lanes: [[0, 1]]
# the current cycle length:90 sec
# Green time for phase 0: 37
# The optimal cycle length:40
#
# Duration for Phase 1 is from the input file.
# Duration for Phase 2 is from the input file.
# tl-logic ID: 976666416
# phase: 0
# group flows: [82, 4.000644444444444]
# The used lanes: [[0]]
# the current cycle length:90 sec
# Green time for phase 0: 37
# The optimal cycle length:40
#
# Duration for Phase 1 is from the input file.
# Duration for Phase 2 is from the input file.
# tl-logic ID: 976666500
# TLS: 976666500 --> the tl-indices with more than one major-green:[0, 0, 0]
# phase: 0
# group flows: [42, 6.501047222222223, 8.001288888888888]
# The used lanes: [[0, 1], [0, 1]]
# phase: 2
# group flows: [42, 0.5000805555555555, 1.000161111111111]
# The used lanes: [[0], [0]]
# the current cycle length:90 sec
# Green time for phase 0: 27
# Green time for phase 2: 7
# The optimal cycle length:40
#
# tl-logic ID: 9792731217
# phase: 0
# group flows: [80, 1.000161111111111]
# The used lanes: [[0]]
# the current cycle length:90 sec
# Green time for phase 0: 37
# The optimal cycle length:40
#
# Duration for Phase 1 is from the input file.
# Duration for Phase 2 is from the input file.
# tl-logic ID: 9792731220
# phase: 0
# group flows: [79, 21.003383333333332]
# The used lanes: [[0]]
# the current cycle length:90 sec
# Green time for phase 0: 37
# The optimal cycle length:40
#
# Duration for Phase 1 is from the input file.
# Duration for Phase 2 is from the input file.
# tl-logic ID: 9809062140
# phase: 0
# group flows: [82, 10.00161111111111, 10.00161111111111]
# The used lanes: [[0], [0]]
# the current cycle length:90 sec
# Green time for phase 0: 37
# The optimal cycle length:40
#
# Duration for Phase 1 is from the input file.
# Duration for Phase 2 is from the input file.
# tl-logic ID: 9830576639
# phase: 0
# group flows: [80, 13.002094444444444, 8.001288888888888]
# The used lanes: [[0], [0]]
# the current cycle length:90 sec
# Green time for phase 0: 37
# The optimal cycle length:40
#
# Duration for Phase 1 is from the input file.
# Duration for Phase 2 is from the input file.
# tl-logic ID: 9846519252
# phase: 0
# group flows: [79, 12.001933333333334]
# The used lanes: [[0, 1]]
# the current cycle length:90 sec
# Green time for phase 0: 37
# The optimal cycle length:40
#
# Duration for Phase 1 is from the input file.
# Duration for Phase 2 is from the input file.
# tl-logic ID: 9846519259
# phase: 0
# group flows: [82, 11.001772222222222]
# The used lanes: [[0, 1]]
# the current cycle length:90 sec
# Green time for phase 0: 37
# The optimal cycle length:40
#
# Duration for Phase 1 is from the input file.
# Duration for Phase 2 is from the input file.
# tl-logic ID: 9846519262
# phase: 0
# group flows: [80, 3.0004833333333334]
# The used lanes: [[0]]
# the current cycle length:90 sec
# Green time for phase 0: 37
# The optimal cycle length:40
#
# Duration for Phase 1 is from the input file.
# Duration for Phase 2 is from the input file.
# tl-logic ID: 9849042346
# phase: 0
# group flows: [79, 4.000644444444444]
# The used lanes: [[0, 1]]
# the current cycle length:90 sec
# Green time for phase 0: 37
# The optimal cycle length:40
#
# Duration for Phase 1 is from the input file.
# Duration for Phase 2 is from the input file.
# tl-logic ID: 9849042351
# phase: 0
# group flows: [79, 11.001772222222222]
# The used lanes: [[0, 1]]
# the current cycle length:90 sec
# Green time for phase 0: 37
# The optimal cycle length:40
#
# Duration for Phase 1 is from the input file.
# Duration for Phase 2 is from the input file.
# tl-logic ID: 9853021287
# phase: 0
# group flows: [82, 1.000161111111111, 0]
# The used lanes: [[0], [0]]
# the current cycle length:90 sec
# Green time for phase 0: 37
# The optimal cycle length:40
#
# Duration for Phase 1 is from the input file.
# Duration for Phase 2 is from the input file.
# tl-logic ID: 9860805564
# phase: 0
# group flows: [82, 0, 2.000322222222222]
# The used lanes: [[0], [0]]
# the current cycle length:90 sec
# Green time for phase 0: 37
# The optimal cycle length:40
#
# Duration for Phase 1 is from the input file.
# Duration for Phase 2 is from the input file.
# tl-logic ID: 9860805566
# phase: 0
# group flows: [82, 0, 2.000322222222222]
# The used lanes: [[0], [0]]
# the current cycle length:90 sec
# Green time for phase 0: 37
# The optimal cycle length:40
#
# Duration for Phase 1 is from the input file.
# Duration for Phase 2 is from the input file.
# tl-logic ID: 9862189839
# phase: 0
# group flows: [80, 9.00145, 1.000161111111111]
# The used lanes: [[0], [0]]
# the current cycle length:90 sec
# Green time for phase 0: 37
# The optimal cycle length:40
#
# Duration for Phase 1 is from the input file.
# Duration for Phase 2 is from the input file.
# tl-logic ID: 9862189869
# phase: 0
# group flows: [80, 10.00161111111111, 1.000161111111111]
# The used lanes: [[0], [0]]
# the current cycle length:90 sec
# Green time for phase 0: 37
# The optimal cycle length:40
#
# Duration for Phase 1 is from the input file.
# Duration for Phase 2 is from the input file.
# tl-logic ID: 9868128826
# phase: 0
# group flows: [82, 1.000161111111111, 1.000161111111111]
# The used lanes: [[0], [0]]
# the current cycle length:90 sec
# Green time for phase 0: 37
# The optimal cycle length:40
#
# Duration for Phase 1 is from the input file.
# Duration for Phase 2 is from the input file.
# tl-logic ID: 9868128827
# phase: 0
# group flows: [82, 1.000161111111111, 1.000161111111111]
# The used lanes: [[0], [0]]
# the current cycle length:90 sec
# Green time for phase 0: 37
# The optimal cycle length:40
#
# Duration for Phase 1 is from the input file.
# Duration for Phase 2 is from the input file.
# tl-logic ID: 9876736997
# phase: 0
# group flows: [82, 4.000644444444444, 1.000161111111111]
# The used lanes: [[0], [0]]
# the current cycle length:90 sec
# Green time for phase 0: 37
# The optimal cycle length:40
#
# Duration for Phase 1 is from the input file.
# Duration for Phase 2 is from the input file.
# tl-logic ID: 9881958052
# phase: 0
# group flows: [39, 9.00145, 11.001772222222222]
# The used lanes: [[0, 1], [0, 1]]
# phase: 2
# group flows: [39, 0]
# The used lanes: [[0]]
# the current cycle length:90 sec
# Green time for phase 0: 33
# Green time for phase 2: 4
# The optimal cycle length:43
#
# tl-logic ID: 990382953
# TLS: 990382953 --> the tl-indices with more than one major-green:[6, 6, 6]
# phase: 0
# group flows: [40, 86.01385555555555, 78.76268749999998]
# The used lanes: [[0], [0]]
# phase: 2
# group flows: [40, 14.002255555555555, 2.7504430555555555]
# The used lanes: [[0], [0]]
# the current cycle length:90 sec
# Green time for phase 0: 29
# Green time for phase 2: 5
# The optimal cycle length:40
#
# tl-logic ID: 9919922412
# phase: 0
# group flows: [82, 0, 1.000161111111111]
# The used lanes: [[0], [0]]
# the current cycle length:90 sec
# Green time for phase 0: 37
# The optimal cycle length:40
#
# Duration for Phase 1 is from the input file.
# Duration for Phase 2 is from the input file.
# tl-logic ID: 9920329685
# phase: 0
# group flows: [82, 5.000805555555555]
# The used lanes: [[0, 1]]
# the current cycle length:90 sec
# Green time for phase 0: 37
# The optimal cycle length:40
#
# Duration for Phase 1 is from the input file.
# Duration for Phase 2 is from the input file.
# tl-logic ID: 9920329686
# phase: 0
# group flows: [82, 8.001288888888888, 9.00145]
# The used lanes: [[0], [0]]
# the current cycle length:90 sec
# Green time for phase 0: 37
# The optimal cycle length:40
#
# Duration for Phase 1 is from the input file.
# Duration for Phase 2 is from the input file.
# tl-logic ID: 992063477
# phase: 0
# group flows: [80, 3.0004833333333334, 0]
# The used lanes: [[0], [0]]
# the current cycle length:90 sec
# Green time for phase 0: 37
# The optimal cycle length:40
#
# Duration for Phase 1 is from the input file.
# Duration for Phase 2 is from the input file.
# tl-logic ID: 9933890470
# phase: 0
# group flows: [80, 25.004027777777775]
# The used lanes: [[0, 1, 2]]
# the current cycle length:90 sec
# Green time for phase 0: 37
# The optimal cycle length:40
#
# Duration for Phase 1 is from the input file.
# Duration for Phase 2 is from the input file.
# tl-logic ID: 9933921647
# phase: 0
# group flows: [82, 3.0004833333333334, 1.000161111111111]
# The used lanes: [[0], [0]]
# the current cycle length:90 sec
# Green time for phase 0: 37
# The optimal cycle length:40
#
# Duration for Phase 1 is from the input file.
# Duration for Phase 2 is from the input file.
# tl-logic ID: 9933921648
# phase: 0
# group flows: [82, 3.0004833333333334, 1.000161111111111]
# The used lanes: [[0], [0]]
# the current cycle length:90 sec
# Green time for phase 0: 37
# The optimal cycle length:40
#
# Duration for Phase 1 is from the input file.
# Duration for Phase 2 is from the input file.
# tl-logic ID: 9933921649
# phase: 0
# group flows: [82, 3.0004833333333334, 1.000161111111111]
# The used lanes: [[0], [0]]
# the current cycle length:90 sec
# Green time for phase 0: 37
# The optimal cycle length:40
#
# Duration for Phase 1 is from the input file.
# Duration for Phase 2 is from the input file.
# tl-logic ID: 9933921686
# phase: 0
# group flows: [80, 38.00612222222222, 40.00644444444444]
# The used lanes: [[0], [0]]
# the current cycle length:90 sec
# Green time for phase 0: 37
# The optimal cycle length:40
#
# Duration for Phase 1 is from the input file.
# Duration for Phase 2 is from the input file.
# tl-logic ID: 9935843362
# phase: 0
# group flows: [80, 1.000161111111111, 0]
# The used lanes: [[0], [0]]
# the current cycle length:90 sec
# Green time for phase 0: 37
# The optimal cycle length:40
#
# Duration for Phase 1 is from the input file.
# Duration for Phase 2 is from the input file.
# tl-logic ID: 9935843363
# phase: 0
# group flows: [80, 1.000161111111111, 0]
# The used lanes: [[0], [0]]
# the current cycle length:90 sec
# Green time for phase 0: 37
# The optimal cycle length:40
#
# Duration for Phase 1 is from the input file.
# Duration for Phase 2 is from the input file.
# tl-logic ID: 9935843368
# phase: 0
# group flows: [80, 1.000161111111111, 0]
# The used lanes: [[0], [0]]
# the current cycle length:90 sec
# Green time for phase 0: 37
# The optimal cycle length:40
#
# Duration for Phase 1 is from the input file.
# Duration for Phase 2 is from the input file.
# tl-logic ID: 9935843369
# phase: 0
# group flows: [80, 1.000161111111111, 0]
# The used lanes: [[0], [0]]
# the current cycle length:90 sec
# Green time for phase 0: 37
# The optimal cycle length:40
#
# Duration for Phase 1 is from the input file.
# Duration for Phase 2 is from the input file.
# tl-logic ID: 9935843370
# phase: 0
# group flows: [80, 1.000161111111111, 0]
# The used lanes: [[0], [0]]
# the current cycle length:90 sec
# Green time for phase 0: 37
# The optimal cycle length:40
#
# Duration for Phase 1 is from the input file.
# Duration for Phase 2 is from the input file.
# tl-logic ID: 9947419191
# phase: 0
# group flows: [80, 11.001772222222222, 8.001288888888888]
# The used lanes: [[0], [0]]
# the current cycle length:90 sec
# Green time for phase 0: 37
# The optimal cycle length:40
#
# Duration for Phase 1 is from the input file.
# Duration for Phase 2 is from the input file.
# tl-logic ID: 995542711
# phase: 0
# group flows: [79, 9.00145, 14.002255555555555]
# The used lanes: [[0], [0]]
# the current cycle length:90 sec
# Green time for phase 0: 37
# The optimal cycle length:40
#
# Duration for Phase 1 is from the input file.
# Duration for Phase 2 is from the input file.
# tl-logic ID: 9957293223
# phase: 0
# group flows: [82, 0, 10.00161111111111]
# The used lanes: [[0], [0]]
# the current cycle length:90 sec
# Green time for phase 0: 37
# The optimal cycle length:40
#
# Duration for Phase 1 is from the input file.
# Duration for Phase 2 is from the input file.
# tl-logic ID: 996349366
# phase: 0
# group flows: [80, 10.00161111111111]
# The used lanes: [[0]]
# the current cycle length:90 sec
# Green time for phase 0: 37
# The optimal cycle length:40
#
# Duration for Phase 1 is from the input file.
# Duration for Phase 2 is from the input file.
# tl-logic ID: 9968102587
# phase: 0
# group flows: [79, 2.000322222222222, 1.000161111111111]
# The used lanes: [[0], [0]]
# the current cycle length:90 sec
# Green time for phase 0: 37
# The optimal cycle length:40
#
# Duration for Phase 1 is from the input file.
# Duration for Phase 2 is from the input file.
# tl-logic ID: 9968102588
# phase: 0
# group flows: [79, 9.00145, 1.000161111111111]
# The used lanes: [[0], [0]]
# the current cycle length:90 sec
# Green time for phase 0: 37
# The optimal cycle length:40
#
# Duration for Phase 1 is from the input file.
# Duration for Phase 2 is from the input file.
# tl-logic ID: 9968102589
# phase: 0
# group flows: [79, 8.001288888888888, 1.000161111111111]
# The used lanes: [[0], [0]]
# the current cycle length:90 sec
# Green time for phase 0: 37
# The optimal cycle length:40
#
# Duration for Phase 1 is from the input file.
# Duration for Phase 2 is from the input file.
# tl-logic ID: 9983558609
# phase: 0
# group flows: [79, 21.003383333333332]
# The used lanes: [[0, 1]]
# the current cycle length:90 sec
# Green time for phase 0: 37
# The optimal cycle length:40
#
# Duration for Phase 1 is from the input file.
# Duration for Phase 2 is from the input file.
# tl-logic ID: 9983558616
# phase: 0
# group flows: [82, 1.000161111111111]
# The used lanes: [[0]]
# the current cycle length:90 sec
# Green time for phase 0: 37
# The optimal cycle length:40
#
# Duration for Phase 1 is from the input file.
# Duration for Phase 2 is from the input file.
# [01] Tạo tls_coord_base từ routes_01_merged.xml …
# number of tls-pairs: 76
# operations: newSet=28 addToSet=12 addToSet2=9 addHalfCoordinated=0 mergeSets=27
# [02] tls_cycle_base đã tồn tại, bỏ qua.
# [02] tls_coord_base đã tồn tại, bỏ qua.
# [03] tls_cycle_base đã tồn tại, bỏ qua.
# [03] tls_coord_base đã tồn tại, bỏ qua.
# [04] tls_cycle_base đã tồn tại, bỏ qua.
# [04] tls_coord_base đã tồn tại, bỏ qua.
# [05] tls_cycle_base đã tồn tại, bỏ qua.
# [05] tls_coord_base đã tồn tại, bỏ qua.
# [06] tls_cycle_base đã tồn tại, bỏ qua.
# [06] tls_coord_base đã tồn tại, bỏ qua.
# [07] tls_cycle_base đã tồn tại, bỏ qua.
# [07] tls_coord_base đã tồn tại, bỏ qua.
# [08] tls_cycle_base đã tồn tại, bỏ qua.
# [08] tls_coord_base đã tồn tại, bỏ qua.
# [09] tls_cycle_base đã tồn tại, bỏ qua.
# [09] tls_coord_base đã tồn tại, bỏ qua.
# [10] tls_cycle_base đã tồn tại, bỏ qua.
# [10] tls_coord_base đã tồn tại, bỏ qua.
# [11] tls_cycle_base đã tồn tại, bỏ qua.
# [11] tls_coord_base đã tồn tại, bỏ qua.
# [12] tls_cycle_base đã tồn tại, bỏ qua.
# [12] tls_coord_base đã tồn tại, bỏ qua.
# [13] tls_cycle_base đã tồn tại, bỏ qua.
# [13] tls_coord_base đã tồn tại, bỏ qua.
# [14] tls_cycle_base đã tồn tại, bỏ qua.
# [14] tls_coord_base đã tồn tại, bỏ qua.
# [15] tls_cycle_base đã tồn tại, bỏ qua.
# [15] tls_coord_base đã tồn tại, bỏ qua.
# [16] tls_cycle_base đã tồn tại, bỏ qua.
# [16] tls_coord_base đã tồn tại, bỏ qua.
# [17] tls_cycle_base đã tồn tại, bỏ qua.
# [17] tls_coord_base đã tồn tại, bỏ qua.
# [18] tls_cycle_base đã tồn tại, bỏ qua.
# [18] tls_coord_base đã tồn tại, bỏ qua.
# [19] tls_cycle_base đã tồn tại, bỏ qua.
# [19] tls_coord_base đã tồn tại, bỏ qua.
# [20] tls_cycle_base đã tồn tại, bỏ qua.
# [20] tls_coord_base đã tồn tại, bỏ qua.
# [21] tls_cycle_base đã tồn tại, bỏ qua.
# [21] tls_coord_base đã tồn tại, bỏ qua.
# [22] tls_cycle_base đã tồn tại, bỏ qua.
# [22] tls_coord_base đã tồn tại, bỏ qua.
# [23] tls_cycle_base đã tồn tại, bỏ qua.
# [23] tls_coord_base đã tồn tại, bỏ qua.
# === Hoàn thành tạo base TLS cho mọi giờ! ===
#
# [WARNING] Không tìm thấy bất kỳ file sub-of trong thư mục gốc routes.
# === Hoàn thành split base TLS thành các ofN! ===
